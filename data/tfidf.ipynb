# %%
import pickle
import pandas as pd
import numpy as np
import scipy
import concurrent.futures as cf
from pymongo import MongoClient
from pprint import pprint
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv('question_data.csv')

# %%
code = df['code'].values.tolist()
code
# Out:
# ['2D3Y1_163',
#  '2D3Y3_74',
#  '2D4Y3_24',
#  '2D4Y3_26',
#  '2D4Y3_27',
#  '2D3Y2_48',
#  '2D3Y2_74',
#  '2D3Y2_76',
#  '2D3Y2_83',
#  '2D3Y2_91',
#  '2D3Y2_171',
#  '2D3Y2_175',
#  '2D3Y3_52',
#  '2D3Y3_66',
#  '2D3Y3_80',
#  '2D4Y3_16',
#  '2D3Y2_39',
#  '2D3Y2_54',
#  '2D3Y2_47',
#  '2D3Y2_56',
#  '2D3Y3_60',
#  '2D3Y3_26',
#  '2D3Y2_105',
#  '2D3Y2_60',
#  '2D3Y3_71',
#  '2D3Y3_96',
#  '2D4Y2_49',
#  '2D4Y2_61',
#  '2D4Y2_65',
#  '2D3Y2_34',
#  '2D3Y2_46',
#  '2D3Y2_49',
#  '2D3Y2_80',
#  '2D3Y2_72',
#  '2D3Y2_82',
#  '2D3Y3_12',
#  '2D3Y3_28',
#  '2D4Y2_57',
#  '2D4Y3_10',
#  '2D4Y3_17',
#  '2D4Y3_28',
#  '2D3Y2_35',
#  '2D3Y2_42',
#  '2D3Y2_43',
#  '2D3Y3_3',
#  '2D3Y2_100',
#  '2D3Y2_111',
#  '2D3Y2_179',
#  '2D3Y3_98',
#  '2D4B1_68',
#  '2D4Y2_48',
#  '2D4Y2_64',
#  '2D4Y3_1',
#  '2D4Y3_2',
#  '2D3Y2_50',
#  '2D3Y2_55',
#  '2D3Y2_65',
#  '2D3Y3_40',
#  '2D3Y2_94',
#  '2D3Y3_30',
#  '2D3Y3_37',
#  '2D3Y3_57',
#  '2D3Y3_67',
#  '2D3Y3_72',
#  '2D3Y3_81',
#  '2D4B1_41',
#  '2D4Y2_45',
#  '2D4Y2_59',
#  '2D3Y2_109',
#  '2D3Y3_54',
#  '2D3Y3_39',
#  '2D3Y3_8',
#  '2D3Y3_6',
#  '2D3Y3_25',
#  '2D3Y3_55',
#  '2D3Y3_73',
#  '2D3Y3_89',
#  '2D4Y3_21',
#  '2D4Y4_7',
#  '2D3Y2_118',
#  '2D3Y3_35',
#  '2D3Y3_33',
#  '2D3Y3_58',
#  '2D4Y2_62',
#  '2D4Y3_13',
#  '2D4Y3_22',
#  '2D4Y3_23',
#  '2D3Y2_41',
#  '2D3Y2_67',
#  '2D3Y2_97',
#  '2D3Y2_104',
#  '2D3Y2_180',
#  '2D3Y3_77',
#  '2D3Y3_46',
#  '2D3Y3_41',
#  '2D3Y2_103',
#  '2D3Y3_88',
#  '2D4B2_56',
#  '2D4Y2_43',
#  '2D4Y3_6',
#  '2D4Y3_7',
#  '2D4Y3_9',
#  '2D4Y3_11',
#  '2D4Y3_19',
#  '2D4Y4_11',
#  '2D3Y3_84',
#  '2D3Y2_33',
#  '2D3Y2_88',
#  '2D3Y2_113',
#  '2D3Y2_117',
#  '2D3Y3_2',
#  '2D3Y3_5',
#  '2D3Y3_31',
#  '2D3Y3_32',
#  '2D3Y3_51',
#  '2D4Y2_50',
#  '2D3Y2_36',
#  '2D4Y2_54',
#  '2D3Y3_68',
#  '2D3Y3_62',
#  '2D3Y2_93',
#  '2D3Y2_114',
#  '2D3Y2_173',
#  '2D3Y3_13',
#  '2D3Y3_14',
#  '2D3Y3_15',
#  '2D3Y3_34',
#  '2D3Y3_75',
#  '2D3Y3_82',
#  '2D3Y3_64',
#  '2D4B2_27',
#  '2D4Y3_3',
#  '2D4Y3_4',
#  '2D4Y3_12',
#  '2D4Y3_15',
#  '2D4Y4_3',
#  '2D4Y4_8',
#  '2D3Y2_73',
#  '2D3Y2_106',
#  '2D3Y3_61',
#  '2D4Y2_51',
#  '2D4Y4_12',
#  '2D3Y2_87',
#  '2D3Y2_101',
#  '2D4Y3_14',
#  '2D3Y2_71',
#  '2D3Y2_92',
#  '2D3Y2_102',
#  '2D3Y2_112',
#  '2D3Y2_116',
#  '2D3Y3_11',
#  '2D3Y3_49',
#  '2D3Y3_63',
#  '2D4Y2_53',
#  '2D4Y2_55',
#  '2D4Y2_60',
#  '2D4Y2_66',
#  '2D4Y3_18',
#  '2D4Y3_32',
#  '2D4Y3_33',
#  '2D4Y4_1',
#  '2D4Y4_9',
#  '2D4Y4_10',
#  '2D3Y2_68',
#  '2D4Y2_58',
#  '2D3Y2_89',
#  '2D4Y2_44',
#  '2D3Y3_95',
#  '2D3Y2_178',
#  '2D3Y3_17',
#  '2D3Y3_20',
#  '2D3Y3_43',
#  '2D3Y3_48',
#  '2D3Y3_94',
#  '2D3Y3_97',
#  '2D3Y3_100',
#  '2D4Y2_47',
#  '2D3Y3_109',
#  '2D4Y2_56',
#  '2D4Y3_30',
#  '2D4Y3_31',
#  '2D4Y4_5',
#  '2D4Y4_6',
#  '2D3Y2_45',
#  '2D3Y2_78',
#  '2D3Y2_172',
#  '2D3Y2_181',
#  '2D3Y3_9',
#  '2D4Y3_25',
#  '2D3Y2_32',
#  '2D3Y2_57',
#  '2D3Y2_58',
#  '2D4Y1_28',
#  '2D4Y1_37',
#  '2D4Y1_46',
#  '2D4Y1_50',
#  '2D4Y1_54',
#  '2D4Y1_68',
#  '2D4Y1_142',
#  '2D4Y1_156',
#  '2D4Y1_158',
#  '2D4Y1_24',
#  '2D4Y1_173',
#  '2D4Y1_26',
#  '2D4Y1_55',
#  '2D4Y1_65',
#  '2D4Y1_71',
#  '2D4Y1_76',
#  '2D4Y1_85',
#  '2D4Y1_113',
#  '2D4Y1_124',
#  '2D4Y1_147',
#  '2D4Y1_178',
#  '2D4Y1_160',
#  '2D4Y1_20',
#  '2D4Y1_6',
#  '2D4Y1_51',
#  '2D4Y1_56',
#  '2D4Y1_57',
#  '2D4Y1_61',
#  '2D4Y1_73',
#  '2D4Y1_80',
#  '2D4Y1_108',
#  '2D4Y1_167',
#  '2D4K5_59',
#  '2D4Y1_16',
#  '2D4Y1_10',
#  '2D4Y1_47',
#  '2D4Y1_96',
#  '2D4Y1_98',
#  '2D4Y1_114',
#  '2D4Y1_121',
#  '2D4Y1_151',
#  '2D4Y1_171',
#  '2D4Y2_2',
#  '2D4Y1_5',
#  '2D4Y1_14',
#  '2D4Y1_48',
#  '2D4Y1_176',
#  '2D4Y1_31',
#  '2D4Y1_175',
#  '2D4Y1_22',
#  '2D4Y1_60',
#  '2D4Y1_75',
#  '2D4Y1_79',
#  '2D4Y1_81',
#  '2D4Y1_84',
#  '2D4Y1_91',
#  '2D4Y1_137',
#  '2D4Y1_172',
#  '2D4Y1_154',
#  '2D4Y2_1',
#  '2D4Y1_13',
#  '2D4Y1_18',
#  '2D4Y1_33',
#  '2D4Y1_39',
#  '2D4Y1_45',
#  '2D4Y1_86',
#  '2D4Y1_89',
#  '2D4Y1_105',
#  '2D4Y1_161',
#  '2D4Y1_8',
#  '2D4Y1_163',
#  '2D4Y1_144',
#  '2D4Y1_38',
#  '2D4Y1_63',
#  '2D4Y1_66',
#  '2D4Y1_69',
#  '2D4Y1_94',
#  '2D4Y1_111',
#  '2D4Y1_127',
#  '2D4Y1_135',
#  '2D4Y1_146',
#  '2D4Y1_150',
#  '2D4Y1_179',
#  '2D4Y1_3',
#  '2D4Y1_35',
#  '2D4Y1_40',
#  '2D4Y1_59',
#  '2D4Y1_74',
#  '2D4Y1_87',
#  '2D4Y1_116',
#  '2D4Y1_122',
#  '2D4Y1_138',
#  '2D4Y1_1',
#  '2D3Y2_13',
#  '2D4Y1_44',
#  '2D4Y1_148',
#  '2D3Y3_65',
#  '2D3Y3_76',
#  '2D3Y3_78',
#  '2D3Y3_85',
#  '2D3Y3_110',
#  '2D4Y2_63',
#  '2D4Y3_5',
#  '2D4Y3_20',
#  '2D4Y5_1',
#  '2D3Y3_47',
#  '2D4Y4_18',
#  '2D4Y4_14',
#  '2H1B1_22',
#  '2D4Y4_20',
#  '2D4Y4_13',
#  '2D4Y4_15',
#  '2H1B3_210',
#  '2H1B3_545',
#  '2D4G5_16',
#  '2D4K1_27',
#  '2D4Y4_19',
#  '2D4K3_29',
#  '2D3Y3_22',
#  '2D3Y2_177',
#  '2D3Y2_62',
#  '2D3Y2_66',
#  '2D3Y2_70',
#  '2D3Y2_75',
#  '2D3Y2_98',
#  '2D3Y2_107',
#  '2D3Y3_1',
#  '2D3Y3_19',
#  '2D3Y3_86',
#  '2D3Y3_10',
#  '2D3Y3_99',
#  '2D4Y3_8',
#  '2D4Y4_4',
#  '2D3Y2_51',
#  '2D3Y2_53',
#  '2D3Y2_63',
#  '2D3Y2_86',
#  '2D3Y2_96',
#  '2D3Y2_108',
#  '2D3Y2_110',
#  '2D4Y2_46',
#  '2D4Y1_168',
#  '2D4K2_69',
#  '2D4Y1_83',
#  '2D4Y1_9',
#  '2D4Y1_11',
#  '2D4Y1_52',
#  '2D4Y1_53',
#  '2D4Y1_77',
#  '2D4Y1_90',
#  '2D4Y1_131',
#  '2D4Y1_139',
#  '2D4Y1_143',
#  '2D4Y1_7',
#  '2D4Y1_4',
#  '2D4Y1_30',
#  '2D4Y1_67',
#  '2D4Y1_78',
#  '2D4Y1_82',
#  '2D4Y1_95',
#  '2D4Y1_106',
#  '2D4Y1_117',
#  '2D4Y1_120',
#  '2D4Y1_128',
#  '2D4Y1_19',
#  '2D4Y1_43',
#  '2D4Y1_180',
#  '2D4Y1_169',
#  '2D4Y1_93',
#  '2D4Y1_97',
#  '2D4Y1_101',
#  '2D4Y1_126',
#  '2D4Y1_153',
#  '2D4Y1_157',
#  '2D4Y1_162',
#  '2D4Y1_174',
#  '2D4Y1_12',
#  '2D4Y1_177',
#  '2D4Y1_15',
#  '2D4Y1_49',
#  '2D4Y1_58',
#  '2D4Y1_64',
#  '2D4Y1_88',
#  '2D4Y1_92',
#  '2D4Y1_115',
#  '2D4Y1_133',
#  '2D4Y1_164',
#  '2D4Y1_166',
#  '2D4Y1_32',
#  '2D3Y1_215',
#  '2D3Y1_196',
#  '2D3Y1_172',
#  '2D1Y5_88',
#  '2D1Y5_110',
#  '2D3Y1_4',
#  '2D3Y1_9',
#  '2D3Y1_23',
#  '2D3Y1_29',
#  '2D3Y1_31',
#  '2D3Y1_3',
#  '2D3Y1_11',
#  '2D1Y5_76',
#  '2D3Y1_22',
#  '2D3Y1_27',
#  '2D3Y1_24',
#  '2D3Y1_26',
#  '2D3Y1_20',
#  '2D3Y1_28',
#  '2D3Y1_32',
#  '2D3Y1_5',
#  '2D3Y1_17',
#  '2D3Y1_18',
#  '2D3Y1_19',
#  '2D3Y1_8',
#  '2D1Y5_70',
#  '2D1Y5_119',
#  '2D1Y5_112',
#  '2D1Y5_78',
#  '2D1Y5_89',
#  '2D1Y5_109',
#  '2D1Y5_131',
#  '2D1Y5_64',
#  '2D1Y5_79',
#  '2D1Y5_83',
#  '2D1Y5_92',
#  '2D1Y5_66',
#  '2D1Y5_97',
#  '2D1Y5_118',
#  '2D1Y5_96',
#  '2D1Y5_116',
#  '2D1Y5_122',
#  '2D1Y5_130',
#  '2D1Y5_62',
#  '2D1Y5_84',
#  '2D1Y5_105',
#  '2D1Y5_114',
#  '2D1Y5_99',
#  '2D1Y5_74',
#  '2D3Y1_10',
#  '2D2B6_78',
#  '2D2Y3_129',
#  '2D2Y3_135',
#  '2D2Y3_138',
#  '2D2Y3_155',
#  '2D2Y3_110',
#  '2D2Y3_112',
#  '2D2Y3_122',
#  '2D2Y3_126',
#  '2D2Y3_136',
#  '2D2Y3_128',
#  '2D2Y3_137',
#  '2D2Y3_142',
#  '2D2Y3_91',
#  '2D2Y3_98',
#  '2D2Y3_108',
#  '2D2Y3_109',
#  '2D2Y3_115',
#  '2D2Y3_143',
#  '2D2Y3_131',
#  '2D2Y3_89',
#  '2D2Y3_121',
#  '2D2B6_103',
#  '2D2Y3_96',
#  '2D2Y3_116',
#  '2D2Y3_97',
#  '2D2Y3_103',
#  '2D2Y3_114',
#  '2D2Y3_130',
#  '2D2Y3_153',
#  '2D2Y3_94',
#  '2D2Y3_99',
#  '2D2Y3_100',
#  '2D2Y3_113',
#  '2D2Y3_140',
#  '2D2Y3_118',
#  '2D2Y3_125',
#  '2D2Y3_133',
#  '2D2Y3_92',
#  '2D2Y3_117',
#  '2D2Y3_90',
#  '2D2Y3_107',
#  '2D2Y3_111',
#  '2D2Y3_124',
#  '2D2Y3_102',
#  '2D2Y3_123',
#  '2D2Y3_95',
#  '2D1Y5_86',
#  '2D1Y5_72',
#  '2D1Y4_224',
#  '2D1Y4_226',
#  '2D1Y3_2',
#  '2D1Y3_8',
#  '2D1Y3_22',
#  '2D1Y3_71',
#  '2D1Y3_87',
#  '2D1Y3_101',
#  '2D1Y3_106',
#  '2D1Y4_223',
#  '2D1Y3_118',
#  '2D1Y5_13',
#  '2D1Y5_35',
#  '2D1Y5_39',
#  '2D1Y4_216',
#  '2D1Y3_32',
#  '2D1Y3_39',
#  '2D1Y3_40',
#  '2D1Y3_41',
#  '2D1Y3_93',
#  '2D1Y3_121',
#  '2D1Y3_102',
#  '2D1Y4_199',
#  '2D1Y5_31',
#  '2D1Y3_73',
#  '2D1Y3_97',
#  '2D1Y3_110',
#  '2D1Y3_114',
#  '2D1Y3_119',
#  '2D1Y3_122',
#  '2D1Y5_9',
#  '2D1Y5_16',
#  '2D1Y5_25',
#  '2D1Y5_36',
#  '2D1Y5_49',
#  '2D1Y3_21',
#  '2D1Y3_30',
#  '2D1Y3_36',
#  '2D1Y3_49',
#  '2D1Y3_77',
#  '2D1Y3_91',
#  '2D1Y3_108',
#  '2D1Y3_111',
#  '2D1Y5_29',
#  '2D1Y4_221',
#  '2D1Y5_82',
#  '2D1Y3_103',
#  '2D1Y5_3',
#  '2D1Y5_77',
#  '2D1Y5_80',
#  '2D1Y5_93',
#  '2D1Y5_101',
#  '2D1Y5_67',
#  '2D1Y5_85',
#  '2D1Y5_111',
#  '2D1Y5_113',
#  '2D1Y5_124',
#  '2D1Y5_127',
#  '2D1Y5_63',
#  '2D1Y5_98',
#  '2D1Y5_125',
#  '2D1Y5_132',
#  '2D1Y5_81',
#  '2D1Y5_102',
#  '2D1Y5_103',
#  '2D1Y5_107',
#  '2D1Y5_120',
#  '2D1Y5_71',
#  '2D1Y5_91',
#  '2D1Y3_126',
#  '2D1Y5_104',
#  '2D1Y5_68',
#  '2D1Y5_17',
#  '2D1Y5_26',
#  '2D1Y5_30',
#  '2D1Y5_56',
#  '2D1Y5_95',
#  '2D1Y5_100',
#  '2D1Y5_106',
#  '2D1Y5_123',
#  '2D1Y5_69',
#  '2D1Y5_75',
#  '2D1Y5_73',
#  '2D1Y5_108',
#  '2D1Y5_126',
#  '2D1Y5_90',
#  '2D1Y5_117',
#  '2D1Y5_94',
#  '2D1Y5_65',
#  '2D1Y5_115',
#  '2D1Y5_121',
#  '2D1Y5_129',
#  '2D1Y5_87',
#  '2D4Y1_112',
#  '2D2Y3_106',
#  '2D2B6_236',
#  '2D3Y1_159',
#  '2D3Y1_188',
#  '2D3Y1_195',
#  '2D3Y1_230',
#  '2D3Y2_2',
#  '2D3Y2_23',
#  '2D3Y1_70',
#  '2D3Y1_97',
#  '2D3Y1_122',
#  '2D3Y1_156',
#  '2D3Y1_123',
#  '2D3Y1_167',
#  '2D3Y1_181',
#  '2D3Y1_193',
#  '2D3Y1_207',
#  '2D3Y1_210',
#  '2D3Y1_212',
#  '2D3Y1_217',
#  '2D3Y2_22',
#  '2D3Y1_40',
#  '2D3Y1_134',
#  '2D3Y1_67',
#  '2D3Y1_146',
#  '2D3Y1_57',
#  '2D3Y1_86',
#  '2D3Y1_102',
#  '2D3Y1_120',
#  '2D3Y1_124',
#  '2D3Y1_136',
#  '2D3Y1_141',
#  '2D3Y1_143',
#  '2D3Y1_175',
#  '2D3Y2_8',
#  '2D3Y1_137',
#  '2D3Y1_114',
#  '2D3Y1_147',
#  '2D3Y1_151',
#  '2D3Y1_192',
#  '2D3Y1_200',
#  '2D3Y1_228',
#  '2D3Y2_5',
#  '2D3Y1_53',
#  '2D3Y1_46',
#  '2D3Y1_54',
#  '2D3Y1_132',
#  '2D3Y1_85',
#  '2D3Y1_80',
#  '2D3Y1_109',
#  '2D3Y1_118',
#  '2D3Y1_164',
#  '2D3Y1_187',
#  '2D3Y1_213',
#  '2D3Y1_216',
#  '2D3Y1_289',
#  '2D3Y1_69',
#  '2D3Y1_98',
#  '2D3Y1_119',
#  '2D3Y1_103',
#  '2D3Y1_126',
#  '2D3Y1_161',
#  '2D3Y1_170',
#  '2D3Y1_182',
#  '2D3Y1_222',
#  '2D3Y1_45',
#  '2D3Y1_51',
#  '2D3Y1_110',
#  '2D3Y1_121',
#  '2D3Y1_125',
#  '2D3Y1_130',
#  '2D3Y1_82',
#  '2D3Y1_87',
#  '2D3Y1_75',
#  '2D3Y1_127',
#  '2D3Y1_128',
#  '2D3Y1_129',
#  '2D3Y1_184',
#  '2D3Y1_190',
#  '2D3Y1_218',
#  '2D3Y1_219',
#  '2D3Y1_221',
#  '2D3Y1_72',
#  '2D3Y1_79',
#  '2D3Y1_73',
#  '2D3Y1_112',
#  '2D3Y1_131',
#  '2D3Y1_178',
#  '2D3Y1_197',
#  '2D3Y1_204',
#  '2D3Y1_206',
#  '2D3Y1_231',
#  '2D3Y2_16',
#  '2D3Y1_52',
#  '2D3Y1_111',
#  '2D2Y3_139',
#  '2D3Y1_71',
#  '2D3Y1_64',
#  '2D3Y2_20',
#  '2D3Y2_31',
#  '2D3Y1_48',
#  '2D3Y1_44',
#  '2D3Y1_58',
#  '2D3Y1_50',
#  '2D3Y1_59',
#  '2D3Y1_56',
#  '2D3Y1_90',
#  '2D3Y2_6',
#  '2D3Y1_107',
#  '2D3Y1_84',
#  '2D3Y1_169',
#  '2D3Y1_105',
#  '2D3Y1_226',
#  '2D3Y1_155',
#  '2D3Y1_179',
#  '2D3Y2_3',
#  '2D3Y1_208',
#  '2D3Y2_18',
#  '2D3Y1_157',
#  '2D3Y1_244',
#  '2D3Y1_287',
#  '2D3Y1_225',
#  '2D2Y3_132',
#  '2D2Y3_144',
#  '2D2Y3_152',
#  '2D2Y3_88',
#  '2D2Y3_93',
#  '2D2Y3_101',
#  '2D2Y3_104',
#  '2D2Y3_105',
#  '2D2Y3_119',
#  '2D3Y1_241',
#  '2D2Y3_120',
#  '2D3Y1_94',
#  '2D3Y1_95',
#  '2D3Y1_96',
#  '2D3Y1_116',
#  '2D3Y1_153',
#  '2D3Y1_174',
#  '2D3Y1_176',
#  '2D3Y1_199',
#  '2D3Y1_209',
#  '2D2Y3_127',
#  '2D3Y1_65',
#  '2D3Y2_24',
#  '2D3Y1_61',
#  '2D3Y1_138',
#  '2D3Y1_166',
#  '2D3Y1_180',
#  '2D3Y1_183',
#  '2D3Y1_191',
#  '2D3Y1_201',
#  '2D3Y1_211',
#  '2D3Y2_15',
#  '2D3Y1_68',
#  '2D3Y1_133',
#  '2D3Y1_115',
#  '2D3Y1_186',
#  '2D3Y1_194',
#  '2D3Y1_203',
#  '2D3Y1_205',
#  '2D3Y1_38',
#  '2D3Y1_43',
#  '2D3Y1_42',
#  '2D3Y1_49',
#  '2D3Y1_62',
#  '2D3Y1_162',
#  '2D3Y2_17',
#  '2D3Y1_108',
#  '2D3Y1_36',
#  '2D3Y1_63',
#  '2D3Y1_91',
#  '2D3Y1_117',
#  '2D3Y1_148',
#  '2D3Y1_152',
#  '2D3Y1_160',
#  '2D3Y1_76',
#  '2D3Y1_173',
#  '2D3Y1_104',
#  '2D3Y1_66',
#  '2D3Y1_198',
#  '2D3Y1_202',
#  '2D3Y1_154',
#  '2D3Y1_229',
#  '2D3Y1_288',
#  '2H3F9_1015',
#  '2D3Y1_165',
#  '2D3Y1_189',
#  '2D3Y1_220',
#  '2D3Y1_35',
#  '2D3Y1_113',
#  '2D4Y1_123',
#  '2D4Y1_130',
#  '2D4Y1_145',
#  '2D2Y1_82',
#  '2D2Y2_1',
#  '2D2Y2_2',
#  '2D2Y2_3',
#  '2D2Y2_9',
#  '2D2Y2_15',
#  '2D2Y2_25',
#  '2D2Y2_41',
#  '2D2Y2_55',
#  '2D2Y1_66',
#  '2D2Y2_76',
#  '2D2Y3_9',
#  '2D2Y3_12',
#  '2D2Y3_29',
#  '2D2Y3_36',
#  '2D2Y3_38',
#  '2D2Y3_40',
#  '2D2Y3_51',
#  '2D2Y3_61',
#  '2D2Y3_77',
#  '2D2Y2_81',
#  '2D2Y3_78',
#  '2D2Y1_56',
#  '2D2Y3_65',
#  '2D2Y2_39',
#  '2D2Y2_42',
#  '2D2Y2_54',
#  '2D2Y2_65',
#  '2D2Y2_67',
#  '2D2Y3_4',
#  '2D2Y3_35',
#  '2D2Y3_74',
#  '2D2Y1_41',
#  '2D2Y1_47',
#  '2D2Y1_50',
#  '2D2Y1_61',
#  '2D2Y2_32',
#  '2D2Y2_56',
#  '2D2Y2_57',
#  '2D2Y3_7',
#  '2D2Y3_8',
#  '2D2Y3_31',
#  '2D2Y3_46',
#  '2D2Y3_54',
#  '2D2Y1_52',
#  '2D2Y2_38',
#  '2D2Y3_82',
#  '2D2Y1_78',
#  '2D2Y3_24',
#  '2D2Y3_26',
#  '2D2Y3_67',
#  '2D2Y1_84',
#  '2D2Y1_86',
#  '2D2Y2_8',
#  '2D2Y2_30',
#  '2D2Y2_79',
#  '2D2Y3_44',
#  '2D2Y3_14',
#  '2D2Y3_70',
#  '2D2Y1_76',
#  '2D2Y2_12',
#  '2D2Y2_43',
#  '2D2Y2_58',
#  '2D2Y2_61',
#  '2D2Y3_37',
#  '2D2Y3_52',
#  '2D2Y2_7',
#  '2D2Y2_18',
#  '2D2Y1_83',
#  '2D2Y1_43',
#  '2D2Y2_80',
#  '2D2Y2_60',
#  '2D2Y2_11',
#  '2D2Y2_34',
#  '2D2Y2_45',
#  '2D2Y2_47',
#  '2D2Y2_69',
#  '2D2Y3_3',
#  '2D2Y3_42',
#  '2D2Y3_57',
#  '2D2Y3_62',
#  '2D2Y2_68',
#  '2D2Y3_68',
#  '2D2Y3_79',
#  '2D2Y3_83',
#  '2D2Y1_42',
#  '2D2Y1_70',
#  '2D2Y1_60',
#  '2D2Y2_17',
#  '2D2Y2_21',
#  '2D2Y2_48',
#  '2D2Y2_49',
#  '2D2Y3_73',
#  '2D2Y2_26',
#  '2D2Y2_29',
#  '2D2Y2_23',
#  '2H1Y3_313',
#  '2H2Y1_23',
#  '2H2Y1_27',
#  '2D2Y1_15',
#  '2D2Y1_21',
#  '2D2Y1_29',
#  '2D2Y1_34',
#  '2D2Y1_38',
#  '2D2Y1_4',
#  '2H1Y3_290',
#  '2D2Y1_9',
#  '2D2Y1_10',
#  '2D2Y1_36',
#  '2D2Y1_26',
#  '2D2Y1_33',
#  '2D2Y1_6',
#  '2D2Y1_11',
#  '2D2Y1_12',
#  '2D2Y1_22',
#  '2D2Y1_30',
#  '2D2Y1_24',
#  '2D2Y1_1',
#  '2H1Y3_283',
#  '2H1Y3_239',
#  '2H1Y3_308',
#  '2H1Y3_378',
#  '2H2Y1_2',
#  '2H1Y3_18',
#  '2H1Y3_31',
#  '2H1Y3_43',
#  '2H1Y3_45',
#  '2H1Y3_94',
#  '2H1Y3_113',
#  '2H1Y3_255',
#  '2H1Y3_119',
#  '2H1Y3_131',
#  '2H1Y3_144',
#  '2H1Y3_145',
#  '2H1Y3_159',
#  '2H1Y3_162',
#  '2H1Y3_169',
#  '2H1Y3_207',
#  '2H1Y3_229',
#  '2H1Y3_233',
#  '2H1Y3_123',
#  '2D2Y2_28',
#  '2D2Y1_17',
#  '2D2Y1_32',
#  '2D2Y2_53',
#  '2D2Y2_62',
#  '2D2Y3_25',
#  '2D2Y3_28',
#  '2D2Y3_69',
#  '2D2Y3_75',
#  '2D2Y3_85',
#  '2D2Y1_45',
#  '2D2Y1_46',
#  '2D2Y2_51',
#  '2D2Y2_4',
#  '2D2Y3_13',
#  '2D2Y3_23',
#  '2D2Y3_39',
#  '2D2Y3_45',
#  '2D2Y3_53',
#  '2D2Y3_81',
#  '2D2Y3_84',
#  '2D2Y1_48',
#  '2D2Y2_13',
#  '2D2Y2_73',
#  '2D2Y1_20',
#  '2D2Y2_36',
#  '2D2Y3_55',
#  '2D2Y1_23',
#  '2D2Y1_27',
#  '2D2Y1_25',
#  '2D2Y1_16',
#  '2D2Y1_19',
#  '2D2Y1_31',
#  '2D2Y1_7',
#  '2D2Y1_18',
#  '2D2Y1_3',
#  '2D2Y2_33',
#  '2D2Y1_35',
#  '2D2Y1_49',
#  '2D2Y1_65',
#  '2D2Y1_85',
#  '2D2Y2_37',
#  '2D2Y2_50',
#  '2D2Y2_63',
#  '2D2Y2_66',
#  '2D2Y2_78',
#  '2D2Y3_34',
#  '2D2Y1_39',
#  '2H1Y3_303',
#  '2D2Y2_64',
#  '2D2Y2_71',
#  '2H1Y1_105',
#  '2H1Y1_109',
#  '2H1Y1_115',
#  '2H1Y1_118',
#  '2H1Y1_14',
#  '2H1Y1_32',
#  '2H1Y1_75',
#  '2H1Y1_99',
#  '2H1Y1_102',
#  '2H1Y1_91',
#  '2H1Y1_106',
#  '2H1Y1_50',
#  '2H1Y1_59',
#  '2H1Y1_61',
#  '2H1Y1_64',
#  '2H1Y1_78',
#  '2H1Y1_12',
#  '2H1Y1_38',
#  '2H1Y1_57',
#  '2H1Y1_73',
#  '2H1Y1_35',
#  '2H1Y1_85',
#  '2H1Y1_84',
#  '2H1Y1_52',
#  '2H1Y1_8',
#  '2H1Y1_23',
#  '2H1Y1_24',
#  '2H1Y1_30',
#  '2H1Y1_33',
#  '2H1Y1_93',
#  '2H1Y1_97',
#  '2H1Y1_98',
#  '2H1Y1_107',
#  '2H1Y1_70',
#  '2H1Y1_6',
#  '2H1Y1_86',
#  '2H1Y1_2',
#  '2H1Y1_10',
#  '2H1Y1_13',
#  '2H1Y1_18',
#  ...]

# %%
client = MongoClient('mongodb://tuan.nva:data-tuan.nva@mongo.data-advising.net:27017/?authSource=QuestionDB_dev&authMechanism=SCRAM-SHA-256&readPreference=primary&appname=MongoDB%20Compass&directConnection=true&ssl=false')
db = client['Service_Exam_dev']
coll = db['questions']

# %%
def preprocessing(question) -> dict:
    bar = dict(code=question['code'])
    bar['text'] = ' '.join([foo['content'] for foo in question['question_contents'] if foo['variety'] == 'TEXT'])
    return bar

# %%
list_questions = list(coll.find({'code': {'$in': code}}, {'_id': 0, 'code': 1, 'question_contents': 1}))

# %%
# %%time

with cf.ThreadPoolExecutor() as executor:
    preprocessed = list(executor.map(preprocessing, list_questions))
# Out:
# Wall time: 1.59 s

# %%
preprocessed
# Out:
# [{'code': '2D1X5_59',
#   'text': 'Biết hàm số $y=ax^4+bx^2+c$ có đồ thị như hình vẽ bên. Mệnh đề nào dưới đây là đúng?'},
#  {'code': '2D1X5_60',
#   'text': 'Hãy xác định các số thực $a$ và $b$ để hàm số $y=\\dfrac{ax+2}{x+b}$ có đồ thị như hình vẽ bên.'},
#  {'code': '2D1X5_68',
#   'text': 'Đường cong ở hình bên là đồ thị của hàm số nào trong các hàm số sau?'},
#  {'code': '2D1X5_70',
#   'text': 'Cho hàm số $y=\\dfrac{ax+b}{cx+d}$ có đồ thị như hình vẽ bên. Mệnh đề nào sau đây đúng?'},
#  {'code': '2D1X5_76',
#   'text': 'Đồ thị sau là đồ thị của hàm số được cho trong 4 đáp án A, B, C, D dưới đây. Đó là hàm số nào?'},
#  {'code': '2D1X5_86', 'text': 'Đồ thị bên là của hàm số nào?'},
#  {'code': '2D1X5_106', 'text': 'Đồ thị nào có đúng một điểm cực trị?'},
#  {'code': '2D1X5_119',
#   'text': 'Cho hàm số $y=f\\left( x \\right)$ có bảng biến thiên như sau. Dựa vào bảng biến thiên, tìm mệnh đề đúng trong các mệnh đề sau đây.'},
#  {'code': '2D1X5_138',
#   'text': 'Cho hàm số $y=f\\left(x\\right)$ có bảng biến thiên như hình vẽ. Khẳng định nào sau đây là đúng?'},
#  {'code': '2D1X5_140',
#   'text': 'Cho hàm số $y=f(x)$ xác định trên $\\mathbb{R}\\backslash\\{2\\}$, liên tục trên mỗi khoảng xác định và có bảng biến thiên sau. Khẳng định nào dưới đây là khẳng định $\\textbf{sai}$?'},
#  {'code': '2D1X5_144',
#   'text': 'Cho hàm số $y=f(x)$ liên tục trên $\\mathbb{R}$ và có bảng biến thiên như sau. Tập hợp tất cả các giá trị thực của tham số $m$ để phương trình $|f(x)+2 | =m $\ncó bốn nghiệm thực phân biệt là'},
#  {'code': '2D1X5_155', 'text': 'Hình vẽ bên là đồ thị hàm số nào?'},
#  {'code': '2D1X5_158',
#   'text': ' $\\\\$Cho hàm số $y=ax^3+bx^2+cx+d \\,(a\\ne 0)$ có đồ thị như hình vẽ bên. Khẳng định nào sau đây là đúng?'},
#  {'code': '2D1X5_181',
#   'text': 'Cho hàm số $y=f(x)$ có bảng biến thiên như hình vẽ. Khẳng định nào dưới đây đúng?'},
#  {'code': '2D3X3_3',
#   'text': 'Tính diện tích tam giác được gới hạn bởi các trục tọa độ và tiếp tuyến của đồ thị $y=\\ln x$ tại giao điểm của đồ thị hàm số với trục $Ox$.'},
#  {'code': '2D3X3_10',
#   'text': 'Tính diện tích hình phẳng giới hạn bởi đồ thị các hàm số $y=x^3$, $y=x^5$.'},
#  {'code': '2D3X3_13',
#   'text': 'Tính diện tích $S$ của hình phẳng giới hạn bởi các đường $y=1, y=\\dfrac{1}{9}(6x^2-x^4).$'},
#  {'code': '2D3X3_59',
#   'text': 'Cho hàm số $y=f(x)$ liên tục trên đoạn $[a;b], (a, b \\in \\mathbb R, a<b)$. Gọi $S$ là diện tích hình phẳng giới hạn bởi các đường $y=f(x), y=0, x=a, x=b$. Mệnh đề nào sau đây là đúng?'},
#  {'code': '2D3X3_64',
#   'text': 'Cho  hàm số $y = f(x)$ liên tục trên đoạn $\\big[a,b\\big]$. Công thức tính diện tích hình phẳng giới hạn bởi đồ thị hàm số $y = f(x)$, $x = a$, $x = b$ và trục $Ox$ là'},
#  {'code': '2D3X3_86',
#   'text': 'Ký hiệu $S$ là diện tích của hình phẳng giới hạn bởi các đường $y=x\\sin x$, $y=0$, $x=0$, $x=\\pi$. Trong các khẳng định sau, khẳng định nào đúng?'},
#  {'code': '2D3X3_88',
#   'text': 'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị của các hàm số $y=x^2-x+3$ và $y=2x+1$.'},
#  {'code': '2D1X5_72',
#   'text': 'Cho hàm số $y=\\dfrac{ax+b}{x+c}$ có đồ thị như hình vẽ bên. Tính giá trị của $S=a+2b+c$.'},
#  {'code': '2D1X5_73',
#   'text': 'Trong các hình vẽ sau, hình nào biểu diễn đồ thị của hàm số $y=\\dfrac{x+1}{-x+1}$?'},
#  {'code': '2D1X5_89',
#   'text': 'Cho hàm số $y=\\dfrac{x+1}{x-1}$. Mệnh đề nào dưới đây là mệnh đề $\\textbf{sai}$?'},
#  {'code': '2D1X5_99',
#   'text': 'Cho hàm số $y=f(x)$ có đồ thị như hình bên. Khẳng định nào sau đây là khẳng định $\\textbf{sai}$? '},
#  {'code': '2D1X5_112',
#   'text': 'Cho hàm số $y=ax^4+bx^2+c$ có đồ thị như hình bên. Trong các mệnh đề sau, mệnh đề nào $\\textbf{đúng}$?'},
#  {'code': '2D1X5_161',
#   'text': 'Cho hàm số có bảng biến thiên dạng như sau. Hãy chọn khẳng định đúng.\n'},
#  {'code': '2D1X5_177',
#   'text': "Cho hàm số  $y=f(x)$  liên tục trên khoảng  $(-3;4)$  và có đạo hàm  $f'(x)$  cũng liên tục trên \n$(-3;4).$  Đồ thị của hàm số $f'(x)$  trên khoảng  $(-3;4)$ được cho bởi hình vẽ bên. Trong các mệnh đề sau, mệnh đề nào $\\textbf{đúng}$?"},
#  {'code': '2D1X5_191',
#   'text': 'Đồ thị hàm số trong hình bên là đồ thị của một trong bốn hàm số được nêu trong bốn đáp án $A$, $B$, $C$, $D$. Đồ thị đó là của hàm số nào?'},
#  {'code': '2D3X3_4',
#   'text': "Diện tích hình phẳng giới hạn bởi đồ thị \\((C)\\) của hàm số \\(y=-2x^3+x^2+x+5\\) và đồ thị \\((C')\\) của hàm số \\(y=x^2-x+5\\) bằng"},
#  {'code': '2D3X3_8',
#   'text': 'Tính diện tích hình phẳng giới hạn bởi đường thẳng $y=2x+1$ và đồ thị hàm số $y=x^2-x+3$.'},
#  {'code': '2D3X3_15',
#   'text': 'Viết công thức tích diện tích hình phẳng giới hạn bởi đồ thị hàm số $y=x^2-1$, trục hoành và hai đường thẳng $x=0,x=2$.'},
#  {'code': '2D3X3_21',
#   'text': 'Gọi $S$ là diện tích của hình phẳng giới hạn bởi các đồ thị hàm số $y=x^2+3$ và $y=4x$. Xác định mệnh đề đúng?'},
#  {'code': '2D3X3_70',
#   'text': 'Cho hàm số $f(x)$ xác định và đồng biến trên $\\big[0; 1\\big]$ và $f\\big(\\dfrac{1}{2}\\big) = 1$. Xác định công thức diện tích hình phẳng được giới hạn bởi các hàm số $y = f(x)$; $y = \\big(f(x)\\big)^2$, $x = 0$ và $x = 1$?'},
#  {'code': '2D3X3_99',
#   'text': 'Gọi $S$ là diện tích hình phẳng giới hạn bởi $y=x^3,y=2-x$ và $y=0.$ $S$ được tính theo công thức nào dưới đây?'},
#  {'code': '2D1X5_61',
#   'text': 'Cho hàm số $y=ax^3+bx^2+cx+d$ có đồ thị như hình bên. Mệnh đề nào sau đây $\\textbf{đúng}$?'},
#  {'code': '2D1X5_97',
#   'text': "Biết hàm số $f\\left( x \\right)$ có đạo hàm $f'\\left( x \\right)$ liên tục trên $\\mathbb{K}$ và $f'\\left(x\\right)$ có đồ thị là đường cong như hình vẽ bên. Tìm số điểm cực trị của đồ thị hàm số $f\\left(x\\right)$."},
#  {'code': '2D1X5_96',
#   'text': 'Cho hàm số $y=f\\left(x\\right)$ xác định trên $\\mathbb{R}\\backslash \\left\\{-1\\right\\},$ liên tục trên mỗi khoảng xác định và có bảng biến thiên như sau Khẳng định nào dưới đây $\\textbf{sai}$?'},
#  {'code': '2D1X5_139',
#   'text': 'Cho hàm số $y=x^3-3x+1$ có đồ thị là (C). Kết luận nào sau đây là $\\textbf{đúng}$?'},
#  {'code': '2D1X5_142',
#   'text': 'Cho đồ thị hàm số $y=f(x)$  như hình vẽ  bên. Đồ \nthị  trong  phương  án  nào  sau  đây  là  đồ  thị  hàm  số \n$y=\\left|f(x)\\right|$ ? }\\providecommand*{\\HA }\n\\providecommand*{\\HB }\n\\providecommand*{\\HC }\n\\providecommand*{\\HD'},
#  {'code': '2D1X5_171',
#   'text': 'Cho hàm số $y=f(x)$ có bảng biến thiên như hình bên. Mệnh đề nào sau đây đúng?'},
#  {'code': '2D1X5_176',
#   'text': 'Cho hàm số $y=ax^4-bx^2+c$ có đồ thị như hình vẽ. Khẳng định nào sau đây $\\textbf{đúng}$?'},
#  {'code': '2D1X5_178',
#   'text': 'Cho hàm số $y=f(x)$ có bảng biến thiên như hình bên dưới đây. Hỏi đồ thị hàm số $y=f(x)$ có bao nhiêu đường tiệm cận?'},
#  {'code': '2D1X5_180',
#   'text': 'Cho hàm số $y=\\dfrac{x+2}{x-1}$ có đồ thị như hình vẽ. Hình vẽ nào dưới đây  là đồ thị của hàm số $y=\\dfrac{|x|+2}{|x|-1}$?  $\\textbf{Hình 1}$ $\\textbf{Hình 2}$ $\\textbf{Hình 3}$ $\\textbf{Hình 4}$'},
#  {'code': '2D1X5_184',
#   'text': 'Cho hàm số $f(x)$ có bảng biến thiên như hình vẽ.  Khẳng định nào dưới đây đúng?'},
#  {'code': '2D3X3_9',
#   'text': 'Gọi $S$ là diện tích hình phẳng giới hạn bởi đồ thị hàm số $y=f(x),$ trục $Ox,$ hai đường thẳng $x = a, x = b.$ Chọn đáp án $\\textbf{đúng}$.'},
#  {'code': '2D3X3_38',
#   'text': 'Tính diện tích $S$ của hình phẳng giới hạn bởi các đường  $y=x^2$, $y=2x^2-2x.$'},
#  {'code': '2D3X3_58',
#   'text': 'Cho các hàm số $y=f(x), y= g(x)$ liên tục trên đoạn $[a;b], (a,b \\in \\mathbb R, a < b)$. Gọi $S$ là diện tích hình phẳng giới hạn bởi các đường $y=f(x), y =g(x), x=a, x=b$. Mệnh đề nào sau đây là đúng?'},
#  {'code': '2D3X3_66',
#   'text': 'Cho hình phẳng $(H)$ giới hạn bởi $(P): y = 2x^2 + 4x + 3$ và các tiếp tuyến với $(P)$ đi qua điểm $A\\big(- 3; -23\\big)$. Tính diện tích $S$ của hình phẳng $(H)$.'},
#  {'code': '2D3X3_69',
#   'text': 'Tính diện tích hình phẳng giới hạn bởi các đồ thị của hàm số $y = 2 - \\vert x\\vert$ và $y = x^2$.'},
#  {'code': '2D3X3_74',
#   'text': 'Diện tích hình phẳng giới hạn bởi các đường $y=x^2-x,$ $y=0,$ $x=0$ và $x=2$ được tính bởi công thức'},
#  {'code': '2D3X3_76',
#   'text': 'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị hàm số $y=x^2+1$, trục hoành và các đường thẳng $x=-1,x=2$.'},
#  {'code': '2D3X3_81',
#   'text': 'Cho hàm số $ y=f(x) $ liên tục trên $ \\mathbb{R} $ và hàm số $ y=g(x)=x.f(x^2) $ có đồ thị trên đoạn $ [0;2] $ như hình vẽ bên. Biết diện tích miền được gạch chéo là $ S=\\dfrac{5}{2} $, tính tích phân $ \\displaystyle I=\\int_{1}^{4}f(x)\\,\\mathrm{d}x $. '},
#  {'code': '2D3X3_84',
#   'text': 'Với giá trị nào của $m$ thì diện tích hình phẳng được giới hạn bởi đồ thị hàm số $y = x^4 + 2mx^2 + m^2$ và các đường thẳng $y = 0$, $x = 0$, $x = 1$ là $\\dfrac{28}{15}$?'},
#  {'code': '2D1X5_150',
#   'text': 'Cho hàm số $y=ax^4+bx^2+c$ có đồ thị như hình dưới đây. Chọn đáp án đúng. '},
#  {'code': '2D1X5_163',
#   'text': 'Đường cong trong hình bên là đồ thị của một hàm số nào dưới đây.'},
#  {'code': '2D1X5_175',
#   'text': 'Cho bảng biến thiên của hàm số $y=f(x)$ trên nửa khoảng  $(-3;2]$  như hình vẽ bên. \nKhẳng định nào dưới đây $\\textbf{sai}$?'},
#  {'code': '2D3X3_35',
#   'text': 'Tính diện tích $S$ của phần hình phẳng giới hạn bởi đường parabol đi qua gốc tọa độ và hai đoạn thẳng $AC$ và $BC$ như hình vẽ bên.$\\\\$\n'},
#  {'code': '2D3X3_45',
#   'text': 'Diện tích hình phẳng giới hạn bởi đồ thị hàm số $y=4-x^2$ và $y=x+2$ là'},
#  {'code': '2D3X3_50',
#   'text': 'Tính diện tích $S$ của hình phẳng được tô đậm trong hình vẽ bên.'},
#  {'code': '2D3X3_65',
#   'text': 'Tính diện tích hình phẳng giới hạn bởi đồ thị hàm số $y = x^2  - 3x + 2$, đường thẳng $x = 0$, $x = 3$ và trục $Ox$.'},
#  {'code': '2D3X3_72',
#   'text': "Cho hàm số $f(x)$ liên tục trên $\\mathbb{R}.$ Đồ thị của hàm số $y=f'(x)$ được cho như hình vẽ bên. Diện tích các hình phẳng $(K),$ $(H)$ lần lượt là $\\dfrac{5}{12}$ và $\\dfrac{8}{3}.$ Biết $f(-1)=\\dfrac{19}{12},$ tính $f(2).$"},
#  {'code': '2D3X3_73',
#   'text': 'Cho $(C)$ là cung của đường cong $y=-x^3+x$ với $x\\in \\left[0; 1\\right].$ Tìm tất cả các giá trị thực của tham số $k$ để đường thẳng $d: y=(k-2)x$ chia hình phẳng giới hạn bởi cung $(C)$ và trục hoành $Ox$ thành hai phần có diện tích bằng nhau.'},
#  {'code': '2D3X3_90',
#   'text': 'Cho đồ thị hàm số $y=x^3$ trên đoạn $\\left[0;1 \\right]$ và một số thực $t\\in \\left[0;1 \\right]$. Gọi $S_1$ là diện tích hình phẳng giới hạn bởi các đường $y=x^3, y=t^3,x=0$ và $S_2$ là diện tích hình phẳng giới hạn bởi các đường $y=x^3, y=t^3,x=1.$ Gọi $m, M$ lần lượt là giá trị nhỏ nhất, giá trị lớn nhất của $S_1 + S_2$. Tính $2M+16m.$'},
#  {'code': '2D3X3_95',
#   'text': 'Tính diện tích $S$ của hình phẳng giới hạn bởi hai đường $y^2-3x+2=0$ và $x^2-3y+2=0$.'},
#  {'code': '2D1X5_62',
#   'text': 'Cho hàm số $y=\\dfrac{2x+3}{x+2}$ có đồ thị $(C).$ Gọi $M, N$ là hai điểm thuộc hai nhánh khác nhau của $(C).$ Tìm giá trị nhỏ nhất của độ dài đoạn thẳng $MN.$'},
#  {'code': '2D1X5_65',
#   'text': 'Cho hàm số $y=\\dfrac{x+b}{cx+d}$ có đồ thị như hình vẽ. Khẳng định nào dưới đây đúng?'},
#  {'code': '2D1X5_80',
#   'text': 'Tìm tất cả các giá trị của $m$ để bất phương trình $x^3+3x^2+1-m\\ge 0$ nghiệm đúng với $\\forall x\\in [-1; 1]$.'},
#  {'code': '2D1X5_95',
#   'text': 'Đồ thị trong hình vẽ bên là đồ thị của hàm số nào trong các hàm số dưới đây?'},
#  {'code': '2D1X5_100',
#   'text': 'Cho đồ thị hàm số bậc $4$ trùng phương $y=ax^4+bx^2+c$ có đồ thị như hình bên dưới. Dấu của các hệ số $a$, $b$, $c$ là'},
#  {'code': '2D1X5_104',
#   'text': 'Bảng biến thiên ở hình bên là của hàm số nào sau đây?'},
#  {'code': '2D1X5_130',
#   'text': 'Cho hàm số $y=f(x)$ xác định, liên tục trên $\\mathbb{R}$ và có bảng biến thiên như sau: Mệnh đề nào dưới đây đúng?'},
#  {'code': '2D3X3_5',
#   'text': 'Cho các hàm số \\(y=f(x)\\) và \\(y=g(x)\\) liên tục trên \\([a;b]\\). Công thức tính diện tích \\(S\\) của hình thang cong giới hạn bởi $2$ đồ thị hàm số trên và các đường thẳng \\(x=a\\), \\(x=b\\) là'},
#  {'code': '2D3X3_6',
#   'text': 'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị hàm số $y=x^2+2x+3$, trục $Ox$ và các đường thẳng $x=-2$, $x=1$.'},
#  {'code': '2D3X3_17',
#   'text': 'Gọi $S$ là số đo diện tích của hình phẳng giới hạn bởi hai đồ thị hàm số $y=2{{x}^{2}}+3x+1$, $y={{x}^{2}}-x-2$. Tính $\\cos \\left( \\dfrac{\\pi }{S} \\right)$.'},
#  {'code': '2D3X3_24',
#   'text': 'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị hàm số $y=\\ln x$, trục hoành và hai đường thẳng $x=1$, $x=25$.'},
#  {'code': '2D3X3_68',
#   'text': 'Tính diện tích hình phẳng giới hạn bởi đồ thị của hàm số $y = x^3 - 3x^2 + x + 1$ và đường thẳng $y = x - 3$.'},
#  {'code': '2D3X3_78',
#   'text': 'Cho hình phẳng $(H)$ giới hạn bởi các đường $y=x^2$, $y=0$, $x=0$, $x=4$. Đường thẳng $y=k \\ (0<k<16)$ chia hình $(H)$ thành hai phần có diện tích $S_1$, $S_2$ (hình vẽ). Tìm $k$ để $S_1 = S_2$.'},
#  {'code': '2D3X3_101',
#   'text': 'Tính diện tích hình phẳng $S$ giới hạn bởi đồ thị của các hàm số $y=x^2,$ $y=\\dfrac{x^2}{27},$ $y=\\dfrac{27}{x}$.'},
#  {'code': '2D1X5_66',
#   'text': 'Hình vẽ bên là đồ thị của một trong bốn hàm số được liệt kê ở các phương án A, B, C, D dưới đây. Hàm số đó là hàm số nào? '},
#  {'code': '2D1X5_71',
#   'text': 'Đường cong trong hình bên là đồ thị của một hàm số trong bốn hàm số được liệt kê ở bốn phương án A, B, C, D dưới đây. Hỏi hàm số đó là hàm số nào?'},
#  {'code': '2D1X5_87',
#   'text': 'Hàm số $y=ax^4+bx^2+c \\ (a\\neq 0)$ có đồ thị như hình bên. Xác định dấu của $a,b,c$.'},
#  {'code': '2D1X5_91', 'text': 'Đồ thị sau đây là của hàm số nào?'},
#  {'code': '2D1X5_98',
#   'text': 'Hàm số nào trong các hàm số cho dưới đây có đồ thị là hình vẽ bên?'},
#  {'code': '2D1X5_136',
#   'text': 'Cho hàm số $y=f(x)$ liên tục trên $\\mathbb{R}\\setminus\\{0\\}$ và có bảng biến thiên như hình dưới Khẳng định nào sau đây $\\textbf{đúng}$?'},
#  {'code': '2D1X5_183',
#   'text': 'Cho hàm số $y=ax^3+bx^2+cx+d$ có đồ thị như hình vẽ. Khẳng định nào dưới đây đúng?'},
#  {'code': '2D3X3_1',
#   'text': 'Cho hình phẳng $\\mathcal D$ giới hạn bởi đường cong $y=\\sqrt{2+\\sin x}$, trục hoành và các đường thẳng $x=0$, $x=\\pi$. Khối tròn xoay tạo thành khi quay $\\mathcal{D}$ quanh trục hoành có thể tích $V$ bằng bao nhiêu?'},
#  {'code': '2D3X3_14',
#   'text': 'Cho parabol $\\left(P\\right):y=x^{2}+1$ và đường thẳng $\\left(d\\right):y=mx+1$ ($m$ không âm). Giá trị $m$ thuộc khoảng nào sau đây để diện tích hình phẳng giới hạn bởi $\\left(P\\right)$ và $\\left(d\\right)$ bằng $36$ (đơn vị diện tích).'},
#  {'code': '2D3X3_18',
#   'text': 'Tính diện tích hình phẳng giới hạn bởi các đồ thị các hàm số $y=\\sin x, y=x-\\pi$ và đường thẳng $x=0$.'},
#  {'code': '2D3X3_53',
#   'text': 'Tính diện tích hình phẳng giới hạn bởi parabol $y=x^2$ và các đường thẳng $y=1,x=0,x=2.$'},
#  {'code': '2D3X3_63',
#   'text': 'Parabol $(P): y=2x$ chia hình phẳng giới hạn bởi đường tròn $x^2+y^2=8$ thành hai phần: phần bên trong $(P)$ có diện tích $S_1$, phần còn lại có diện tích $S_2$ (xem hình vẽ bên). Tính tỉ số $k=\\dfrac{S_1}{S_2}$ (làm tròn đến hàng phần trăm).'},
#  {'code': '2D1X5_55',
#   'text': 'Cho hàm số $y=f(x)$ xác định trên $\\mathbb{R}\\setminus\\{-2\\},$ liên tục trên mỗi khoảng xác định và có bảng biến thiên như sau. Khẳng định nào dưới đây $\\textbf{sai}$?'},
#  {'code': '2D1X5_63',
#   'text': 'Đường cong trong hình vẽ là đồ thị của một hàm số trong bốn hàm số được liệt kê ở các phương án $\\textbf{A, B, C, D}$. Hỏi hàm số đó là hàm số nào?'},
#  {'code': '2D1X5_58', 'text': 'Đồ thị ở hình bên là đồ thị của hàm số nào?'},
#  {'code': '2D1X5_108',
#   'text': "Cho đồ thị của ba hàm số $y=f(x)$, $y=f'(x)$, $y=f''(x)$ được mô tả bằng hình vẽ bên. Hỏi đồ thị của các hàm số $y=f(x)$, $y=f'(x)$ và $y=f''(x)$ theo thứ tự, lần lượt tương ứng với đường cong nào?"},
#  {'code': '2D1X5_115',
#   'text': 'Tính tổng các hoành độ của  những  điểm thuộc đồ thị hàm số  $(C): y=x^3-3x^2+2$ cách đều  hai điểm $A(12;1)$ và  $B(-6;3)$.'},
#  {'code': '2D1X5_162',
#   'text': 'Trong các hàm số được cho ở các phương án $\\textbf{A}$, $\\textbf{B}$, $\\textbf{C}$, $\\textbf{D}$, hàm số nào có đồ thị được cho như hình vẽ?'},
#  {'code': '2D1X5_169',
#   'text': 'Cho hàm số $y=f(x)$ xác định trên $\\mathbb{R}\\setminus \\{1\\}$, liên tục trên mỗi khoảng xác định và có bảng biến thiên như bên dưới. Tìm tập hợp tất cả các giá trị thực của tham số $m$ sao cho phương trình $f(x)=m$ có nghiệm duy nhất.'},
#  {'code': '2D1X5_170',
#   'text': 'Đường cong trong hình vẽ bên là đồ thị của một trong bốn hàm số được liệt kê ở bốn phương án $\\textbf{A, B, C, D}$ dưới đây. Hỏi hàm số đó là hàm số nào?'},
#  {'code': '2D1X5_173',
#   'text': 'Đường cong trong hình bên là đồ thị của hàm số được liệt kê trong bốn phương án $\\textbf{A, B, C, D}$ dưới đây. Hỏi hàm số đó là hàm số nào?'},
#  {'code': '2D1X5_185',
#   'text': 'Cho hàm số $y=ax^4+bx^2 +c$ có đồ thị như hình vẽ. Khẳng định nào dưới đây đúng?'},
#  {'code': '2D1X5_190',
#   'text': 'Cho hàm số $f(x)$ có bảng biến thiên như bảng dưới đây. Trong các khẳng định sau, khẳng định nào đúng?'},
#  {'code': '2D3X3_7',
#   'text': 'Diện tích hình phẳng giới hạn bởi hai đồ thị hàm số $y=x^2-x+1$, $y=x+1$ là'},
#  {'code': '2D3X3_27',
#   'text': 'Diện tích hình phẳng giới hạn bởi các đường $y=mx\\cos x$, $Ox$, $x=0$, $x=\\pi$ bằng $3\\pi$. Khi đó, giá trị của $m$ là'},
#  {'code': '2D3X3_36',
#   'text': 'Tính diện tích $S$ của hình phẳng giới hạn bởi hai đường cong $y=x^3-x$ và $y=x-x^2.$'},
#  {'code': '2D3X3_44',
#   'text': 'Tính diện tích hình phẳng  giới hạn bởi  các  đường \\ $y=2^x,$ $y=3-x$  và  $x=0$.'},
#  {'code': '2D3X3_49',
#   'text': 'Cho $(H)$ là hình phẳng giới hạn bởi đồ thị ${\\displaystyle (C): y = 4x - x^2}$ và trục hoành ở hình vẽ bên. Đường thẳng $y = m$ chia $(H)$ thành hai phần có diện tích bằng nhau. Biết $m = a + \\sqrt[3]{b}$ với $a$, $b$ là các số hữu tỉ, tính $S = a\\cdot b$.'},
#  {'code': '2D3X3_51',
#   'text': 'Tính diện tích hình phẳng giới hạn bởi đồ thị của hàm số $y=x^2+1$ và đường thẳng $y=x+3$.'},
#  {'code': '2D3X3_85',
#   'text': 'Cho hàm số $y = \\dfrac{1}{3}x^3 + mx^2 - 2x - 2m - \\dfrac{1}{3}$, ($m$ là tham số) có đồ thị là $(C)$. Có tất cả bao nhiêu giá trị của $m \\in \\left(0; \\dfrac{5}{6}\\right)$ để hình phẳng giới hạn bởi đồ thị $(C)$ và các đường thẳng $x = 0,$ $x = 2,$ $y = 0$ có diện tích bằng $4$?'},
#  {'code': '2D3X3_98',
#   'text': 'Tính diện tích hình phẳng giới hạn bởi đồ thị hàm số $y=x^3$, trục hoành và các đường thẳng $x=-1,x=2.$'},
#  {'code': '2D3X3_103',
#   'text': 'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị các hàm số $y=x^{2}-2x+3$ và $y=3$.'},
#  {'code': '2D1X5_113',
#   'text': "Cho hàm số $y=f(x)$ xác định và có đạo hàm $f'(x).$ Đồ thị của hàm số $f'(x)$ như hình bên. Khẳng định nào sau đây là $\\textbf{đúng}$?"},
#  {'code': '2D1X5_127',
#   'text': 'Đồ thị hàm số $y = \\dfrac{x+1}{-x+1}$ có dạng nào trong các dạng sau đây?'},
#  {'code': '2D1X5_148',
#   'text': 'Hàm số  $y=ax^3+bx+c$ có  đồ thị như hình vẽ bên. Tìm giá trị của  $a,b,c$.'},
#  {'code': '2D1X5_172',
#   'text': 'Cho hàm số $y=f(x)$ có bảng biến thiên như hình bên. Tìm tập hợp tất cả các giá trị thực của tham số $m$ để phương trình $f(x)=m$ có ba nghiệm thực phân biệt.'},
#  {'code': '2D1X5_186',
#   'text': 'Đường cong trong hình vẽ là đồ thị của một trong bốn hàm số được liệt kê ở bốn phương án $A$, $B$, $C$, $D$ dưới đây. Hỏi hàm số đó là hàm số nào?'},
#  {'code': '2D3X3_26',
#   'text': 'Cho hàm số $y=f\\left(x\\right)$ và phần hình phẳng $\\left(H\\right)$ được gạch chéo như hình vẽ bên. Công thức tính diện tích hình phẳng $\\left(H\\right)$ là'},
#  {'code': '2D3X3_29',
#   'text': 'Parabol $(P): y^2=2x$ cắt đường tròn $(C): x^2+y^2=8$ tại hai điểm $A$ và $B$. Diện tích của hình phẳng được gạch chéo ở hình bên được tính theo công thức nào?'},
#  {'code': '2D3X3_32',
#   'text': 'Cho hai hàm số $y=f(x)$, $y=g(x)$ liên tục trên $[a;b].$ Diện tích hình giới hạn bởi hai đồ thị hàm số $y=f(x)$, $y=g(x)$ và hai đường $x=a$, $x=b$ được tính bởi công thức nào sau đây?'},
#  {'code': '2D3X3_37',
#   'text': 'Tính diện tích hình phẳng giới hạn bởi các đường thẳng $x=0,x=1$, đồ thị hàm số $y=x^4+3x^2+1$ và trục hoành.'},
#  {'code': '2D3X3_42',
#   'text': 'Parabol $y=\\dfrac{x^2}{2}$ chia hình tròn có tâm tại gốc tọa độ, bán kính bằng $2\\sqrt{2}$ thành hai phần có diện tích $S_1,S_2$ như hình vẽ bên. Tính $\\dfrac{S_2}{S_1}$.'},
#  {'code': '2D3X3_48',
#   'text': 'Tính diện tích hình phẳng giới hạn bởi các đường $y = 2 + \\sin x$, $y = 1 + \\cos^2x$, $x = 0$ và $x = \\pi.$'},
#  {'code': '2D3X3_61',
#   'text': 'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị hàm số $y=3x^2-2x+1$ và các đường thẳng $y=0, x=2, x=3$.'},
#  {'code': '2D3X3_87',
#   'text': 'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị của các hàm số $y=\\left(\\mathrm{e}+1\\right)x$ và $y=\\left(1+\\mathrm{e}^x\\right)x$.'},
#  {'code': '2D1X5_81',
#   'text': 'Cho hàm số $y=f(x)$ xác định và liên tục trên đoạn $[-2;2]$ và có đồ thị là đường cong như trong hình vẽ bên. Điểm cực tiểu của đồ thị hàm số $y=f(x)$ trên đoạn $[-2;2]$ là'},
#  {'code': '2D1X5_82',
#   'text': 'Cho hàm số $y=ax^3+bx^2+cx+d \\,(a\\neq 0)$ có đồ thị như hình vẽ bên. Khẳng định nào sau đây đúng?'},
#  {'code': '2D1X5_94',
#   'text': 'Tìm $a$, $b$, $c$ để hàm số $y=\\dfrac{ax+2}{cx+b}$ có đồ thị như hình bên.'},
#  {'code': '2D1X5_121',
#   'text': 'Cho hàm số $y=f(x)=x^3+ax^2+bx+4$ có đồ thị $(C)$ như hình vẽ. Hỏi $(C)$ là đồ thị của hàm số $y=f(x)$ nào?'},
#  {'code': '2D1X5_149',
#   'text': 'Bảng  biến thiên  sau là  bảng  biến thiên của một trong các hàm số được liệt kê ở các  phương án A, B, C, D dưới  đây. Hỏi đó là hàm số  nào?\n\n'},
#  {'code': '2D1X5_154',
#   'text': 'Hàm số nào dưới đây có đồ thị nhận $Oy$ làm trục đối xứng?'},
#  {'code': '2D1X5_179',
#   'text': 'Đường cong trong hình vẽ bên là đồ thị của hàm số nào trong các hàm số dưới đây? '},
#  {'code': '2D1X5_188',
#   'text': 'Cho hàm số $y=x^3+ax^2+bx+c\\ (a,b,c\\in \\mathbb{R})$ có đồ thị như hình vẽ. Khẳng định nào sau đây $\\textbf{sai}$? '},
#  {'code': '2D3X3_12',
#   'text': 'Tính diện tích $S$ của hình phẳng giới hạn bởi các đường $y=\\sqrt{x}, y=x^{3}$.'},
#  {'code': '2D3X3_25',
#   'text': 'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị hàm số $y=3x^2+1$ và đồ thị $y=3x+1$.'},
#  {'code': '2D3X3_39',
#   'text': 'Tính diện tích hình phẳng giới hạn bởi đồ thị hàm số $y=x^3+3x^2-x$ và đồ thị hàm số $y=2x^2+x$.'},
#  {'code': '2D3X3_40',
#   'text': 'Cho Parabol $(P):y=x^2$. Hai điểm $A$, $B$ di động trên $(P)$ sao cho $AB=2$. Gọi $S$ là diện tích hình phẳng giới hạn bởi Parabol $(P)$ và đoạn thẳng $AB$. Tìm giá trị lớn nhất của $S$.'},
#  {'code': '2D3X3_89',
#   'text': 'Tính diện tích hình phẳng $(H)$ giới hạn bởi các đường $y=x^2-2x,$ $y=x.$'},
#  {'code': '2D1X5_74',
#   'text': 'Đồ thị trong hình bên là đồ thị của một hàm số trong bốn hàm số được liệt kê ở bốn phương án $\\textbf{A, B, C, D}$ dưới đây. Hỏi hàm số đó là hàm số nào?'},
#  {'code': '2D1X5_124', 'text': 'Bảng biến thiên sau đây là của hàm số nào?'},
#  {'code': '2D1X5_134',
#   'text': 'Cho hàm số $y=f(x)$ liên tục và có đạo hàm cấp hai trên $\\mathbb{R}.$ Đồ thị của các hàm số $y=f(x), y=f\'(x), y=f"(x)$ lần lượt là các đường cong nào trong hình bên?'},
#  {'code': '2D1X5_159', 'text': 'Hình bên là đồ thị của hàm số nào dưới đây? '},
#  {'code': '2D3X3_20',
#   'text': 'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị các hàm số $y=|x|$, $y=x^2-2$.'},
#  {'code': '2D3X3_28',
#   'text': 'Diện tích hình phẳng giới hạn bởi các đường $y=x^2-2x-8$ và $y=2x-3$ là'},
#  {'code': '2D3X3_62',
#   'text': 'Gọi $S$ là diện tích hình phẳng giới hạn bởi các đường $y=x^2-2x, y=x$. Mệnh đề nào sau đây đúng?'},
#  {'code': '2D3X3_92',
#   'text': 'Tính diện tích hình phẳng giới hạn bởi đồ thị hàm số $y=x^2+2$ và $y=3x$.'},
#  {'code': '2D3X3_96',
#   'text': 'Tính diện tích $S$ của hình phẳng giới hạn bởi các đường $y=\\ln x$, $y=0$ và $x=e^2$.'},
#  {'code': '2D1X5_54',
#   'text': 'Hàm số $y=ax^3 + bx^2 + cx + d$ có đồ thị như hình vẽ sau. Chọn nhận xét đúng.'},
#  {'code': '2D1X5_78',
#   'text': 'Cho hàm số $y=f(x)$\tcó đồ thị như trong hình bên.\n Tìm tập hợp tất cả các giá trị thực của $m$ để đồ thị hàm số $y=f(|x|+m)$ có 5 điểm cực trị.'},
#  {'code': '2D1X5_64',
#   'text': 'Bảng biến thiên trong hình vẽ là bảng biến thiên của một trong bốn hàm số được liệt kê ở các phương án A, B, C, D dưới đây. Hỏi hàm số đó là hàm số nào?'},
#  {'code': '2D1X5_75',
#   'text': 'Đường cong trong hình bên là đồ thị của hàm số nào trong các hàm số sau đây?'},
#  {'code': '2D1X5_105',
#   'text': 'Hàm số $y=f(x)$ xác định trên $\\mathbb{R},$ có đồ thị là đường cong như hình bên. Mệnh đề nào dưới đây đúng?'},
#  {'code': '2D1X5_129',
#   'text': '  Đường cong trong hình bên là đồ thị của một hàm số trong bốn hàm số được liệt kê ở bốn phương án $\\textbf{A, B, C, D}$ dưới đây. Hỏi hàm số đó là hàm số nào?'},
#  {'code': '2D1X5_132',
#   'text': ' {} Cho hàm số $y=f(x)$ liên tục trên đoạn $[-2;3],$ có bảng biến thiên như hình bên. Khẳng định nào sau đây là khẳng định đúng?'},
#  {'code': '2D1X5_143',
#   'text': 'Cho hàm số $ y = ax^4 + bx^2 + c$ có đồ thị như hình vẽ bên.\nMệnh đề nào dưới đây $\\textbf{đúng}$?\n'},
#  {'code': '2D1X5_174',
#   'text': 'Cho hàm số $y=ax^4+bx^2+c$ có đồ thị như hình bên. Mệnh đề nào sau đây đúng?'},
#  {'code': '2D3X3_2',
#   'text': 'Cho hàm số $y=f(x)$ có đồ thị như hình vẽ dưới đây. Diện tích hình phẳng $S$ (phần tô màu trong hình vẽ) được tính bởi công thức nào?'},
#  {'code': '2D3X3_22',
#   'text': 'Tính diện tích hình phẳng giới hạn bởi parabol $(P): y^2=2x$ và đường thẳng $x=2$.'},
#  {'code': '2D3X3_41',
#   'text': 'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị hàm số $y=\\dfrac{2x+1}{x+1}$, trục $Ox$ và hai đường thẳng $x=1, x=3$.'},
#  {'code': '2D3X3_57',
#   'text': 'Diện tích hình phẳng giới hạn bởi các đường $y=x(4-x)^2$, trục hoành và hai đường thẳng $x=1, x=5$ là'},
#  {'code': '2D3X3_60',
#   'text': 'Diện tích hình phẳng giới hạn bởi các đường $y=-x^2+6x$ và $y=(x-6)^2$ là'},
#  {'code': '2D3X3_100',
#   'text': 'Cho hình phẳng (H) giới hạn bởi các đường cong $y=x^2-2x+1$ và $y=-x^2+5x+1$. Đặt diện tích của hình (H) là $S=\\dfrac{1}{a} \\left( \\dfrac{b}{c}\\right)^d$ với $a$, $b$, $c$, $d$ là các số nguyên dương và $\\dfrac{b}{c}$ là phân số tối giản. Tính $Q=ab-cd$.'},
#  {'code': '2D3X3_102',
#   'text': 'Cho hàm số $y=f(x)$ liên tục trên $\\mathbb{R}$, có đồ thị cắt trục $Ox$ tại các điểm có hoành độ lần lượt bằng $-3, 0$ và $4$ như hình bên. Tìm công thức tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị hàm số $y=f(x)$ và trục $Ox.$\n'},
#  {'code': '2D1X5_103',
#   'text': 'Cho hàm số $y=f(x)$ có đồ thị như hình vẽ. Tìm số điểm cực trị của hàm số $y=\\left|f(x-1)\\right|$.'},
#  {'code': '2D1X5_111',
#   'text': 'Biết rằng hàm số $y=4x^3-6x^2+1$ có đồ thị như hình vẽ bên. Phát biểu nào sau đây là phát biểu đúng?'},
#  {'code': '2D1X5_122',
#   'text': 'Cho hàm số $y=\\dfrac{ax+b}{cx+d}$ có đồ thị như hình bên. Mệnh đề nào dưới đây đúng?'},
#  {'code': '2D1X5_152',
#   'text': 'Hàm số nào dưới đây có tập xác định là $\\mathbb{R}\\backslash{\\{1\\}}$?'},
#  {'code': '2D1X5_153',
#   'text': 'Hàm số nào có bảng biến thiên dưới đây?$\\\\$'},
#  {'code': '2D1X5_165',
#   'text': 'Cho hàm số $y=f(x)$ xác định, liên tục trên đoạn $[-1;3]$ và có đồ thị như hình vẽ bên. $\\\\$\nKhẳng định nào sau đây đúng?'},
#  {'code': '2D1X5_166',
#   'text': 'Hình vẽ bên là đồ thị của hàm số nào trong các hàm số sau?'},
#  {'code': '2D1X5_167',
#   'text': 'Cho hàm số $y=f(x)$ liên tục trên đoạn $[-2;2],$ và có đồ thị là đường cong như trong hình vẽ bên. Tìm số nghiệm trên đoạn $[-2;2]$ của phương trình $|f(x)|=1.$'},
#  {'code': '2D1X5_168',
#   'text': 'Cho hàm số $y=f(x)$ có bảng biến thiên như bên dưới. Mệnh đề nào dưới đây là mệnh đề đúng?'},
#  {'code': '2D3X3_30',
#   'text': 'Tính diện tích hình phẳng giới hạn bởi các đường $y=x^4$, $y=0$, $x=5.$'},
#  {'code': '2D3X3_43',
#   'text': 'Tính diện tích hình phẳng được tô đậm ở hình bên.'},
#  {'code': '2D3X3_55',
#   'text': 'Cho parabol như hình vẽ. Hãy tính diện tích hình phẳng giới hạn bởi parabol và trục hoành.'},
#  {'code': '2D3X3_83',
#   'text': 'Diện tích hình phẳng giới hạn bởi các đường $x=a, x=b$, đồ thị hàm số $y=f(x)$ liên tục trên đoạn $[a;b]$ và trục $Ox$ là'},
#  {'code': '2D3X3_91',
#   'text': 'Diện tích hình phẳng giới hạn bởi đồ thị hàm số $y=x^3$, trục hoành và hai đường thẳng $x=-1, x=2$ là'},
#  {'code': '2D1X5_67',
#   'text': 'Cho hàm số $y=\\dfrac{ax+b}{cx+d}$ có đồ thị như hình vẽ. Mệnh đề nào dưới đây $\\textbf{đúng}$?'},
#  {'code': '2D1X5_114',
#   'text': 'Cho hàm số $y=f(x)$ xác định, liên tục trên $\\mathbb{R}$ và có bảng biến thiên như dưới đây. Khẳng định nào sau đây là khẳng định {đúng}?'},
#  {'code': '2D1X5_77',
#   'text': 'Hàm số $y=f(x)$ liên tục trên $\\mathbb{R}$ và có bảng biến thiên như hình vẽ. Khẳng định nào sau đây là $\\textbf{sai}$?'},
#  {'code': '2D1X5_92',
#   'text': 'Cho hàm số $y=f(x)$ có bảng biến thiên sau: Khẳng định nào sau đây $\\textbf{sai}$?'},
#  {'code': '2D1X5_101', 'text': ''},
#  {'code': '2D1X5_117',
#   'text': 'Hình vẽ bên là đồ thị của hàm số $y=\\dfrac{ax+b}{cx+d}$. Mệnh đề nào sau đây $\\textbf{đúng}$?'},
#  {'code': '2D1X5_123',
#   'text': ' {} Đường cong trong hình bên là đồ thị của một trong bốn hàm số liệt kê ở bốn phương án $\\textbf{A, B, C, D}$ dưới đây. Hỏi hàm số đó là hàm số nào?'},
#  {'code': '2D1X5_126',
#   'text': 'Cho hàm số $y=\\dfrac{ax+b}{x+1}$ có đồ thị như hình vẽ bên. Tìm khẳng định đúng trong các khẳng định sau.'},
#  {'code': '2D1X5_135',
#   'text': 'Tìm trên đồ thị hàm số $y=-x^3+4x+2$ hai điểm phân biệt mà chúng đối xứng với nhau qua trục tung.'},
#  {'code': '2D1X5_182',
#   'text': 'Đường cong trong hình vẽ là đồ thị của một trong bốn hàm số được liệt kê ở các phương án A, B, C, D dưới đây. Hàm số đó là hàm số nào?'},
#  {'code': '2D1X5_189',
#   'text': 'Trong các hàm số sau, hàm số nào có đồ thị như hình vẽ dưới đây?'},
#  {'code': '2D3X3_11',
#   'text': 'Cho hình phẳng giới hạn bởi các đường $(C):y=x^2$, trục hoành và tiếp tuyến của $(C)$ tại điểm $x_0=1$. Tính diện tích $S$ của hình phẳng đó.'},
#  {'code': '2D3X3_23',
#   'text': 'Diện tích hình phẳng giới hạn bởi đồ thị hàm số $y=x^2+3x-2$ và $y=-x-2$ là'},
#  {'code': '2D3X3_31',
#   'text': 'Tính diện tích hình phẳng giới hạn bởi các đường $y=2x^3+x^2+3x,$ $y=0, x=0, x=3.$'},
#  {'code': '2D3X3_46',
#   'text': 'Tính diện tích hình phẳng giới hạn bởi các đường $x=1,x= \\textrm{e},y=0$ và $y=\\dfrac{\\ln x}{2\\sqrt{x}}.$'},
#  {'code': '2D3X3_67',
#   'text': 'Tính diện tích $S$ của hình phẳng giới hạn bởi parabol $(P):y=3x^2+2$, trục hoành, trục tung và đường thẳng $x=2$.'},
#  {'code': '2D3X3_80',
#   'text': 'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị hàm số $y=x^2+2x+1$, trục hoành và các đường thẳng $x=-1, x=3$.'},
#  {'code': '2D3X3_82',
#   'text': 'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị hàm số $f(x)=x^2-x$, trục $Ox$ và hai đường thẳng $x=-1, x=1$.'},
#  {'code': '2D1X5_116', 'text': 'Đồ thị sau đây là đồ thị của hàm số nào?'},
#  {'code': '2D1X5_120',
#   'text': 'Hàm số  $y=ax^3+bx^2+cx+d \\left( a\\ne 0 \\right)$  có đồ thị sau. Khi đó, khẳng định nào sau đây là đúng?'},
#  {'code': '2D1X5_125',
#   'text': '  Cho đồ thị hàm số $y=a x^4+b x^2+c$ có đồ thị như hình vẽ bên. Chọn mệnh đề đúng trong các mệnh đề sau.'},
#  {'code': '2D1X5_128',
#   'text': 'Cho hàm số $y=f(x)$ xác định, liên tục trên $\\mathbb{R}$ và có bảng biến thiên như hình dưới đây Khẳng định nào sau đây $\\textbf{đúng}$?'},
#  {'code': '2D3X3_16',
#   'text': 'Trên mặt phẳng tọa độ $Oxy,$ cho phần hình phẳng được tô đậm như hình bên được giới hạn bởi một đồ thị hàm số đa thức bậc ba và một đường thẳng. Diện tích $S$ của phần tô đậm đó bằng bao nhiêu?'},
#  {'code': '2D3X3_19',
#   'text': 'Tính diện tích hình phẳng giới hạn bởi đường cong $y =x^2 + x - 1$ và đường thẳng $y = 2x + 1$.'},
#  {'code': '2D3X3_33',
#   'text': 'Tính diện tích hình phẳng giới hạn bởi các đường $y=x^2+4x, y=x-2.$'},
#  {'code': '2D3X3_47',
#   'text': 'Cho hàm số $y = f(x)$ liên tục trên $\\big[a; b\\big]$. Công thức tính diện tích của hình phẳng giới hạn bởi đồ thị hàm số $y = f\\big(x\\big)$, trục hoành và hai đường thẳng $x = a$, $x = b$ là công thức nào sau đây?'},
#  {'code': '2D3X3_75',
#   'text': 'Cho hàm số $y=f(x)$ liên tục trên đoạn $[a;b]$ và cắt trục hoành tại điểm $x=c$ (như hình vẽ). Gọi $S$ là diện tích hình phẳng được giới hạn bởi đồ thị của hàm số $y=f(x)$, trục hoành và hai đường thẳng $x=a,x=b$. Khẳng định nào sau đây là khẳng định $\\textbf{đúng}$?\n'},
#  {'code': '2D3X3_77',
#   'text': 'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị của hàm số $y=\\mathrm{e}^x+x$ và các đường thẳng $x-y+1=0,\\, x=\\ln 5$.'},
#  {'code': '2D1X5_79', 'text': 'Hình bên là đồ thị của hàm số nào?'},
#  {'code': '2D1X5_110',
#   'text': 'Cho hàm số $y=ax^4+bx^2+c$ ($a\\neq 0$) và có bảng biến thiên như hình sau: Khẳng định nào sau đây là khẳng định đúng?'},
#  {'code': '2D1X5_131',
#   'text': 'Tìm tập xác định $D$ của hàm số $y=\\log_2\\left(x^2-2x\\right).$'},
#  {'code': '2D1X5_133', 'text': 'Hàm số có đồ thị như hình vẽ bên là'},
#  {'code': '2D1X5_141',
#   'text': 'Cho hàm số bậc ba $y=ax^3+bx^2+cx+d$ có đồ thị như hình vẽ. Dấu của $a; b; c; d$ là'},
#  {'code': '2D1X5_146', 'text': 'Đồ thị ở hình bên là đồ thị của hàm số nào?'},
#  {'code': '2D1X5_147',
#   'text': 'Cho hàm số $y=ax^3+bx^2+cx+d$ có đồ thị như hình vẽ. Khẳng định nào sau đây đúng?'},
#  {'code': '2D1X5_157',
#   'text': ' $\\\\$Cho hàm số $y=f(x)$ xác định và liên tục trên đoạn $[-2;2]$ và có đồ thị là đường cong trong hình vẽ bên. Điểm cực tiểu của đồ thị hàm số $y=f(x)$ là'},
#  {'code': '2D1X5_164',
#   'text': "Cho hàm số $y=f(x)$ liên tục trên $\\mathbb{R}$ và có bảng xét dấu $f'(x)$ như sau: Mệnh đề nào sau đây là $\\textbf{sai}$?"},
#  {'code': '2D3X3_54',
#   'text': 'Tính diện tích hình phẳng $ S $ được giới hạn bởi các đồ thị hàm số $y=x^2-x+3$ và đường thẳng $y=2x+1$'},
#  {'code': '2D1X5_56',
#   'text': 'Cho hàm số $y=f(x)$ liên tục trên khoảng $\\mathbb{K},$ có đồ thị $(C)$ trên $\\mathbb{K}$ như hình vẽ bên. Khẳng định nào sau đây là đúng? '},
#  {'code': '2D1X5_57',
#   'text': 'Đường cong trong hình bên là đồ thị của một hàm số trong bốn hàm số được liệt kê ở bốn phương án $A,B,C,D$ dưới đây. Hỏi hàm số đó là hàm số nào?\n'},
#  {'code': '2D1X5_69',
#   'text': 'Cho hàm số $y=f(x)$ liên trục trên khoảng $(-3;2)$, có bảng biến thiên như hình vẽ. Khẳng định nào sau đây là đúng?'},
#  {'code': '2D1X5_84',
#   'text': 'Cho hàm số $y=f(x)$ liên tục trên $\\mathbb{R}$ và có bảng biến thiên như sau Trong các mệnh đề sau, mệnh đề nào $\\textbf{sai}$?'},
#  {'code': '2D1X5_93',
#   'text': 'Cho hàm số $y=\\dfrac{3x-1}{2x+1}$ có đồ thị là $(C)$. Tìm tọa độ tâm đối xứng của đồ thị $(C)$.'},
#  {'code': '2D1X5_102',
#   'text': 'Cho hàm số $y=ax^4+bx^2+c$ có đồ thị như hình bên. Xác định các hệ số $a$, $b$ và $c$.'},
#  {'code': '2D1X5_107',
#   'text': 'Cho hàm số $y=f(x)$ xác định và liên tục trên khoảng $(-\\infty;+\\infty)$, có bảng biến thiên như hình vẽ. Mệnh đề nào sau đây $\\textbf{sai}$?$\\\\$\n'},
#  {'code': '2D1X5_109',
#   'text': 'Đồ thị như hình bên là của hàm số nào trong các hàm số được liệt kê ở các phương án $\\textbf{A, B, C, D}$.'},
#  {'code': '2D1X5_118',
#   'text': 'Hàm số  $y=f\\left( x \\right)$  có bảng biến thiên như hình vẽ sau. Dựa vào bảng biến thiên, phát biểu nào sau đây đúng?'},
#  {'code': '2D1X5_145',
#   'text': 'Cho hàm số $y=x^4+2x^2+3$. Khẳng định nào trong các khẳng định sau đây là $\\textbf{sai}$?'},
#  {'code': '2D1X5_156',
#   'text': 'Tìm tất cả các giá trị của tham số $m$ để phương trình $\\left|x\\right|^3-3x^2+2-m=0$ có 4 nghiệm phân biệt.'},
#  {'code': '2D1X5_160',
#   'text': 'Tìm tất cả các giá trị thực của tham số $m$ để phương trình $4|x|^3-3|x|-1=mx-m$ có 4 nghiệm phân biệt.'},
#  {'code': '2D1X5_187',
#   'text': 'Cho hàm số $y=f(x)$ liên tục trên $\\mathbb{R}$ và có bảng biến thiên sau: Khẳng định nào sau đây là khẳng định $\\textbf{đúng}$?'},
#  {'code': '2D3X3_52',
#   'text': 'Tính diện tích hình phẳng giới hạn bởi hai đồ thị hàm số $y=\\sqrt{x},y=6-x$ và trục hoành.'},
#  {'code': '2D3X3_79',
#   'text': 'Tính diện tích hình phẳng giới hạn bởi đường cong parabol $y=x^2-x+3$ và đường thẳng $y=2x+1.$'},
#  {'code': '2D3X3_110',
#   'text': 'Gọi $(H)$  là hình phẳng  giới hạn bởi  đồ thị $(P)$ của  hàm số $y=6x-x^2$ và trục hoành. Hai đường thẳng  $y=m$  và  $y=n$ chia hình $(H)$  thành  ba  phần  có  diện tích bằng  nhau. Tính $P={(9-m)}^3 +{(9-n)}^3$.'},
#  {'code': '2D3X3_135',
#   'text': 'Diện tích hình phẳng giới hạn bởi các đường \n$y=x^3-1,$ $y=0,$ $x=0,$ $x=2$   bằng'},
#  {'code': '2D3X3_151',
#   'text': 'Cho hình phẳng giới hạn bởi các đường $y=\\sin x, y=\\cos x$ và $S_1, S_2$ là diện tích của các phần được gạch chéo như hình vẽ bên. Tính $S_1^2+S_2^2, x=\\dfrac{\\pi}{4}, x=\\dfrac{5\\pi}{4}$'},
#  {'code': '2H2F3_36',
#   'text': 'Cho hình chóp $S.ABCD$ có đáy là hình vuông cạnh $a$, $SA\\perp (ABCD)$, $SA=a\\sqrt3$. Tính diện tích mặt cầu ngoại tiếp hình chóp $S.ABCD$.'},
#  {'code': '2H2F3_42',
#   'text': 'Cho mặt cầu tâm $O$, bán kính $R=3$. Mặt phẳng $(\\alpha)$ cách tâm $O$ của mặt cầu một khoảng bằng 1, cắt mặt cầu theo một đường tròn. Gọi $P$ là chu vi đường tròn này, tính $P$.'},
#  {'code': '2H2F3_53',
#   'text': 'Bé Na bơm không khí vào một quả bóng cao su hình cầu. Giả sử thể tích của quả bóng sau khi bơm thêm bằng 2 lần thể tích quả bóng trước khi bơm. Hỏi bán kính của quả bóng tăng lên mấy lần so với trước?'},
#  {'code': '2H2F3_98',
#   'text': 'Một khối cầu có bán kính $2R$ thì có thể tích $V$ bằng bao nhiêu?'},
#  {'code': '2H2F3_101',
#   'text': 'Một hình nón có thiết diện qua trục là một tam giác đều cạnh bằng $a$. Tính bán kính $R$ của mặt cầu ngoại tiếp hình nón theo $a$.'},
#  {'code': '2H2F5_6',
#   'text': 'Để làm cống thoát nước cho một khu vực dân cư trên đường Hùng Vương, thị trấn\nKrông Năng người ta cần đúc $500$ ống hình trụ có đường kính trong và chiều cao của mỗi ống\nbằng $1\\;{\\rm m},$ độ dày của thành ống là $10\\; {\\rm cm}.$ Chọn mác bê tông là $250$ (tức mỗi ${\\rm m}^3$ bê tông cần dùng\n$7$ bao xi măng). Hỏi phải chuẩn bị bao nhiêu bao xi-măng để làm đủ số ống nói trên.'},
#  {'code': '2H2F5_13',
#   'text': 'Một chậu nước hình bán cầu bằng nhôm có bán kính $R=20\\,\\textrm{cm}$ đặt trong một khung hình hộp chữ nhật (hình 1). Trong chậu chứa sẵn một khối nước hình chỏm cầu có chiều cao $h=10\\,\\textrm{cm}$. Bỏ vào trong chậu nước một viên bi kim loại hình cầu sao cho mặt nước dâng lên vừa phủ kín viên bi (hình 2). Bán kính của viên bi gần nhất với số nào sau đây?'},
#  {'code': '2D3X3_109',
#   'text': 'Tính diện tích hình  phẳng  giới hạn bởi  parabol $y=x^2+4$  và  đường thẳng $y=x+4$.'},
#  {'code': '2D3X3_111', 'text': 'Diện tích hình phẳng trong hình vẽ bên là'},
#  {'code': '2D3X3_112',
#   'text': 'Tính diện tích hình phẳng giới hạn bởi đồ thị hàm số  $y=x^2$  và đường thẳng  $y=2x$.'},
#  {'code': '2D3X3_113',
#   'text': 'Cho hàm số $y=\\dfrac{x^4}{2}-2m^2x^2+2.$ Tìm tập hợp tất cả các giá trị thực của tham số $m$ sao cho đồ thị của hàm số đã cho có cực đại và cực tiểu, đồng thời đường thẳng cùng phương với trục hoành qua điểm cực đại tạo với đồ thị một hình phẳng có diện tích bằng $\\dfrac{64}{15}.$'},
#  {'code': '2D3X3_116',
#   'text': 'Cho hàm số $y=f(x)$ có đồ thị như hình vẽ. Diện tích $\\mathcal{S}$ của hình phẳng gạch chéo trong hình bên được tính theo công thức nào sau đây?$\\\\$\n'},
#  {'code': '2D3X3_126',
#   'text': ' {} Cho hình thang cong $(H)$ giới hạn bởi các đường $y=2^x$, $y=0$, $x=0$, $x=4$. Đường thẳng $x=a$ $(0<a<4)$ chia $(H)$ thành hai phần có diện tích là $S_1$ và $S_2$ như hình vẽ bên. Tìm $a$ để $S_2=4S_1$.'},
#  {'code': '2D3X3_132',
#   'text': 'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị hàm số $y=x^4-2x^2+1$ và trục $Ox$.'},
#  {'code': '2H2F3_5',
#   'text': 'Trong tất cả các hình chóp tứ giác đều nội tiếp mặt cầu có bán kính bằng $9$, tính thể tích\n$V$ của khối chóp có thể tích lớn nhất.'},
#  {'code': '2H2F3_26',
#   'text': 'Cho hình chóp $S.ABC$ có đáy $ABC$ là tam giác đều cạnh $a$. Cạnh $SA$ vuông góc với mặt phẳng đáy $(ABC)$ và $SA=a\\sqrt{3}$. Tính thể tích khối cầu ngoại tiếp hình chóp.'},
#  {'code': '2H2F3_39',
#   'text': 'Cho tứ diện $ABCD$ có $AB=CD=a, AC=BD=AD=BC=b$. Tính bán kính mặt cầu ngoại tiếp $R$ của tứ diện $ABCD$.'},
#  {'code': '2H2F3_92',
#   'text': 'Cho mặt cầu $(S)$ có diện tích bằng $\\dfrac{8\\pi a^2}{3}$. Tìm bán kính mặt cầu $(S)$.'},
#  {'code': '2H2F3_114',
#   'text': 'Cho hình chóp $S.ABCD$ có đáy là hình chữ nhật với $AB=a$, $BC=2a$. Mặt bên $SAB$ là tam giác vuông tại $S$ và thuộc mặt phẳng vuông góc với $(ABCD)$. Tính bán kính của mặt cầu ngoại tiếp hình chóp $S.ABCD$.'},
#  {'code': '2H2F5_25',
#   'text': 'Một xí nghiệp chế biến thực phẩm muốn sản xuất những loại hộp hình trụ (có nắp cùng chất liệu) có dung tích 1 lít. Gọi $x$ (dm) là độ dài bán kính đáy của hình trụ. Tìm $x$ để sản xuất hình trụ tốn ít vật liệu nhất.'},
#  {'code': '2H2F5_27',
#   'text': 'Từ miếng tôn hình vuông cạnh bằng $4 \\text{ dm}$ , người ta cắt ra hình quạt\ntâm $O$ bán kính $OA=4 \\text{ dm}$ (xem hình) để cuộn lại thành một chiếc\nphễu hình nón (khi đó $OA$ trùng với $OB$). Chiều cao của chiếc phễu có\nsố đo gần đúng (làm tròn đến $3$ chữ số thập phân) là'},
#  {'code': '2H2F5_43',
#   'text': 'Người ta xếp $7$ viên bi có cùng bán kính $r$ vào một cái lọ hình trụ sao cho tất cả các viên bi đều tiếp xúc với đáy, viên bi nằm chính giữa tiếp xúc với $6$ viên bi xung quanh và mỗi viên bi xung quanh đều tiếp xúc với các đường sinh của lọ hình trụ. Khi đó diện tích đáy của cái lọ hình trụ là'},
#  {'code': '2D3X3_106',
#   'text': 'Biết diện tích của hình phẳng giới hạn bởi các đường $ y=|\\ln x| $ và $ y=1 $ là $ S=a\\mathrm{e}+\\dfrac{b}{\\mathrm{e}} + c $,  với $ a, b, c $ là các số nguyên. Tính $ P=a+b+c $.'},
#  {'code': '2D3X3_108',
#   'text': 'Cho hình thang cong $\\mathcal{H}$ giới hạn bởi các đường $y=\\dfrac{1}{x},$ $x=\\dfrac{1}{2},$ $x=2$ và trục hoành. Đường thẳng $x=k$ với $\\dfrac{1}{2}<k<2$ chia $\\mathcal{H}$ thành hai phần có diện tích là $S_1$ và $S_2$ như hình bên. Tìm tất cả các giá trị thực của $k$ để $S_1=3S_2.$'},
#  {'code': '2D3X3_120',
#   'text': 'Diện tích hình phẳng giới hạn bởi đồ thị các hàm số $y = - x^2 + 2x + 1$ và $y = 2x^2 - 4x + 1$ là'},
#  {'code': '2D3X3_148',
#   'text': 'Cho hình thang cong $(H)$ giớ hạn bới các đường $y=\\mathrm{e}^x, y=0, x=0, x=\\ln4$. Đương thẳng $x=k$ (với $0<k<\\ln4$) chia hình $(H)$ thành hai phần có diện tích $S_1,S_2$ như hình vẽ bên. Tìm $k$ để $S_1=2S_2.$'},
#  {'code': '2D3X3_154',
#   'text': 'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị hàm số $y=x^2 -x$ và trục hoành.'},
#  {'code': '2H2F3_13',
#   'text': 'Cho hình chóp tam giác đều có cạnh đáy bằng $a$, góc giữa cạnh bên và mặt đáy là $60^\\circ$. Hỏi diện tích mặt cầu $(S)$ có tâm $O$ và tiếp xúc với các cạnh bên bằng bao nhiêu? ($O$ là tâm mặt đáy)'},
#  {'code': '2H2F3_33',
#   'text': "Cho lăng trụ đứng $ABCD.A'B'C'D'$ có đáy $ABCD$ là hình thang cân, $AD=2a,$ $AB=BC=CD=a,$ $AA'=2a.$ Tính diện tích $S$ của mặt cầu ngoại tiếp lăng trụ $ABCD.A'B'C'D'.$"},
#  {'code': '2H2F3_41',
#   'text': 'Cho hình chóp $SABCD$ có $SA\\perp (ABC)$, $SA=a$, đáy là hình thang vuông tại $A$ và $B$, $AB=BC=a$ và $AD=2a$. Gọi $(S)$ là mặt cầu ngoại tiếp hình chóp $S.ACD$. Thể tích của khối cầu tạo nên bởi mặt cầu $(S)$ là'},
#  {'code': '2H2F3_44',
#   'text': 'Thể tích của một khối cầu bằng $\\dfrac{32\\pi}{3} (\\textrm{cm}^3)$. Đường kính của khối cầu đó là'},
#  {'code': '2H2F3_69',
#   'text': 'Tính thể tích $V$ của khối cầu có độ dài đường kính bằng $6a$.'},
#  {'code': '2H2F3_73',
#   'text': 'Cho hình chóp $S.ABC$ có đáy $ABC$ là tam giác đều cạnh $a$, mặt bên $SAB$ là tam giác đều và nằm trong mặt phẳng vuông góc với mặt phẳng đáy. Tính thể tích của khối cầu ngoại tiếp hình chóp đã cho.'},
#  {'code': '2H2F3_76',
#   'text': 'Cho hình chóp $S.ABC$ có đáy $ABC$ là tam giác vuông cân tại $B$, đường thẳng $SA$ vuông góc với mặt phẳng $(ABC)$ và $SA=AB=a$. Tính diện tích $S$ của mặt cầu ngoại tiếp hình chóp $S.ABC$.'},
#  {'code': '2H2F3_85',
#   'text': 'Cho hình chóp $S.ABC$ có $SA\\perp (ABC)$, tam giác $ABC$ vuông tại $B, AB=a, BC=a\\sqrt{3}$ và $SA=2a$. Tính diện tích $S$ của mặt cầu ngoại tiếp hình chóp $S.ABC$.'},
#  {'code': '2H2F3_94',
#   'text': 'Cho hình chóp tứ giác đều $S.ABCD$ có cạnh bên và cạnh đáy đều bằng $a$. Có một mặt cầu đi qua $A$ và tiếp xúc với cạnh $SB$, $SD$ tại trung điểm mỗi cạnh. Tính diện tích mặt cầu đó.'},
#  {'code': '2H2F3_113',
#   'text': 'Cho hình chóp $S.ABC$ có đáy $ABC$ là tam giác đều cạnh $a$, $SA=a\\sqrt{2}$ và $SA\\perp (ABC)$. Tính theo $a$ thể tích $V$ của khối cầu ngoại tiếp hình chóp $S.ABC$.'},
#  {'code': '2H2F3_115',
#   'text': 'Cho hình lập phương có cạnh bằng $a$ và tâm $O.$ Tính thể tích khối cầu tâm $O$ tiếp xúc với các mặt của hình lập phương.'},
#  {'code': '2H2F3_121',
#   'text': 'Cho hình chóp $S.ABCD$ có đáy $ABCD$ là hình chữ nhật, $AB=a, AD=2a,$ tam giác $SAB$ đều và nằm trong mặt phẳng vuông góc với đáy. Gọi $M, N$ lần lượt là trung điểm của các cạnh $AD,$ $DC.$ Tính bán kính $R$ của mặt cầu ngoại tiếp hình chóp $S.DMN.$'},
#  {'code': '2H2F5_7',
#   'text': 'Một người thợ có một khối đá hình trụ. Kẻ hai đường kính $MN, PQ$ của hai đáy sao cho $MN\\bot PQ$. Người thợ đó cắt khối đá theo các mặt đi qua 3 trong 4 điểm $M, N, P, Q$ để thu được khối đá có hình tứ diện $MNPQ$ bằng $30\\mbox{dm}^3$. Hãy tính thể tích của lượng đã bị cắt bỏ ( làm tròn kết quả đến 1 chữ số thập phân).'},
#  {'code': '2H2F5_18',
#   'text': 'Người ta bỏ 3 quả bóng bàn cùng kích thước vào trong một chiếc hộp hình trụ có đáy bằng hình tròn lớn của quả bóng bàn và chiều cao bằng $3$ lân đường kính của quả bóng bàn. Gọi $S_1$ là tổng diện tích của $3$ quả bóng bàn, $S_2$ là diện tích xung quanh của hình trụ. Tỉ số $\\dfrac{S_1}{S_2}$ bằng'},
#  {'code': '2H2F5_20',
#   'text': 'Một tấm nhôm hình chữ nhật có hai kích thước là $a$ và $2a$ ($a$ là độ dài có sẵn). Người ta cuốn tấm nhôm đó thành một hình trụ. Tính bán kính đáy của hình trụ nếu hình trụ được tạo thành có chiều dài đường sinh bằng $2a$.'},
#  {'code': '2H2F5_24',
#   'text': "Một khối cầu bằng thép có bán kính $5$ m. Để là một chiếc lu đựng nước, người ta cắt bỏ hai phần bằng hai mặt phẳng cách nhau $6$ m và cùng vuông góc với đường kính $AB$, tạo thành thiết diện ở hai đáy là hình tròn tâm $I$ và $I'$ như hình vẽ.$\\\\$\nMặt phẳng ở đáy dưới (chứa $I$) cách tâm $O$ của khối cầu $a$ m. Sau khi cắt, đáy dưới được hàn kín lại bằng tấm thép hình tròn, đáy trên để trống. Giả sử mỗi mét vuông thép có giá $100.000$ đồng. Tính số tiền tối thiểu mua thép để hàn kín đáy dưới biết chiếc lu chứa được đúng $126$ m$^3$ nước. (Coi bề dày của khối cầu và tám thép ở đấy không đáng kể, kết quả làm tròn đến đơn vị nghìn đồng.)"},
#  {'code': '2D3X3_122',
#   'text': 'Tính diện tích hình phẳng giới hạn bởi đồ thị hàm số $y=x^2-4x+3$ và trục $Ox.$'},
#  {'code': '2H2F3_19',
#   'text': "Cho lăng trụ đứng $ABC.A'B'C'$ có đáy là tam giác vuông cân và các cạnh $AB=BC=2, AA' =2\\sqrt{2}$. Tính thể tích khối cầu ngoại tiếp tứ diện $AB'A'C$."},
#  {'code': '2H2F3_50',
#   'text': 'Cho hình chóp tứ giác đều \\(S.ABCD\\) có cạnh đáy bằng \\(3\\sqrt{2}a\\), cạnh bên bằng \\(5a\\). Tính bán kính \\(R\\) của mặt cầu ngoại tiếp hình chóp \\(S.ABCD\\).'},
#  {'code': '2H2F3_54',
#   'text': 'Cho hình chóp $S.ABC$ có đáy $ABC$ là tam giác vuông tại $B$ với $AB=a,$ $BC=2a,$ $SA=2a$ và $SA$ vuông góc với mặt phẳng $(ABC).$ Tính thể tích $V$ của mặt cầu ngoại tiếp hình chóp $S.ABC.$'},
#  {'code': '2H2F3_57',
#   'text': 'Cho hình chóp $S.ABCD$ có đáy $ABCD$ là hình thoi cạnh $a$, góc $\\widehat{BAD} = 60^{\\circ}$. Hình chiếu vuông góc của $S$ trên mặt phẳng $(ABCD)$ là trung điểm $M$ của cạnh $AB$. Biết $SD = a\\sqrt{3}$, tính thể tích $V$ của khối cầu ngoại tiếp hình chóp $S.ABCD$.'},
#  {'code': '2H2F3_59',
#   'text': 'Cho hình chóp $S. ABCD$ có đáy là hình thang vuông tại $A$ và $B$, $SA$ vuông góc với đáy. Biết $SA=a \\sqrt 2$, $AD=2AB=2BC=2a$. Tính bán kính mặt cầu ngoại tiếp hình chóp $S. BCD$.'},
#  {'code': '2H2F3_67',
#   'text': 'Hình chóp $S.ABCD$ có đáy $ABCD$ là hình thoi cạnh bằng 1, $\\widehat{ABC}=60^\\circ$. Hai mặt phẳng $(SAD)$ và $(SAB)$ cùng vuông góc với mặt phẳng $(ABCD)$. Cạnh $SB$ tạo với mặt phẳng $(ABCD)$ góc $60^\\circ$. Tính diện tích mặt cầu ngoại tiếp tứ diện $S.ABD$.'},
#  {'code': '2H2F3_75',
# ...
#   'text': 'Tính tổng $S$ của phần thực và phần ảo của số phức $z=\\dfrac{(-1-i)\\left[(2-i)-(3-2i)\\right]}{1-i}$.'},
#  {'code': '2D4F2_173',
#   'text': 'Cho số phức $z=a+bi$ $(a,b\\in \\mathbb R;\\, i^2=-1)$. Số phức $z^2$ có phần ảo là'},
#  {'code': '2D4F2_191',
#   'text': 'Số phức liên hợp của số phức $z=(2+i)(-1+i)(2i+1)^2$ là'},
#  {'code': '2D4F2_195',
#   'text': 'Mô-đun của số phức $z=5+2i-\\left(1+i\\right)^3$ là'},
#  {'code': '2D4F2_234',
#   'text': 'Biết $\\dfrac{1}{3+4i}=a+bi,$ với $a,b\\in\\mathbb{R}.$ Tính $ab.$'},
#  {'code': '2D1X8_12',
#   'text': 'Một vật chuyển động theo quy luật $s(t) = 6t^2 - 2t^3,$ với $t$ (giây) là khoảng thời gian tính từ lúc vật bắt đầu chuyển động và $s\\unit{(m)}$ là quãng đường vật đi được trong thời gian đó. Hỏi trong khoảng 6 giây kể từ lúc vật bắt đầu chuyển động, vận tốc lớn nhất của vật là bao nhiêu?'},
#  {'code': '2D1X8_29',
#   'text': 'Một chất điểm chuyển động theo quy luật $s(t)=3t^2-t^3,$ trong đó $t$ là khoảng thời gian tính bằng giây, tính từ lúc chất điểm bắt đầu chuyển động, $s$ là quảng đường chất điểm đi được tính bằng mét. Tính thời điểm $t$ (giây) mà tại đó vận tốc của chất điểm đạt giá trị lớn nhất.'},
#  {'code': '2D1X8_30',
#   'text': 'Khi nuôi cá thí nghiệm trong hồ, một nhà sinh vật học thấy rằng: Nếu trên mỗi đơn vị diện tích của mặt hồ có $n$ con cá thì trung bình mỗi con cá sau một vụ cân nặng $P(n)=480-20n\\,(\\mathrm{gam}).$ Tìm số con cá phải thả trên mỗi đơn vị diện tích của mặt hồ để sau một vụ thu hoạch được nhiều $\\mathrm{gam}$ cá nhất.'},
#  {'code': '2D1X8_37',
#   'text': 'Công ty $X$ muốn thiết kế các hộp chứa sản phẩm dạng hình trụ có nắp với dung tích bằng $100\\textrm{ cm}^3$, bán kính đáy $x\\textrm{ cm}$, chiều cao $h\\textrm{ cm}$ (xem hình bên). Khi thiết kế, công ty $X$ luôn đặt mục tiêu sao cho vật liệu làm vỏ hộp là ít nhất, nghĩa là diện tích toàn phần hình trụ là nhỏ nhất. Khi đó, kích thước của $x$ và $h$ gần bằng số nào nhất trong các số dưới đây để công ty $X$ tiết kiệm được vật liệu nhất?'},
#  {'code': '2D4F2_15',
#   'text': 'Số phức$z$ thỏa mãn $z - (2 + 3i)\\overline{z} = 1 - 9i$ là'},
#  {'code': '2D4F2_71',
#   'text': 'Tính mô-đun của số phức $z=\\left(1+i \\right)^3$.'},
#  {'code': '2D4F2_119',
#   'text': 'Cho các  số  phức  $z_1 =2-3i, z_2=1+4i$. Tìm số  phức  liên hợp của số phức  $z_1z_2$.'},
#  {'code': '2D4F2_121',
#   'text': 'Tìm tất cả các căn bậc hai của số phức $-25$.'},
#  {'code': '2D4F2_134',
#   'text': 'Cho số phức $z=i(2-3i)$ có phần thực là $a$ và phần ảo là $b$. Tìm $a$ và $b$.'},
#  {'code': '2D4F2_157',
#   'text': 'Cho số phức $z=2+5i$. Tìm số phức $w=iz+\\overline{z}$.'},
#  {'code': '2D4F2_180',
#   'text': 'Cho số phức $z=(3-2i)(2+i)-7$. Tìm số phức liên hợp của số phức $w=1+z+z^2$.'},
#  {'code': '2D4F2_215',
#   'text': 'Tìm phần thực và phần ảo của số phức $z=(1+3i)-(2+i)$.'},
#  {'code': '2D4F2_8',
#   'text': 'Cho số phức $z$ thỏa mãn điều kiện $2z+\\overline z = 3+i$. Tính $A= |iz+2i+1|$.'},
#  {'code': '2D4F2_14',
#   'text': 'Trong mặt phẳng phức cho tam giác $ABC$ vuông tại $C$. Biết rằng $A$, $B$ lần lượt là điểm biểu diễn các số phức $z_{1}=-2-4i$, $z_{2}=2-2i$. Khi đó điểm $C$ biểu diễn số phức'},
#  {'code': '2D4F2_54',
#   'text': 'Số phức $z=a+bi$ $\\left(a,b\\in\\mathbb{R}\\right)$ thỏa mãn $2z+\\overline{z}-5+i=0$. Tính $P=6a+4b$.'},
#  {'code': '2D4F2_68',
#   'text': 'Cho số phức $z=\\dfrac{1-i}{1+i}$. Tìm phần thực và phần ảo của số phức $z^{2017}$.'},
#  {'code': '2D4F2_82',
#   'text': 'Trong mặt phẳng phức, tìm tọa độ điểm $M$ là điểm biểu diễn số phức $z$ biết $z$ thỏa mãn phương trình $(1+i)\\overline{z}=3-5i$.'},
#  {'code': '2D4F2_116',
#   'text': 'Tổng phần thực và phần ảo của số phức $z=\\left(1+2i\\right)\\left(3-i\\right)$ là'},
#  {'code': '2D4F2_122',
#   'text': 'Cho hai số phức $z_1=3-2i$ và $z_2=1+i$. Tính mô-đun của số phức $w=z_1+\\overline{z_2}$.'},
#  {'code': '2D4F2_163',
#   'text': 'Số phức $z=a+bi\\, (a,b\\in \\mathbb{R})$ thoả mãn điều kiện $z+\\dfrac{\\overline{z}\\left(6-2i\\right)}{(1+3i)(1+i)} +4i=0$. Tính tích $P=a.b$.'},
#  {'code': '2D4F2_181',
#   'text': 'Giá trị của biểu thức $z={\\left(1+i\\sqrt{7-4\\sqrt{3}}\\right)}^{24}$ bằng'},
#  {'code': '2D4F2_201',
#   'text': 'Tính tổng phần thực và phần ảo của số phức $z=2+2i-(3-i)(1+3i).$'},
#  {'code': '2D4F2_211',
#   'text': 'Cho số phức $z=2-5i$. Tìm phần thực của số phức $z^{-1}$.'},
#  {'code': '2D4F2_214',
#   'text': 'Tìm số phức liên hợp của số phức $z=2i(5-i)$.'},
#  {'code': '2D4F2_224', 'text': 'Tìm số phức $z$ biết $\\bar{z}=(3-i)(2+3i)$.'},
#  {'code': '2D1X8_41',
#   'text': 'Một gia đình xây cái bể hình trụ có thể tích $100$ m$^3$. Đáy bể làm bằng bê tông có giá $100.000$ đồng/m$^2$. Phần thân làm bằng tôn có giá $90.000$ đồng/m$^2$. Phần nắp làm bằng nhôm giá $120.000$ đồng/m$^2$. Để chi phí xây dựng bể đạt chi phí thấp nhất thì tỉ số giữa chiều cao $h$ và bán kính $R$ của bể là bao nhiêu?'},
#  {'code': '2D4F2_37',
#   'text': 'Tìm số phức liên hợp của số phức $z$ biết $z=i.z+2$.'},
#  {'code': '2D4F2_57',
#   'text': 'Cho các số phức $z_1$, $z_2$ thỏa mãn $|z_1+z_2|=3$, $|z_1|=1$, $|z_2|=2$. Tính $z_1 \\overline{z_2} + \\overline{z_1} z_2$.'},
#  {'code': '2D4F2_63',
#   'text': 'Gọi $M$ là điểm biểu diễn của số phức $z=\\left(2-i\\right)2i$ trong mặt phẳng toạ độ. Tọa độ của điểm $M$ là'},
#  {'code': '2D4F2_66', 'text': 'Số phức $(2-i)(1+2i)^2$ có mô-đun bằng'},
#  {'code': '2D4F2_69',
#   'text': 'Cho số phức $z=a+bi$ ($a, b$ là các số thực khác $0$) thỏa mãn $\\left(i\\overline{z}\\right)\\left(z+3-i\\right)=0$. Tính tích $ab$.'},
#  {'code': '2D4F2_90',
#   'text': 'Trên mặt phẳng tọa độ, điểm $P$ là điểm biểu diễn số phức $z$ như hình vẽ. Điểm nào trong hình vẽ là điểm biểu diễn số phức $w=z-1-2i$. '},
#  {'code': '2D4F2_103',
#   'text': 'Cho số phức $z=2-3i-(1+i).$ Gọi $M$ là điểm biểu diễn của số phức $z$ trên mặt phẳng tọa độ. Tìm tọa độ điểm $M$.'},
#  {'code': '2D4F2_162',
#   'text': 'Cho số phức $z=(1+4i)i$. Tính mô-đun của số phức $\\overline{z}$.'},
#  {'code': '2D4F2_165',
#   'text': 'Cho số phức $z$ thỏa mãn $\\left(1+i\\right)z+\\left(3-i\\right)\\overline{z}=2-6i$. Tính mô-đun của $z$.'},
#  {'code': '2D4F2_176',
#   'text': 'Cho hai số phức $z_1=4-2i;z_2=-2+i$. Tính môđun của số phức $z_1+z_2$.'},
#  {'code': '2D4F2_183',
#   'text': 'Với  $z_1,z_2$ là  hai số  phức  bất kỳ, giá trị của  biểu thức  $a=\\dfrac{|z_1|^2+|z_2|^2}{|z_1+z_2|^2+|z_1-z_2|^2}$ bằng'},
#  {'code': '2D4F2_190',
#   'text': 'Trong các mệnh đề sau, hãy xác định mệnh đề đúng?'},
#  {'code': '2D4F2_199', 'text': 'Tìm phần thực của số phức $z=(2-3i)(1-2i).$'},
#  {'code': '2D4F1_102', 'text': 'Tìm số phức liên hợp của số phức $z=3-2i$.'},
#  {'code': '2D1X3_23',
#   'text': 'Giá trị nhỏ nhất của hàm số $y=\\dfrac{1-x}{2x-3}$ trên đoạn $[0; 1]$ là'},
#  {'code': '2D1X3_25',
#   'text': 'Cho $x, y$ là các số thực dương thỏa mãn điều kiện $x^4 + y^4 + \\dfrac{2}{xy}=3xy+3$. Khi đó giá trị lớn nhất của biểu thức $P=x^2 y^2 + \\dfrac{16}{x^2 + y^2 + 2}$ là'},
#  {'code': '2D1X3_32',
#   'text': 'Hàm số $y=\\dfrac{{x}^2-3x}{x+1}$ có giá trị lớn nhất trên đoạn $[0;3]$ là'},
#  {'code': '2D1X3_38',
#   'text': 'Tìm giá trị lớn nhất và giá trị nhỏ nhất của hàm số $y=x^3+3x^2-9x+1$ trên đoạn $[0;3]$.'},
#  {'code': '2D1X3_65',
#   'text': 'Tìm giá trị lớn nhất và giá trị nhỏ nhất của hàm số $y=\\sqrt{4-x^2}$ trên đoạn $\\left[\\sqrt{3};2\\right]$.'},
#  {'code': '2D1X3_71',
#   'text': 'Cho $x,y\\ge 0$ và $x+y=4$. Tìm giá trị lớn nhất của biểu thức $S=\\left(x^3-1\\right)\\left(y^3-1\\right)$.'},
#  {'code': '2D1X3_78',
#   'text': 'Biết giá trị lớn nhất của hàm số $y=-x^2+4x-m$ trên đoạn $[-1;3]$ là 10. Khi đó, giá trị $m$ là bao nhiêu?'},
#  {'code': '2D1X3_81',
#   'text': 'Giá trị lớn nhất của hàm số $y=\\dfrac{x^2+3}{x-1}$ trên đoạn $[2; 4]$ là'},
#  {'code': '2D1X3_109',
#   'text': 'Giá trị nhỏ nhất của hàm số $y=-x^3+6x^2+2$ trên đoạn $\\left[1;6\\right]$ là'},
#  {'code': '2D4F3_6',
#   'text': 'Tìm tất cả các giá trị thực $x$, $y$ sao cho $x^2-1+yi=-1+2i$.'},
#  {'code': '2D4F3_14',
#   'text': 'Tìm số phức $z$ biết $\\dfrac{1}{\\overline{z}}=\\dfrac{1}{1-2i}-\\dfrac{1}{(1+2i)^{2}}$.'},
#  {'code': '2D4F3_20', 'text': 'Số căn bậc hai của số phức $z=4i$ là'},
#  {'code': '2D4F3_59',
#   'text': 'Cho hai số phức $z_1, z_2$ thỏa $|z_1|=1, |z_2|=1, |z_1+z_2|=\\sqrt{3}$. Khi đó, $|z_1-z_2|$ bằng'},
#  {'code': '2D4F3_60',
#   'text': 'Cho $z_1$, $z_2$, $z_3$ là các số phức thỏa mãn $z_1+z_2+z_3=0$ và $\\left|z_1\\right|=\\left|z_2\\right|=\\left|z_3\\right|=1$. Gọi $A$, $B$, $C$ là ba điểm biểu diễn lần lượt cho ba số phức $z_1$, $z_2$, $z_3$. Tính diện tích $S$ của tam giác $ABC$.'},
#  {'code': '2D4F3_61',
#   'text': 'Cho các số thực $a, b$ và số phức $w$, biết $w-2$ và $3i+2w$ là các nghiệm của phương trình\n$z^2 + az +b = 0$. Khi đó, mô-đun của $w$ bằng'},
#  {'code': '2D4F3_63',
#   'text': 'Cho số phức $z=a+bi$, $a\\ne 0$ thỏa mãn $z$ không là số thực và $\\dfrac{z^2+z+1}{z^2-z+1}$ là số thực. Tính $M=\\dfrac{1-a^4-b^4}{1-a^6-b^6}$.'},
#  {'code': '2D4F3_76',
#   'text': 'Cho số phức $z$ là nghiệm của phương trình $z^2-2z+2=0$. Tính giá trị của biểu thức  $P=z^{2012}+\\dfrac{1}{z^{2012}}$.'},
#  {'code': '2D4F3_111',
#   'text': 'Tập nghiệm của phương trình $z^4-2z^2-8=0$ là'},
#  {'code': '2D4F3_119',
#   'text': 'Gọi $z_1$ là nghiệm phức có phần ảo âm của phương trình $z^2+2z+2=0$. Tìm số phức liên hợp của số phức $w=(1+2i)z_1$.'},
#  {'code': '2D4F3_144', 'text': 'Phương trình: $8z^2-4z+1=0$ có nghiệm là'},
#  {'code': '2D4F3_177',
#   'text': 'Cho số phức $z=a+bi, \\mbox{ trong đó }a,b\\in \\mathbb{R}$ thoả mãn $3z-2\\overline{z}-6+10i=0.$ Tính $a-b.$'},
#  {'code': '2D4F3_200',
#   'text': 'Trong $\\mathbb{C}$, tìm tập hợp nghiệm của phương trình $z^4  - 2z^2  - 8 = 0$.'},
#  {'code': '2D4F3_213',
#   'text': 'Tính mô đun của số phức $z$ biết $(1+2i)z^2=3+4i.$'},
#  {'code': '2D4F3_238',
#   'text': 'Kí hiệu $z_1, z_2$ là hai nghiệm phức của phương trình $z^2+z+1=0$. Tính giá trị của  $P=z_1^2+z_2^2+z_1z_2$.'},
#  {'code': '2D2X1_6',
#   'text': 'Cho $m=2^x,\\space n=3^x$. Biểu diễn $6^x$ theo $m,n$'},
#  {'code': '2D2X1_8',
#   'text': 'Cho $m=2^x,\\space n=2^{2x}$, biểu diễn $2^{3x}$ theo $m,n$'},
#  {'code': '2D2X1_28',
#   'text': 'Cho $m=12^x,\\space n=6^x$. Biểu diễn $2^x$ theo $m,\\space n$'},
#  {'code': '2D2X1_35',
#   'text': 'Cho $a=2^{3x},\\space b=2^{7x}$, biểu diễn $2^{4x}$ theo $a,\\space b$'},
#  {'code': '2D2X1_57', 'text': ''},
#  {'code': '2H2F2_20',
#   'text': 'Trong không gian, cho hình chữ nhật $ABCD$ có $AB=1$ và $AD=2$. Gọi $M$, $N$ lần lượt là trung điểm của $AD$ và $BC$. Quay hình chữ nhật đó xung quanh trục $MN$, ta được một khối trụ. Tính diện tích toàn phần của hình trụ.'},
#  {'code': '2H2F2_24',
#   'text': "Cho hình trụ có bán kính đường tròn đáy bằng $R,$ chiều cao bằng $R\\sqrt{3}.$ Gọi $O,$ $O'$ là tâm của hai đường tròn đáy. Lấy các điểm $A,$ $B$ lần lượt thuộc đường tròn $(O),$ $(O')$ sao cho $AB=R\\sqrt{6}.$ Tính thể tích $V$ của khối tứ diện $OAO'B$ theo $R.$"},
#  {'code': '2H2F2_38',
#   'text': 'Một chi tiết máy bằng đồng được tạo ra bằng cách cho hình vẽ sau (tất  cả các góc của hai đường thẳng cắt nhau đều bằng $90^\\circ$) với các kích thước $DI = 6$ cm, $GH = 1$ cm, $DE = FG = 2$ cm xoay quanh trục $d$. Khi bỏ chi tiết này vào một hộp nước hình trụ có bán kính đáy là $4$ cm, chiều cao $12$ cm đang chứa một lượng nước bằng nửa thể tích hộp thì mực nước dâng thêm là (Biết chi tiết chìm hoàn toàn trong nước)'},
#  {'code': '2H2F2_55',
#   'text': 'Bánh của một chiếc xe lu có dạng hình trụ với đường kính đáy bằng $1,\\!2$ m, bề ngang bằng $2,\\!1$ m. Hỏi khi xe di chuyển thẳng, bánh xe quay được $12$ vòng, thì diện tích mặt đường được lu là bao nhiêu? (Kết quả làm tròn đến hàng đơn vị.)'},
#  {'code': '2D4F1_82', 'text': 'Phần ảo của số phức $z=\\dfrac{5}{3}i$ là'},
#  {'code': '2D4F1_86',
#   'text': 'Phần thực và phần ảo của số phức $z=\\sqrt{2}-\\sqrt{3}i$ lần lượt là'},
#  {'code': '2D4F1_96',
#   'text': 'Tìm phần thực và phần ảo của số phức $z = 1 - 3i$.'},
#  {'code': '2D4F1_98',
#   'text': 'Trong các khẳng định dưới đây, khẳng định nào $\\textbf{sai}$?'},
#  {'code': '2D1X3_2',
#   'text': 'Tìm giá trị nhỏ nhất $m$ của hàm số $y=x^3-7x^2+11x-2$ trên đoạn $[0; 2]$.'},
#  {'code': '2D1X3_41',
#   'text': 'Cho hàm số $f(x)=\\dfrac{9x+m^2}{x-1}$ (với $m$ là tham số thực). Tìm giá trị lớn nhất của hàm số trên đoạn $\\left[2;4\\right].$'},
#  {'code': '2D1X3_45',
#   'text': 'Cho $x, y$ là những số thực thoả mãn $x^2+2xy+3y^2=1$. Giá trị  lớn nhất $M$ và nhỏ nhất $m$ của biểu thức $P=2(x^2+6xy)$ tương ứng là:'},
#  {'code': '2D1X3_57',
#   'text': 'Giá trị lớn nhất của hàm số $y=\\sqrt{2x-x^2}$ trên đoạn $\\left[0;\\dfrac{3}{2}\\right]$ là'},
#  {'code': '2D1X3_59',
#   'text': 'Đặt $M$ là giá trị lớn nhất, $m$ là giá trị nhỏ nhất của hàm số $f(x)=|x^3+3x^2-72x+90|$ trên đoạn $[-5;5].$ Khi đó tổng $M+m$ có giá trị là một số thuộc khoảng nào dưới đây?'},
#  {'code': '2D1X3_104',
#   'text': 'Cho các số thực  $x, y$  thỏa mãn $x^2+2xy+3y^2=4.$  Tìm giá trị lớn nhất của biểu thức $P=\\left(x-y\\right)^2.$'},
#  {'code': '2D1X3_108',
#   'text': 'Tổng giá trị lớn nhất và giá trị nhỏ nhất của hàm số $y=2x^3-3x^2-12x+10$ trên đoạn $[-3;3]$ là'},
#  {'code': '2D1X3_119',
#   'text': 'Cho phương trình $\\sqrt{x-1}+4m\\sqrt[4]{x^2-3x+2}+(m+3)\\sqrt{x-2}=0$. Tìm $m$ để phương trình có nghiệm thực.'},
#  {'code': '2D4F3_17',
#   'text': 'Cho số phức $z_1 = 1 + 2i$ và $z_2 = 1 - 2i$. Hỏi $z_1$, $z_2$ là nghiệm của phương trình phức nào sau đây?'},
#  {'code': '2D4F3_37',
#   'text': 'Trong  tập phức,  phương trình ${(z+1)}^2 +{(z+2)}^2 +{(z+3)}^2=0$  có  bao nhiêu nghiệm?'},
#  {'code': '2D4F3_39',
#   'text': 'Các nghiệm phức của phương trình $z^2+\\left(1+i\\right)z+5i=0$ là'},
#  {'code': '2D4F3_56',
#   'text': 'Cho $z$ là số phức có phần thực là số nguyên và $|z|-2\\overline{z}=-7+3i+z$. Tính môđun của số phức $w=1-z+z^{2}$.'},
#  {'code': '2D4F3_71',
#   'text': 'Trên đoạn $[-5; 5]$ có bao nhiêu số nguyên $x$ thỏa mãn $\\left|1+4i-2^{-x}\\right|\\le 5$?'},
#  {'code': '2D4F3_84',
#   'text': 'Biết phương trình $z^2+az+b=0$ có một nghiệm phức là $z_0=1+2i$ với $a,b \\in \\mathbb{R}$. Tìm $a, b$.'},
#  {'code': '2D4F3_85',
#   'text': 'Cho số phức $z$ có phần ảo âm, và thỏa mãn $z^2-z+1=0.$ Tìm môđun của số phức $\\omega=2z+3.$'},
#  {'code': '2D4F3_92',
#   'text': 'Cho số phức $z$ thỏa mãn $\\left|z\\right|\\leq 1$. Đặt $A=\\dfrac{2z-i}{2+iz}$. Mệnh đề nào dưới đây đúng?'},
#  {'code': '2D4F3_96',
#   'text': 'Tìm phần ảo của số phức $z$ thỏa mãn $z+2\\overline z=\\left(2-i\\right)^3\\left(1-i\\right)$.'},
#  {'code': '2D4F3_137',
#   'text': 'Gọi $z_1$ và $z_2$ là hai nghiệm phức của phương trình $z^2-2z+10=0$. Giá trị biểu thức $A=|z_1|+|z_2|$ là'},
#  {'code': '2D4F3_147',
#   'text': 'Biết rằng phương trình $z^2+bz+c=0 (b, c\\in \\mathbb{R})$ có một nghiệm phức là $z_1=1+2i$. Khẳng định nào sau đây là đúng?'},
#  {'code': '2D4F3_151',
#   'text': 'Cho số phức $z$ thỏa mãn hệ thức $z+4i=\\vert z\\vert+2\\vert z\\vert i-1.$ Tính $T=4\\vert z\\vert^2-18\\vert z\\vert.$'},
#  {'code': '2D4F3_154',
#   'text': 'Cho số phức $z=a+bi$ ($a,b\\in \\mathbb{R}$) thỏa mãn $6(2+i)z-18\\overline{z}=-1+19i$. Tính tổng $S=3a+2b$.'},
#  {'code': '2D4F3_166',
#   'text': 'Có bao nhiêu số phức thỏa mãn phương trình $z^2=\\left|z\\right|^2+\\overline z$ ?'},
#  {'code': '2D4F3_198',
#   'text': 'Cho số phức $z$ có môđun bằng $\\dfrac{1}{2}$ và số phức $w$ thỏa mãn: $\\dfrac{1}{z}+\\dfrac{1}{w}=\\dfrac{1}{z+w}$. Môđun của số phức $w$ bằng bao nhiêu?'},
#  {'code': '2D4F3_201',
#   'text': 'Trong $\\mathbb{C}$, tìm nghiệm của phương trình $\\big(2 + 3i\\big)z = z - 1$.'},
#  {'code': '2D4F3_214',
#   'text': 'Cho số phức $z$ là nghiệm phức của phương trình $x^2+x+1=0.$ Tính $P=z^4+2z^3-z.$'},
#  {'code': '2D4F3_226',
#   'text': 'Cho số phức $z$ thỏa mãn $\\big(1 + i\\big)^2\\big(2 - i\\big)z = 8 + i + \\big(1 + 2i\\big)z$. Tìm phần thực của số phức $z$.'},
#  {'code': '2D4F3_230',
#   'text': 'Trong tập hợp số phức $\\mathbb{C}$, có bao nhiêu số phức $z$ thỏa mãn điều kiện $z^2 + 3\\bar{z} - 2z\\cdot\\bar{z} = 0$.'},
#  {'code': '2D4F3_237',
#   'text': 'Cho các số thực $a$, $b$, $c$ sao cho phương trình $z^3 + az^2 + bz + c = 0$ nhận $z = 1 + i$ và $z = 2$ là nghiệm của phương trình. Tính tổng $S = a + b + c$.'},
#  ...]

# %%
code = [foo['code'] for foo in preprocessed]
corpus = [foo['text'] for foo in preprocessed]

# %%
corpus
# Out:
# ['Biết hàm số $y=ax^4+bx^2+c$ có đồ thị như hình vẽ bên. Mệnh đề nào dưới đây là đúng?',
#  'Hãy xác định các số thực $a$ và $b$ để hàm số $y=\\dfrac{ax+2}{x+b}$ có đồ thị như hình vẽ bên.',
#  'Đường cong ở hình bên là đồ thị của hàm số nào trong các hàm số sau?',
#  'Cho hàm số $y=\\dfrac{ax+b}{cx+d}$ có đồ thị như hình vẽ bên. Mệnh đề nào sau đây đúng?',
#  'Đồ thị sau là đồ thị của hàm số được cho trong 4 đáp án A, B, C, D dưới đây. Đó là hàm số nào?',
#  'Đồ thị bên là của hàm số nào?',
#  'Đồ thị nào có đúng một điểm cực trị?',
#  'Cho hàm số $y=f\\left( x \\right)$ có bảng biến thiên như sau. Dựa vào bảng biến thiên, tìm mệnh đề đúng trong các mệnh đề sau đây.',
#  'Cho hàm số $y=f\\left(x\\right)$ có bảng biến thiên như hình vẽ. Khẳng định nào sau đây là đúng?',
#  'Cho hàm số $y=f(x)$ xác định trên $\\mathbb{R}\\backslash\\{2\\}$, liên tục trên mỗi khoảng xác định và có bảng biến thiên sau. Khẳng định nào dưới đây là khẳng định $\\textbf{sai}$?',
#  'Cho hàm số $y=f(x)$ liên tục trên $\\mathbb{R}$ và có bảng biến thiên như sau. Tập hợp tất cả các giá trị thực của tham số $m$ để phương trình $|f(x)+2 | =m $\ncó bốn nghiệm thực phân biệt là',
#  'Hình vẽ bên là đồ thị hàm số nào?',
#  ' $\\\\$Cho hàm số $y=ax^3+bx^2+cx+d \\,(a\\ne 0)$ có đồ thị như hình vẽ bên. Khẳng định nào sau đây là đúng?',
#  'Cho hàm số $y=f(x)$ có bảng biến thiên như hình vẽ. Khẳng định nào dưới đây đúng?',
#  'Tính diện tích tam giác được gới hạn bởi các trục tọa độ và tiếp tuyến của đồ thị $y=\\ln x$ tại giao điểm của đồ thị hàm số với trục $Ox$.',
#  'Tính diện tích hình phẳng giới hạn bởi đồ thị các hàm số $y=x^3$, $y=x^5$.',
#  'Tính diện tích $S$ của hình phẳng giới hạn bởi các đường $y=1, y=\\dfrac{1}{9}(6x^2-x^4).$',
#  'Cho hàm số $y=f(x)$ liên tục trên đoạn $[a;b], (a, b \\in \\mathbb R, a<b)$. Gọi $S$ là diện tích hình phẳng giới hạn bởi các đường $y=f(x), y=0, x=a, x=b$. Mệnh đề nào sau đây là đúng?',
#  'Cho  hàm số $y = f(x)$ liên tục trên đoạn $\\big[a,b\\big]$. Công thức tính diện tích hình phẳng giới hạn bởi đồ thị hàm số $y = f(x)$, $x = a$, $x = b$ và trục $Ox$ là',
#  'Ký hiệu $S$ là diện tích của hình phẳng giới hạn bởi các đường $y=x\\sin x$, $y=0$, $x=0$, $x=\\pi$. Trong các khẳng định sau, khẳng định nào đúng?',
#  'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị của các hàm số $y=x^2-x+3$ và $y=2x+1$.',
#  'Cho hàm số $y=\\dfrac{ax+b}{x+c}$ có đồ thị như hình vẽ bên. Tính giá trị của $S=a+2b+c$.',
#  'Trong các hình vẽ sau, hình nào biểu diễn đồ thị của hàm số $y=\\dfrac{x+1}{-x+1}$?',
#  'Cho hàm số $y=\\dfrac{x+1}{x-1}$. Mệnh đề nào dưới đây là mệnh đề $\\textbf{sai}$?',
#  'Cho hàm số $y=f(x)$ có đồ thị như hình bên. Khẳng định nào sau đây là khẳng định $\\textbf{sai}$? ',
#  'Cho hàm số $y=ax^4+bx^2+c$ có đồ thị như hình bên. Trong các mệnh đề sau, mệnh đề nào $\\textbf{đúng}$?',
#  'Cho hàm số có bảng biến thiên dạng như sau. Hãy chọn khẳng định đúng.\n',
#  "Cho hàm số  $y=f(x)$  liên tục trên khoảng  $(-3;4)$  và có đạo hàm  $f'(x)$  cũng liên tục trên \n$(-3;4).$  Đồ thị của hàm số $f'(x)$  trên khoảng  $(-3;4)$ được cho bởi hình vẽ bên. Trong các mệnh đề sau, mệnh đề nào $\\textbf{đúng}$?",
#  'Đồ thị hàm số trong hình bên là đồ thị của một trong bốn hàm số được nêu trong bốn đáp án $A$, $B$, $C$, $D$. Đồ thị đó là của hàm số nào?',
#  "Diện tích hình phẳng giới hạn bởi đồ thị \\((C)\\) của hàm số \\(y=-2x^3+x^2+x+5\\) và đồ thị \\((C')\\) của hàm số \\(y=x^2-x+5\\) bằng",
#  'Tính diện tích hình phẳng giới hạn bởi đường thẳng $y=2x+1$ và đồ thị hàm số $y=x^2-x+3$.',
#  'Viết công thức tích diện tích hình phẳng giới hạn bởi đồ thị hàm số $y=x^2-1$, trục hoành và hai đường thẳng $x=0,x=2$.',
#  'Gọi $S$ là diện tích của hình phẳng giới hạn bởi các đồ thị hàm số $y=x^2+3$ và $y=4x$. Xác định mệnh đề đúng?',
#  'Cho hàm số $f(x)$ xác định và đồng biến trên $\\big[0; 1\\big]$ và $f\\big(\\dfrac{1}{2}\\big) = 1$. Xác định công thức diện tích hình phẳng được giới hạn bởi các hàm số $y = f(x)$; $y = \\big(f(x)\\big)^2$, $x = 0$ và $x = 1$?',
#  'Gọi $S$ là diện tích hình phẳng giới hạn bởi $y=x^3,y=2-x$ và $y=0.$ $S$ được tính theo công thức nào dưới đây?',
#  'Cho hàm số $y=ax^3+bx^2+cx+d$ có đồ thị như hình bên. Mệnh đề nào sau đây $\\textbf{đúng}$?',
#  "Biết hàm số $f\\left( x \\right)$ có đạo hàm $f'\\left( x \\right)$ liên tục trên $\\mathbb{K}$ và $f'\\left(x\\right)$ có đồ thị là đường cong như hình vẽ bên. Tìm số điểm cực trị của đồ thị hàm số $f\\left(x\\right)$.",
#  'Cho hàm số $y=f\\left(x\\right)$ xác định trên $\\mathbb{R}\\backslash \\left\\{-1\\right\\},$ liên tục trên mỗi khoảng xác định và có bảng biến thiên như sau Khẳng định nào dưới đây $\\textbf{sai}$?',
#  'Cho hàm số $y=x^3-3x+1$ có đồ thị là (C). Kết luận nào sau đây là $\\textbf{đúng}$?',
#  'Cho đồ thị hàm số $y=f(x)$  như hình vẽ  bên. Đồ \nthị  trong  phương  án  nào  sau  đây  là  đồ  thị  hàm  số \n$y=\\left|f(x)\\right|$ ? }\\providecommand*{\\HA }\n\\providecommand*{\\HB }\n\\providecommand*{\\HC }\n\\providecommand*{\\HD',
#  'Cho hàm số $y=f(x)$ có bảng biến thiên như hình bên. Mệnh đề nào sau đây đúng?',
#  'Cho hàm số $y=ax^4-bx^2+c$ có đồ thị như hình vẽ. Khẳng định nào sau đây $\\textbf{đúng}$?',
#  'Cho hàm số $y=f(x)$ có bảng biến thiên như hình bên dưới đây. Hỏi đồ thị hàm số $y=f(x)$ có bao nhiêu đường tiệm cận?',
#  'Cho hàm số $y=\\dfrac{x+2}{x-1}$ có đồ thị như hình vẽ. Hình vẽ nào dưới đây  là đồ thị của hàm số $y=\\dfrac{|x|+2}{|x|-1}$?  $\\textbf{Hình 1}$ $\\textbf{Hình 2}$ $\\textbf{Hình 3}$ $\\textbf{Hình 4}$',
#  'Cho hàm số $f(x)$ có bảng biến thiên như hình vẽ.  Khẳng định nào dưới đây đúng?',
#  'Gọi $S$ là diện tích hình phẳng giới hạn bởi đồ thị hàm số $y=f(x),$ trục $Ox,$ hai đường thẳng $x = a, x = b.$ Chọn đáp án $\\textbf{đúng}$.',
#  'Tính diện tích $S$ của hình phẳng giới hạn bởi các đường  $y=x^2$, $y=2x^2-2x.$',
#  'Cho các hàm số $y=f(x), y= g(x)$ liên tục trên đoạn $[a;b], (a,b \\in \\mathbb R, a < b)$. Gọi $S$ là diện tích hình phẳng giới hạn bởi các đường $y=f(x), y =g(x), x=a, x=b$. Mệnh đề nào sau đây là đúng?',
#  'Cho hình phẳng $(H)$ giới hạn bởi $(P): y = 2x^2 + 4x + 3$ và các tiếp tuyến với $(P)$ đi qua điểm $A\\big(- 3; -23\\big)$. Tính diện tích $S$ của hình phẳng $(H)$.',
#  'Tính diện tích hình phẳng giới hạn bởi các đồ thị của hàm số $y = 2 - \\vert x\\vert$ và $y = x^2$.',
#  'Diện tích hình phẳng giới hạn bởi các đường $y=x^2-x,$ $y=0,$ $x=0$ và $x=2$ được tính bởi công thức',
#  'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị hàm số $y=x^2+1$, trục hoành và các đường thẳng $x=-1,x=2$.',
#  'Cho hàm số $ y=f(x) $ liên tục trên $ \\mathbb{R} $ và hàm số $ y=g(x)=x.f(x^2) $ có đồ thị trên đoạn $ [0;2] $ như hình vẽ bên. Biết diện tích miền được gạch chéo là $ S=\\dfrac{5}{2} $, tính tích phân $ \\displaystyle I=\\int_{1}^{4}f(x)\\,\\mathrm{d}x $. ',
#  'Với giá trị nào của $m$ thì diện tích hình phẳng được giới hạn bởi đồ thị hàm số $y = x^4 + 2mx^2 + m^2$ và các đường thẳng $y = 0$, $x = 0$, $x = 1$ là $\\dfrac{28}{15}$?',
#  'Cho hàm số $y=ax^4+bx^2+c$ có đồ thị như hình dưới đây. Chọn đáp án đúng. ',
#  'Đường cong trong hình bên là đồ thị của một hàm số nào dưới đây.',
#  'Cho bảng biến thiên của hàm số $y=f(x)$ trên nửa khoảng  $(-3;2]$  như hình vẽ bên. \nKhẳng định nào dưới đây $\\textbf{sai}$?',
#  'Tính diện tích $S$ của phần hình phẳng giới hạn bởi đường parabol đi qua gốc tọa độ và hai đoạn thẳng $AC$ và $BC$ như hình vẽ bên.$\\\\$\n',
#  'Diện tích hình phẳng giới hạn bởi đồ thị hàm số $y=4-x^2$ và $y=x+2$ là',
#  'Tính diện tích $S$ của hình phẳng được tô đậm trong hình vẽ bên.',
#  'Tính diện tích hình phẳng giới hạn bởi đồ thị hàm số $y = x^2  - 3x + 2$, đường thẳng $x = 0$, $x = 3$ và trục $Ox$.',
#  "Cho hàm số $f(x)$ liên tục trên $\\mathbb{R}.$ Đồ thị của hàm số $y=f'(x)$ được cho như hình vẽ bên. Diện tích các hình phẳng $(K),$ $(H)$ lần lượt là $\\dfrac{5}{12}$ và $\\dfrac{8}{3}.$ Biết $f(-1)=\\dfrac{19}{12},$ tính $f(2).$",
#  'Cho $(C)$ là cung của đường cong $y=-x^3+x$ với $x\\in \\left[0; 1\\right].$ Tìm tất cả các giá trị thực của tham số $k$ để đường thẳng $d: y=(k-2)x$ chia hình phẳng giới hạn bởi cung $(C)$ và trục hoành $Ox$ thành hai phần có diện tích bằng nhau.',
#  'Cho đồ thị hàm số $y=x^3$ trên đoạn $\\left[0;1 \\right]$ và một số thực $t\\in \\left[0;1 \\right]$. Gọi $S_1$ là diện tích hình phẳng giới hạn bởi các đường $y=x^3, y=t^3,x=0$ và $S_2$ là diện tích hình phẳng giới hạn bởi các đường $y=x^3, y=t^3,x=1.$ Gọi $m, M$ lần lượt là giá trị nhỏ nhất, giá trị lớn nhất của $S_1 + S_2$. Tính $2M+16m.$',
#  'Tính diện tích $S$ của hình phẳng giới hạn bởi hai đường $y^2-3x+2=0$ và $x^2-3y+2=0$.',
#  'Cho hàm số $y=\\dfrac{2x+3}{x+2}$ có đồ thị $(C).$ Gọi $M, N$ là hai điểm thuộc hai nhánh khác nhau của $(C).$ Tìm giá trị nhỏ nhất của độ dài đoạn thẳng $MN.$',
#  'Cho hàm số $y=\\dfrac{x+b}{cx+d}$ có đồ thị như hình vẽ. Khẳng định nào dưới đây đúng?',
#  'Tìm tất cả các giá trị của $m$ để bất phương trình $x^3+3x^2+1-m\\ge 0$ nghiệm đúng với $\\forall x\\in [-1; 1]$.',
#  'Đồ thị trong hình vẽ bên là đồ thị của hàm số nào trong các hàm số dưới đây?',
#  'Cho đồ thị hàm số bậc $4$ trùng phương $y=ax^4+bx^2+c$ có đồ thị như hình bên dưới. Dấu của các hệ số $a$, $b$, $c$ là',
#  'Bảng biến thiên ở hình bên là của hàm số nào sau đây?',
#  'Cho hàm số $y=f(x)$ xác định, liên tục trên $\\mathbb{R}$ và có bảng biến thiên như sau: Mệnh đề nào dưới đây đúng?',
#  'Cho các hàm số \\(y=f(x)\\) và \\(y=g(x)\\) liên tục trên \\([a;b]\\). Công thức tính diện tích \\(S\\) của hình thang cong giới hạn bởi $2$ đồ thị hàm số trên và các đường thẳng \\(x=a\\), \\(x=b\\) là',
#  'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị hàm số $y=x^2+2x+3$, trục $Ox$ và các đường thẳng $x=-2$, $x=1$.',
#  'Gọi $S$ là số đo diện tích của hình phẳng giới hạn bởi hai đồ thị hàm số $y=2{{x}^{2}}+3x+1$, $y={{x}^{2}}-x-2$. Tính $\\cos \\left( \\dfrac{\\pi }{S} \\right)$.',
#  'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị hàm số $y=\\ln x$, trục hoành và hai đường thẳng $x=1$, $x=25$.',
#  'Tính diện tích hình phẳng giới hạn bởi đồ thị của hàm số $y = x^3 - 3x^2 + x + 1$ và đường thẳng $y = x - 3$.',
#  'Cho hình phẳng $(H)$ giới hạn bởi các đường $y=x^2$, $y=0$, $x=0$, $x=4$. Đường thẳng $y=k \\ (0<k<16)$ chia hình $(H)$ thành hai phần có diện tích $S_1$, $S_2$ (hình vẽ). Tìm $k$ để $S_1 = S_2$.',
#  'Tính diện tích hình phẳng $S$ giới hạn bởi đồ thị của các hàm số $y=x^2,$ $y=\\dfrac{x^2}{27},$ $y=\\dfrac{27}{x}$.',
#  'Hình vẽ bên là đồ thị của một trong bốn hàm số được liệt kê ở các phương án A, B, C, D dưới đây. Hàm số đó là hàm số nào? ',
#  'Đường cong trong hình bên là đồ thị của một hàm số trong bốn hàm số được liệt kê ở bốn phương án A, B, C, D dưới đây. Hỏi hàm số đó là hàm số nào?',
#  'Hàm số $y=ax^4+bx^2+c \\ (a\\neq 0)$ có đồ thị như hình bên. Xác định dấu của $a,b,c$.',
#  'Đồ thị sau đây là của hàm số nào?',
#  'Hàm số nào trong các hàm số cho dưới đây có đồ thị là hình vẽ bên?',
#  'Cho hàm số $y=f(x)$ liên tục trên $\\mathbb{R}\\setminus\\{0\\}$ và có bảng biến thiên như hình dưới Khẳng định nào sau đây $\\textbf{đúng}$?',
#  'Cho hàm số $y=ax^3+bx^2+cx+d$ có đồ thị như hình vẽ. Khẳng định nào dưới đây đúng?',
#  'Cho hình phẳng $\\mathcal D$ giới hạn bởi đường cong $y=\\sqrt{2+\\sin x}$, trục hoành và các đường thẳng $x=0$, $x=\\pi$. Khối tròn xoay tạo thành khi quay $\\mathcal{D}$ quanh trục hoành có thể tích $V$ bằng bao nhiêu?',
#  'Cho parabol $\\left(P\\right):y=x^{2}+1$ và đường thẳng $\\left(d\\right):y=mx+1$ ($m$ không âm). Giá trị $m$ thuộc khoảng nào sau đây để diện tích hình phẳng giới hạn bởi $\\left(P\\right)$ và $\\left(d\\right)$ bằng $36$ (đơn vị diện tích).',
#  'Tính diện tích hình phẳng giới hạn bởi các đồ thị các hàm số $y=\\sin x, y=x-\\pi$ và đường thẳng $x=0$.',
#  'Tính diện tích hình phẳng giới hạn bởi parabol $y=x^2$ và các đường thẳng $y=1,x=0,x=2.$',
#  'Parabol $(P): y=2x$ chia hình phẳng giới hạn bởi đường tròn $x^2+y^2=8$ thành hai phần: phần bên trong $(P)$ có diện tích $S_1$, phần còn lại có diện tích $S_2$ (xem hình vẽ bên). Tính tỉ số $k=\\dfrac{S_1}{S_2}$ (làm tròn đến hàng phần trăm).',
#  'Cho hàm số $y=f(x)$ xác định trên $\\mathbb{R}\\setminus\\{-2\\},$ liên tục trên mỗi khoảng xác định và có bảng biến thiên như sau. Khẳng định nào dưới đây $\\textbf{sai}$?',
#  'Đường cong trong hình vẽ là đồ thị của một hàm số trong bốn hàm số được liệt kê ở các phương án $\\textbf{A, B, C, D}$. Hỏi hàm số đó là hàm số nào?',
#  'Đồ thị ở hình bên là đồ thị của hàm số nào?',
#  "Cho đồ thị của ba hàm số $y=f(x)$, $y=f'(x)$, $y=f''(x)$ được mô tả bằng hình vẽ bên. Hỏi đồ thị của các hàm số $y=f(x)$, $y=f'(x)$ và $y=f''(x)$ theo thứ tự, lần lượt tương ứng với đường cong nào?",
#  'Tính tổng các hoành độ của  những  điểm thuộc đồ thị hàm số  $(C): y=x^3-3x^2+2$ cách đều  hai điểm $A(12;1)$ và  $B(-6;3)$.',
#  'Trong các hàm số được cho ở các phương án $\\textbf{A}$, $\\textbf{B}$, $\\textbf{C}$, $\\textbf{D}$, hàm số nào có đồ thị được cho như hình vẽ?',
#  'Cho hàm số $y=f(x)$ xác định trên $\\mathbb{R}\\setminus \\{1\\}$, liên tục trên mỗi khoảng xác định và có bảng biến thiên như bên dưới. Tìm tập hợp tất cả các giá trị thực của tham số $m$ sao cho phương trình $f(x)=m$ có nghiệm duy nhất.',
#  'Đường cong trong hình vẽ bên là đồ thị của một trong bốn hàm số được liệt kê ở bốn phương án $\\textbf{A, B, C, D}$ dưới đây. Hỏi hàm số đó là hàm số nào?',
#  'Đường cong trong hình bên là đồ thị của hàm số được liệt kê trong bốn phương án $\\textbf{A, B, C, D}$ dưới đây. Hỏi hàm số đó là hàm số nào?',
#  'Cho hàm số $y=ax^4+bx^2 +c$ có đồ thị như hình vẽ. Khẳng định nào dưới đây đúng?',
#  'Cho hàm số $f(x)$ có bảng biến thiên như bảng dưới đây. Trong các khẳng định sau, khẳng định nào đúng?',
#  'Diện tích hình phẳng giới hạn bởi hai đồ thị hàm số $y=x^2-x+1$, $y=x+1$ là',
#  'Diện tích hình phẳng giới hạn bởi các đường $y=mx\\cos x$, $Ox$, $x=0$, $x=\\pi$ bằng $3\\pi$. Khi đó, giá trị của $m$ là',
#  'Tính diện tích $S$ của hình phẳng giới hạn bởi hai đường cong $y=x^3-x$ và $y=x-x^2.$',
#  'Tính diện tích hình phẳng  giới hạn bởi  các  đường \\ $y=2^x,$ $y=3-x$  và  $x=0$.',
#  'Cho $(H)$ là hình phẳng giới hạn bởi đồ thị ${\\displaystyle (C): y = 4x - x^2}$ và trục hoành ở hình vẽ bên. Đường thẳng $y = m$ chia $(H)$ thành hai phần có diện tích bằng nhau. Biết $m = a + \\sqrt[3]{b}$ với $a$, $b$ là các số hữu tỉ, tính $S = a\\cdot b$.',
#  'Tính diện tích hình phẳng giới hạn bởi đồ thị của hàm số $y=x^2+1$ và đường thẳng $y=x+3$.',
#  'Cho hàm số $y = \\dfrac{1}{3}x^3 + mx^2 - 2x - 2m - \\dfrac{1}{3}$, ($m$ là tham số) có đồ thị là $(C)$. Có tất cả bao nhiêu giá trị của $m \\in \\left(0; \\dfrac{5}{6}\\right)$ để hình phẳng giới hạn bởi đồ thị $(C)$ và các đường thẳng $x = 0,$ $x = 2,$ $y = 0$ có diện tích bằng $4$?',
#  'Tính diện tích hình phẳng giới hạn bởi đồ thị hàm số $y=x^3$, trục hoành và các đường thẳng $x=-1,x=2.$',
#  'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị các hàm số $y=x^{2}-2x+3$ và $y=3$.',
#  "Cho hàm số $y=f(x)$ xác định và có đạo hàm $f'(x).$ Đồ thị của hàm số $f'(x)$ như hình bên. Khẳng định nào sau đây là $\\textbf{đúng}$?",
#  'Đồ thị hàm số $y = \\dfrac{x+1}{-x+1}$ có dạng nào trong các dạng sau đây?',
#  'Hàm số  $y=ax^3+bx+c$ có  đồ thị như hình vẽ bên. Tìm giá trị của  $a,b,c$.',
#  'Cho hàm số $y=f(x)$ có bảng biến thiên như hình bên. Tìm tập hợp tất cả các giá trị thực của tham số $m$ để phương trình $f(x)=m$ có ba nghiệm thực phân biệt.',
#  'Đường cong trong hình vẽ là đồ thị của một trong bốn hàm số được liệt kê ở bốn phương án $A$, $B$, $C$, $D$ dưới đây. Hỏi hàm số đó là hàm số nào?',
#  'Cho hàm số $y=f\\left(x\\right)$ và phần hình phẳng $\\left(H\\right)$ được gạch chéo như hình vẽ bên. Công thức tính diện tích hình phẳng $\\left(H\\right)$ là',
#  'Parabol $(P): y^2=2x$ cắt đường tròn $(C): x^2+y^2=8$ tại hai điểm $A$ và $B$. Diện tích của hình phẳng được gạch chéo ở hình bên được tính theo công thức nào?',
#  'Cho hai hàm số $y=f(x)$, $y=g(x)$ liên tục trên $[a;b].$ Diện tích hình giới hạn bởi hai đồ thị hàm số $y=f(x)$, $y=g(x)$ và hai đường $x=a$, $x=b$ được tính bởi công thức nào sau đây?',
#  'Tính diện tích hình phẳng giới hạn bởi các đường thẳng $x=0,x=1$, đồ thị hàm số $y=x^4+3x^2+1$ và trục hoành.',
#  'Parabol $y=\\dfrac{x^2}{2}$ chia hình tròn có tâm tại gốc tọa độ, bán kính bằng $2\\sqrt{2}$ thành hai phần có diện tích $S_1,S_2$ như hình vẽ bên. Tính $\\dfrac{S_2}{S_1}$.',
#  'Tính diện tích hình phẳng giới hạn bởi các đường $y = 2 + \\sin x$, $y = 1 + \\cos^2x$, $x = 0$ và $x = \\pi.$',
#  'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị hàm số $y=3x^2-2x+1$ và các đường thẳng $y=0, x=2, x=3$.',
#  'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị của các hàm số $y=\\left(\\mathrm{e}+1\\right)x$ và $y=\\left(1+\\mathrm{e}^x\\right)x$.',
#  'Cho hàm số $y=f(x)$ xác định và liên tục trên đoạn $[-2;2]$ và có đồ thị là đường cong như trong hình vẽ bên. Điểm cực tiểu của đồ thị hàm số $y=f(x)$ trên đoạn $[-2;2]$ là',
#  'Cho hàm số $y=ax^3+bx^2+cx+d \\,(a\\neq 0)$ có đồ thị như hình vẽ bên. Khẳng định nào sau đây đúng?',
#  'Tìm $a$, $b$, $c$ để hàm số $y=\\dfrac{ax+2}{cx+b}$ có đồ thị như hình bên.',
#  'Cho hàm số $y=f(x)=x^3+ax^2+bx+4$ có đồ thị $(C)$ như hình vẽ. Hỏi $(C)$ là đồ thị của hàm số $y=f(x)$ nào?',
#  'Bảng  biến thiên  sau là  bảng  biến thiên của một trong các hàm số được liệt kê ở các  phương án A, B, C, D dưới  đây. Hỏi đó là hàm số  nào?\n\n',
#  'Hàm số nào dưới đây có đồ thị nhận $Oy$ làm trục đối xứng?',
#  'Đường cong trong hình vẽ bên là đồ thị của hàm số nào trong các hàm số dưới đây? ',
#  'Cho hàm số $y=x^3+ax^2+bx+c\\ (a,b,c\\in \\mathbb{R})$ có đồ thị như hình vẽ. Khẳng định nào sau đây $\\textbf{sai}$? ',
#  'Tính diện tích $S$ của hình phẳng giới hạn bởi các đường $y=\\sqrt{x}, y=x^{3}$.',
#  'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị hàm số $y=3x^2+1$ và đồ thị $y=3x+1$.',
#  'Tính diện tích hình phẳng giới hạn bởi đồ thị hàm số $y=x^3+3x^2-x$ và đồ thị hàm số $y=2x^2+x$.',
#  'Cho Parabol $(P):y=x^2$. Hai điểm $A$, $B$ di động trên $(P)$ sao cho $AB=2$. Gọi $S$ là diện tích hình phẳng giới hạn bởi Parabol $(P)$ và đoạn thẳng $AB$. Tìm giá trị lớn nhất của $S$.',
#  'Tính diện tích hình phẳng $(H)$ giới hạn bởi các đường $y=x^2-2x,$ $y=x.$',
#  'Đồ thị trong hình bên là đồ thị của một hàm số trong bốn hàm số được liệt kê ở bốn phương án $\\textbf{A, B, C, D}$ dưới đây. Hỏi hàm số đó là hàm số nào?',
#  'Bảng biến thiên sau đây là của hàm số nào?',
#  'Cho hàm số $y=f(x)$ liên tục và có đạo hàm cấp hai trên $\\mathbb{R}.$ Đồ thị của các hàm số $y=f(x), y=f\'(x), y=f"(x)$ lần lượt là các đường cong nào trong hình bên?',
#  'Hình bên là đồ thị của hàm số nào dưới đây? ',
#  'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị các hàm số $y=|x|$, $y=x^2-2$.',
#  'Diện tích hình phẳng giới hạn bởi các đường $y=x^2-2x-8$ và $y=2x-3$ là',
#  'Gọi $S$ là diện tích hình phẳng giới hạn bởi các đường $y=x^2-2x, y=x$. Mệnh đề nào sau đây đúng?',
#  'Tính diện tích hình phẳng giới hạn bởi đồ thị hàm số $y=x^2+2$ và $y=3x$.',
#  'Tính diện tích $S$ của hình phẳng giới hạn bởi các đường $y=\\ln x$, $y=0$ và $x=e^2$.',
#  'Hàm số $y=ax^3 + bx^2 + cx + d$ có đồ thị như hình vẽ sau. Chọn nhận xét đúng.',
#  'Cho hàm số $y=f(x)$\tcó đồ thị như trong hình bên.\n Tìm tập hợp tất cả các giá trị thực của $m$ để đồ thị hàm số $y=f(|x|+m)$ có 5 điểm cực trị.',
#  'Bảng biến thiên trong hình vẽ là bảng biến thiên của một trong bốn hàm số được liệt kê ở các phương án A, B, C, D dưới đây. Hỏi hàm số đó là hàm số nào?',
#  'Đường cong trong hình bên là đồ thị của hàm số nào trong các hàm số sau đây?',
#  'Hàm số $y=f(x)$ xác định trên $\\mathbb{R},$ có đồ thị là đường cong như hình bên. Mệnh đề nào dưới đây đúng?',
#  '  Đường cong trong hình bên là đồ thị của một hàm số trong bốn hàm số được liệt kê ở bốn phương án $\\textbf{A, B, C, D}$ dưới đây. Hỏi hàm số đó là hàm số nào?',
#  ' {} Cho hàm số $y=f(x)$ liên tục trên đoạn $[-2;3],$ có bảng biến thiên như hình bên. Khẳng định nào sau đây là khẳng định đúng?',
#  'Cho hàm số $ y = ax^4 + bx^2 + c$ có đồ thị như hình vẽ bên.\nMệnh đề nào dưới đây $\\textbf{đúng}$?\n',
#  'Cho hàm số $y=ax^4+bx^2+c$ có đồ thị như hình bên. Mệnh đề nào sau đây đúng?',
#  'Cho hàm số $y=f(x)$ có đồ thị như hình vẽ dưới đây. Diện tích hình phẳng $S$ (phần tô màu trong hình vẽ) được tính bởi công thức nào?',
#  'Tính diện tích hình phẳng giới hạn bởi parabol $(P): y^2=2x$ và đường thẳng $x=2$.',
#  'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị hàm số $y=\\dfrac{2x+1}{x+1}$, trục $Ox$ và hai đường thẳng $x=1, x=3$.',
#  'Diện tích hình phẳng giới hạn bởi các đường $y=x(4-x)^2$, trục hoành và hai đường thẳng $x=1, x=5$ là',
#  'Diện tích hình phẳng giới hạn bởi các đường $y=-x^2+6x$ và $y=(x-6)^2$ là',
#  'Cho hình phẳng (H) giới hạn bởi các đường cong $y=x^2-2x+1$ và $y=-x^2+5x+1$. Đặt diện tích của hình (H) là $S=\\dfrac{1}{a} \\left( \\dfrac{b}{c}\\right)^d$ với $a$, $b$, $c$, $d$ là các số nguyên dương và $\\dfrac{b}{c}$ là phân số tối giản. Tính $Q=ab-cd$.',
#  'Cho hàm số $y=f(x)$ liên tục trên $\\mathbb{R}$, có đồ thị cắt trục $Ox$ tại các điểm có hoành độ lần lượt bằng $-3, 0$ và $4$ như hình bên. Tìm công thức tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị hàm số $y=f(x)$ và trục $Ox.$\n',
#  'Cho hàm số $y=f(x)$ có đồ thị như hình vẽ. Tìm số điểm cực trị của hàm số $y=\\left|f(x-1)\\right|$.',
#  'Biết rằng hàm số $y=4x^3-6x^2+1$ có đồ thị như hình vẽ bên. Phát biểu nào sau đây là phát biểu đúng?',
#  'Cho hàm số $y=\\dfrac{ax+b}{cx+d}$ có đồ thị như hình bên. Mệnh đề nào dưới đây đúng?',
#  'Hàm số nào dưới đây có tập xác định là $\\mathbb{R}\\backslash{\\{1\\}}$?',
#  'Hàm số nào có bảng biến thiên dưới đây?$\\\\$',
#  'Cho hàm số $y=f(x)$ xác định, liên tục trên đoạn $[-1;3]$ và có đồ thị như hình vẽ bên. $\\\\$\nKhẳng định nào sau đây đúng?',
#  'Hình vẽ bên là đồ thị của hàm số nào trong các hàm số sau?',
#  'Cho hàm số $y=f(x)$ liên tục trên đoạn $[-2;2],$ và có đồ thị là đường cong như trong hình vẽ bên. Tìm số nghiệm trên đoạn $[-2;2]$ của phương trình $|f(x)|=1.$',
#  'Cho hàm số $y=f(x)$ có bảng biến thiên như bên dưới. Mệnh đề nào dưới đây là mệnh đề đúng?',
#  'Tính diện tích hình phẳng giới hạn bởi các đường $y=x^4$, $y=0$, $x=5.$',
#  'Tính diện tích hình phẳng được tô đậm ở hình bên.',
#  'Cho parabol như hình vẽ. Hãy tính diện tích hình phẳng giới hạn bởi parabol và trục hoành.',
#  'Diện tích hình phẳng giới hạn bởi các đường $x=a, x=b$, đồ thị hàm số $y=f(x)$ liên tục trên đoạn $[a;b]$ và trục $Ox$ là',
#  'Diện tích hình phẳng giới hạn bởi đồ thị hàm số $y=x^3$, trục hoành và hai đường thẳng $x=-1, x=2$ là',
#  'Cho hàm số $y=\\dfrac{ax+b}{cx+d}$ có đồ thị như hình vẽ. Mệnh đề nào dưới đây $\\textbf{đúng}$?',
#  'Cho hàm số $y=f(x)$ xác định, liên tục trên $\\mathbb{R}$ và có bảng biến thiên như dưới đây. Khẳng định nào sau đây là khẳng định {đúng}?',
#  'Hàm số $y=f(x)$ liên tục trên $\\mathbb{R}$ và có bảng biến thiên như hình vẽ. Khẳng định nào sau đây là $\\textbf{sai}$?',
#  'Cho hàm số $y=f(x)$ có bảng biến thiên sau: Khẳng định nào sau đây $\\textbf{sai}$?',
#  '',
#  'Hình vẽ bên là đồ thị của hàm số $y=\\dfrac{ax+b}{cx+d}$. Mệnh đề nào sau đây $\\textbf{đúng}$?',
#  ' {} Đường cong trong hình bên là đồ thị của một trong bốn hàm số liệt kê ở bốn phương án $\\textbf{A, B, C, D}$ dưới đây. Hỏi hàm số đó là hàm số nào?',
#  'Cho hàm số $y=\\dfrac{ax+b}{x+1}$ có đồ thị như hình vẽ bên. Tìm khẳng định đúng trong các khẳng định sau.',
#  'Tìm trên đồ thị hàm số $y=-x^3+4x+2$ hai điểm phân biệt mà chúng đối xứng với nhau qua trục tung.',
#  'Đường cong trong hình vẽ là đồ thị của một trong bốn hàm số được liệt kê ở các phương án A, B, C, D dưới đây. Hàm số đó là hàm số nào?',
#  'Trong các hàm số sau, hàm số nào có đồ thị như hình vẽ dưới đây?',
#  'Cho hình phẳng giới hạn bởi các đường $(C):y=x^2$, trục hoành và tiếp tuyến của $(C)$ tại điểm $x_0=1$. Tính diện tích $S$ của hình phẳng đó.',
#  'Diện tích hình phẳng giới hạn bởi đồ thị hàm số $y=x^2+3x-2$ và $y=-x-2$ là',
#  'Tính diện tích hình phẳng giới hạn bởi các đường $y=2x^3+x^2+3x,$ $y=0, x=0, x=3.$',
#  'Tính diện tích hình phẳng giới hạn bởi các đường $x=1,x= \\textrm{e},y=0$ và $y=\\dfrac{\\ln x}{2\\sqrt{x}}.$',
#  'Tính diện tích $S$ của hình phẳng giới hạn bởi parabol $(P):y=3x^2+2$, trục hoành, trục tung và đường thẳng $x=2$.',
#  'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị hàm số $y=x^2+2x+1$, trục hoành và các đường thẳng $x=-1, x=3$.',
#  'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị hàm số $f(x)=x^2-x$, trục $Ox$ và hai đường thẳng $x=-1, x=1$.',
#  'Đồ thị sau đây là đồ thị của hàm số nào?',
#  'Hàm số  $y=ax^3+bx^2+cx+d \\left( a\\ne 0 \\right)$  có đồ thị sau. Khi đó, khẳng định nào sau đây là đúng?',
#  '  Cho đồ thị hàm số $y=a x^4+b x^2+c$ có đồ thị như hình vẽ bên. Chọn mệnh đề đúng trong các mệnh đề sau.',
#  'Cho hàm số $y=f(x)$ xác định, liên tục trên $\\mathbb{R}$ và có bảng biến thiên như hình dưới đây Khẳng định nào sau đây $\\textbf{đúng}$?',
#  'Trên mặt phẳng tọa độ $Oxy,$ cho phần hình phẳng được tô đậm như hình bên được giới hạn bởi một đồ thị hàm số đa thức bậc ba và một đường thẳng. Diện tích $S$ của phần tô đậm đó bằng bao nhiêu?',
#  'Tính diện tích hình phẳng giới hạn bởi đường cong $y =x^2 + x - 1$ và đường thẳng $y = 2x + 1$.',
#  'Tính diện tích hình phẳng giới hạn bởi các đường $y=x^2+4x, y=x-2.$',
#  'Cho hàm số $y = f(x)$ liên tục trên $\\big[a; b\\big]$. Công thức tính diện tích của hình phẳng giới hạn bởi đồ thị hàm số $y = f\\big(x\\big)$, trục hoành và hai đường thẳng $x = a$, $x = b$ là công thức nào sau đây?',
#  'Cho hàm số $y=f(x)$ liên tục trên đoạn $[a;b]$ và cắt trục hoành tại điểm $x=c$ (như hình vẽ). Gọi $S$ là diện tích hình phẳng được giới hạn bởi đồ thị của hàm số $y=f(x)$, trục hoành và hai đường thẳng $x=a,x=b$. Khẳng định nào sau đây là khẳng định $\\textbf{đúng}$?\n',
#  'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị của hàm số $y=\\mathrm{e}^x+x$ và các đường thẳng $x-y+1=0,\\, x=\\ln 5$.',
#  'Hình bên là đồ thị của hàm số nào?',
#  'Cho hàm số $y=ax^4+bx^2+c$ ($a\\neq 0$) và có bảng biến thiên như hình sau: Khẳng định nào sau đây là khẳng định đúng?',
#  'Tìm tập xác định $D$ của hàm số $y=\\log_2\\left(x^2-2x\\right).$',
#  'Hàm số có đồ thị như hình vẽ bên là',
#  'Cho hàm số bậc ba $y=ax^3+bx^2+cx+d$ có đồ thị như hình vẽ. Dấu của $a; b; c; d$ là',
#  'Đồ thị ở hình bên là đồ thị của hàm số nào?',
#  'Cho hàm số $y=ax^3+bx^2+cx+d$ có đồ thị như hình vẽ. Khẳng định nào sau đây đúng?',
#  ' $\\\\$Cho hàm số $y=f(x)$ xác định và liên tục trên đoạn $[-2;2]$ và có đồ thị là đường cong trong hình vẽ bên. Điểm cực tiểu của đồ thị hàm số $y=f(x)$ là',
#  "Cho hàm số $y=f(x)$ liên tục trên $\\mathbb{R}$ và có bảng xét dấu $f'(x)$ như sau: Mệnh đề nào sau đây là $\\textbf{sai}$?",
#  'Tính diện tích hình phẳng $ S $ được giới hạn bởi các đồ thị hàm số $y=x^2-x+3$ và đường thẳng $y=2x+1$',
#  'Cho hàm số $y=f(x)$ liên tục trên khoảng $\\mathbb{K},$ có đồ thị $(C)$ trên $\\mathbb{K}$ như hình vẽ bên. Khẳng định nào sau đây là đúng? ',
#  'Đường cong trong hình bên là đồ thị của một hàm số trong bốn hàm số được liệt kê ở bốn phương án $A,B,C,D$ dưới đây. Hỏi hàm số đó là hàm số nào?\n',
#  'Cho hàm số $y=f(x)$ liên trục trên khoảng $(-3;2)$, có bảng biến thiên như hình vẽ. Khẳng định nào sau đây là đúng?',
#  'Cho hàm số $y=f(x)$ liên tục trên $\\mathbb{R}$ và có bảng biến thiên như sau Trong các mệnh đề sau, mệnh đề nào $\\textbf{sai}$?',
#  'Cho hàm số $y=\\dfrac{3x-1}{2x+1}$ có đồ thị là $(C)$. Tìm tọa độ tâm đối xứng của đồ thị $(C)$.',
#  'Cho hàm số $y=ax^4+bx^2+c$ có đồ thị như hình bên. Xác định các hệ số $a$, $b$ và $c$.',
#  'Cho hàm số $y=f(x)$ xác định và liên tục trên khoảng $(-\\infty;+\\infty)$, có bảng biến thiên như hình vẽ. Mệnh đề nào sau đây $\\textbf{sai}$?$\\\\$\n',
#  'Đồ thị như hình bên là của hàm số nào trong các hàm số được liệt kê ở các phương án $\\textbf{A, B, C, D}$.',
#  'Hàm số  $y=f\\left( x \\right)$  có bảng biến thiên như hình vẽ sau. Dựa vào bảng biến thiên, phát biểu nào sau đây đúng?',
#  'Cho hàm số $y=x^4+2x^2+3$. Khẳng định nào trong các khẳng định sau đây là $\\textbf{sai}$?',
#  'Tìm tất cả các giá trị của tham số $m$ để phương trình $\\left|x\\right|^3-3x^2+2-m=0$ có 4 nghiệm phân biệt.',
#  'Tìm tất cả các giá trị thực của tham số $m$ để phương trình $4|x|^3-3|x|-1=mx-m$ có 4 nghiệm phân biệt.',
#  'Cho hàm số $y=f(x)$ liên tục trên $\\mathbb{R}$ và có bảng biến thiên sau: Khẳng định nào sau đây là khẳng định $\\textbf{đúng}$?',
#  'Tính diện tích hình phẳng giới hạn bởi hai đồ thị hàm số $y=\\sqrt{x},y=6-x$ và trục hoành.',
#  'Tính diện tích hình phẳng giới hạn bởi đường cong parabol $y=x^2-x+3$ và đường thẳng $y=2x+1.$',
#  'Gọi $(H)$  là hình phẳng  giới hạn bởi  đồ thị $(P)$ của  hàm số $y=6x-x^2$ và trục hoành. Hai đường thẳng  $y=m$  và  $y=n$ chia hình $(H)$  thành  ba  phần  có  diện tích bằng  nhau. Tính $P={(9-m)}^3 +{(9-n)}^3$.',
#  'Diện tích hình phẳng giới hạn bởi các đường \n$y=x^3-1,$ $y=0,$ $x=0,$ $x=2$   bằng',
#  'Cho hình phẳng giới hạn bởi các đường $y=\\sin x, y=\\cos x$ và $S_1, S_2$ là diện tích của các phần được gạch chéo như hình vẽ bên. Tính $S_1^2+S_2^2, x=\\dfrac{\\pi}{4}, x=\\dfrac{5\\pi}{4}$',
#  'Cho hình chóp $S.ABCD$ có đáy là hình vuông cạnh $a$, $SA\\perp (ABCD)$, $SA=a\\sqrt3$. Tính diện tích mặt cầu ngoại tiếp hình chóp $S.ABCD$.',
#  'Cho mặt cầu tâm $O$, bán kính $R=3$. Mặt phẳng $(\\alpha)$ cách tâm $O$ của mặt cầu một khoảng bằng 1, cắt mặt cầu theo một đường tròn. Gọi $P$ là chu vi đường tròn này, tính $P$.',
#  'Bé Na bơm không khí vào một quả bóng cao su hình cầu. Giả sử thể tích của quả bóng sau khi bơm thêm bằng 2 lần thể tích quả bóng trước khi bơm. Hỏi bán kính của quả bóng tăng lên mấy lần so với trước?',
#  'Một khối cầu có bán kính $2R$ thì có thể tích $V$ bằng bao nhiêu?',
#  'Một hình nón có thiết diện qua trục là một tam giác đều cạnh bằng $a$. Tính bán kính $R$ của mặt cầu ngoại tiếp hình nón theo $a$.',
#  'Để làm cống thoát nước cho một khu vực dân cư trên đường Hùng Vương, thị trấn\nKrông Năng người ta cần đúc $500$ ống hình trụ có đường kính trong và chiều cao của mỗi ống\nbằng $1\\;{\\rm m},$ độ dày của thành ống là $10\\; {\\rm cm}.$ Chọn mác bê tông là $250$ (tức mỗi ${\\rm m}^3$ bê tông cần dùng\n$7$ bao xi măng). Hỏi phải chuẩn bị bao nhiêu bao xi-măng để làm đủ số ống nói trên.',
#  'Một chậu nước hình bán cầu bằng nhôm có bán kính $R=20\\,\\textrm{cm}$ đặt trong một khung hình hộp chữ nhật (hình 1). Trong chậu chứa sẵn một khối nước hình chỏm cầu có chiều cao $h=10\\,\\textrm{cm}$. Bỏ vào trong chậu nước một viên bi kim loại hình cầu sao cho mặt nước dâng lên vừa phủ kín viên bi (hình 2). Bán kính của viên bi gần nhất với số nào sau đây?',
#  'Tính diện tích hình  phẳng  giới hạn bởi  parabol $y=x^2+4$  và  đường thẳng $y=x+4$.',
#  'Diện tích hình phẳng trong hình vẽ bên là',
#  'Tính diện tích hình phẳng giới hạn bởi đồ thị hàm số  $y=x^2$  và đường thẳng  $y=2x$.',
#  'Cho hàm số $y=\\dfrac{x^4}{2}-2m^2x^2+2.$ Tìm tập hợp tất cả các giá trị thực của tham số $m$ sao cho đồ thị của hàm số đã cho có cực đại và cực tiểu, đồng thời đường thẳng cùng phương với trục hoành qua điểm cực đại tạo với đồ thị một hình phẳng có diện tích bằng $\\dfrac{64}{15}.$',
#  'Cho hàm số $y=f(x)$ có đồ thị như hình vẽ. Diện tích $\\mathcal{S}$ của hình phẳng gạch chéo trong hình bên được tính theo công thức nào sau đây?$\\\\$\n',
#  ' {} Cho hình thang cong $(H)$ giới hạn bởi các đường $y=2^x$, $y=0$, $x=0$, $x=4$. Đường thẳng $x=a$ $(0<a<4)$ chia $(H)$ thành hai phần có diện tích là $S_1$ và $S_2$ như hình vẽ bên. Tìm $a$ để $S_2=4S_1$.',
#  'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị hàm số $y=x^4-2x^2+1$ và trục $Ox$.',
#  'Trong tất cả các hình chóp tứ giác đều nội tiếp mặt cầu có bán kính bằng $9$, tính thể tích\n$V$ của khối chóp có thể tích lớn nhất.',
#  'Cho hình chóp $S.ABC$ có đáy $ABC$ là tam giác đều cạnh $a$. Cạnh $SA$ vuông góc với mặt phẳng đáy $(ABC)$ và $SA=a\\sqrt{3}$. Tính thể tích khối cầu ngoại tiếp hình chóp.',
#  'Cho tứ diện $ABCD$ có $AB=CD=a, AC=BD=AD=BC=b$. Tính bán kính mặt cầu ngoại tiếp $R$ của tứ diện $ABCD$.',
#  'Cho mặt cầu $(S)$ có diện tích bằng $\\dfrac{8\\pi a^2}{3}$. Tìm bán kính mặt cầu $(S)$.',
#  'Cho hình chóp $S.ABCD$ có đáy là hình chữ nhật với $AB=a$, $BC=2a$. Mặt bên $SAB$ là tam giác vuông tại $S$ và thuộc mặt phẳng vuông góc với $(ABCD)$. Tính bán kính của mặt cầu ngoại tiếp hình chóp $S.ABCD$.',
#  'Một xí nghiệp chế biến thực phẩm muốn sản xuất những loại hộp hình trụ (có nắp cùng chất liệu) có dung tích 1 lít. Gọi $x$ (dm) là độ dài bán kính đáy của hình trụ. Tìm $x$ để sản xuất hình trụ tốn ít vật liệu nhất.',
#  'Từ miếng tôn hình vuông cạnh bằng $4 \\text{ dm}$ , người ta cắt ra hình quạt\ntâm $O$ bán kính $OA=4 \\text{ dm}$ (xem hình) để cuộn lại thành một chiếc\nphễu hình nón (khi đó $OA$ trùng với $OB$). Chiều cao của chiếc phễu có\nsố đo gần đúng (làm tròn đến $3$ chữ số thập phân) là',
#  'Người ta xếp $7$ viên bi có cùng bán kính $r$ vào một cái lọ hình trụ sao cho tất cả các viên bi đều tiếp xúc với đáy, viên bi nằm chính giữa tiếp xúc với $6$ viên bi xung quanh và mỗi viên bi xung quanh đều tiếp xúc với các đường sinh của lọ hình trụ. Khi đó diện tích đáy của cái lọ hình trụ là',
#  'Biết diện tích của hình phẳng giới hạn bởi các đường $ y=|\\ln x| $ và $ y=1 $ là $ S=a\\mathrm{e}+\\dfrac{b}{\\mathrm{e}} + c $,  với $ a, b, c $ là các số nguyên. Tính $ P=a+b+c $.',
#  'Cho hình thang cong $\\mathcal{H}$ giới hạn bởi các đường $y=\\dfrac{1}{x},$ $x=\\dfrac{1}{2},$ $x=2$ và trục hoành. Đường thẳng $x=k$ với $\\dfrac{1}{2}<k<2$ chia $\\mathcal{H}$ thành hai phần có diện tích là $S_1$ và $S_2$ như hình bên. Tìm tất cả các giá trị thực của $k$ để $S_1=3S_2.$',
#  'Diện tích hình phẳng giới hạn bởi đồ thị các hàm số $y = - x^2 + 2x + 1$ và $y = 2x^2 - 4x + 1$ là',
#  'Cho hình thang cong $(H)$ giớ hạn bới các đường $y=\\mathrm{e}^x, y=0, x=0, x=\\ln4$. Đương thẳng $x=k$ (với $0<k<\\ln4$) chia hình $(H)$ thành hai phần có diện tích $S_1,S_2$ như hình vẽ bên. Tìm $k$ để $S_1=2S_2.$',
#  'Tính diện tích $S$ của hình phẳng giới hạn bởi đồ thị hàm số $y=x^2 -x$ và trục hoành.',
#  'Cho hình chóp tam giác đều có cạnh đáy bằng $a$, góc giữa cạnh bên và mặt đáy là $60^\\circ$. Hỏi diện tích mặt cầu $(S)$ có tâm $O$ và tiếp xúc với các cạnh bên bằng bao nhiêu? ($O$ là tâm mặt đáy)',
#  "Cho lăng trụ đứng $ABCD.A'B'C'D'$ có đáy $ABCD$ là hình thang cân, $AD=2a,$ $AB=BC=CD=a,$ $AA'=2a.$ Tính diện tích $S$ của mặt cầu ngoại tiếp lăng trụ $ABCD.A'B'C'D'.$",
#  'Cho hình chóp $SABCD$ có $SA\\perp (ABC)$, $SA=a$, đáy là hình thang vuông tại $A$ và $B$, $AB=BC=a$ và $AD=2a$. Gọi $(S)$ là mặt cầu ngoại tiếp hình chóp $S.ACD$. Thể tích của khối cầu tạo nên bởi mặt cầu $(S)$ là',
#  'Thể tích của một khối cầu bằng $\\dfrac{32\\pi}{3} (\\textrm{cm}^3)$. Đường kính của khối cầu đó là',
#  'Tính thể tích $V$ của khối cầu có độ dài đường kính bằng $6a$.',
#  'Cho hình chóp $S.ABC$ có đáy $ABC$ là tam giác đều cạnh $a$, mặt bên $SAB$ là tam giác đều và nằm trong mặt phẳng vuông góc với mặt phẳng đáy. Tính thể tích của khối cầu ngoại tiếp hình chóp đã cho.',
#  'Cho hình chóp $S.ABC$ có đáy $ABC$ là tam giác vuông cân tại $B$, đường thẳng $SA$ vuông góc với mặt phẳng $(ABC)$ và $SA=AB=a$. Tính diện tích $S$ của mặt cầu ngoại tiếp hình chóp $S.ABC$.',
#  'Cho hình chóp $S.ABC$ có $SA\\perp (ABC)$, tam giác $ABC$ vuông tại $B, AB=a, BC=a\\sqrt{3}$ và $SA=2a$. Tính diện tích $S$ của mặt cầu ngoại tiếp hình chóp $S.ABC$.',
#  'Cho hình chóp tứ giác đều $S.ABCD$ có cạnh bên và cạnh đáy đều bằng $a$. Có một mặt cầu đi qua $A$ và tiếp xúc với cạnh $SB$, $SD$ tại trung điểm mỗi cạnh. Tính diện tích mặt cầu đó.',
#  'Cho hình chóp $S.ABC$ có đáy $ABC$ là tam giác đều cạnh $a$, $SA=a\\sqrt{2}$ và $SA\\perp (ABC)$. Tính theo $a$ thể tích $V$ của khối cầu ngoại tiếp hình chóp $S.ABC$.',
#  'Cho hình lập phương có cạnh bằng $a$ và tâm $O.$ Tính thể tích khối cầu tâm $O$ tiếp xúc với các mặt của hình lập phương.',
#  'Cho hình chóp $S.ABCD$ có đáy $ABCD$ là hình chữ nhật, $AB=a, AD=2a,$ tam giác $SAB$ đều và nằm trong mặt phẳng vuông góc với đáy. Gọi $M, N$ lần lượt là trung điểm của các cạnh $AD,$ $DC.$ Tính bán kính $R$ của mặt cầu ngoại tiếp hình chóp $S.DMN.$',
#  'Một người thợ có một khối đá hình trụ. Kẻ hai đường kính $MN, PQ$ của hai đáy sao cho $MN\\bot PQ$. Người thợ đó cắt khối đá theo các mặt đi qua 3 trong 4 điểm $M, N, P, Q$ để thu được khối đá có hình tứ diện $MNPQ$ bằng $30\\mbox{dm}^3$. Hãy tính thể tích của lượng đã bị cắt bỏ ( làm tròn kết quả đến 1 chữ số thập phân).',
#  'Người ta bỏ 3 quả bóng bàn cùng kích thước vào trong một chiếc hộp hình trụ có đáy bằng hình tròn lớn của quả bóng bàn và chiều cao bằng $3$ lân đường kính của quả bóng bàn. Gọi $S_1$ là tổng diện tích của $3$ quả bóng bàn, $S_2$ là diện tích xung quanh của hình trụ. Tỉ số $\\dfrac{S_1}{S_2}$ bằng',
#  'Một tấm nhôm hình chữ nhật có hai kích thước là $a$ và $2a$ ($a$ là độ dài có sẵn). Người ta cuốn tấm nhôm đó thành một hình trụ. Tính bán kính đáy của hình trụ nếu hình trụ được tạo thành có chiều dài đường sinh bằng $2a$.',
#  "Một khối cầu bằng thép có bán kính $5$ m. Để là một chiếc lu đựng nước, người ta cắt bỏ hai phần bằng hai mặt phẳng cách nhau $6$ m và cùng vuông góc với đường kính $AB$, tạo thành thiết diện ở hai đáy là hình tròn tâm $I$ và $I'$ như hình vẽ.$\\\\$\nMặt phẳng ở đáy dưới (chứa $I$) cách tâm $O$ của khối cầu $a$ m. Sau khi cắt, đáy dưới được hàn kín lại bằng tấm thép hình tròn, đáy trên để trống. Giả sử mỗi mét vuông thép có giá $100.000$ đồng. Tính số tiền tối thiểu mua thép để hàn kín đáy dưới biết chiếc lu chứa được đúng $126$ m$^3$ nước. (Coi bề dày của khối cầu và tám thép ở đấy không đáng kể, kết quả làm tròn đến đơn vị nghìn đồng.)",
#  'Tính diện tích hình phẳng giới hạn bởi đồ thị hàm số $y=x^2-4x+3$ và trục $Ox.$',
#  "Cho lăng trụ đứng $ABC.A'B'C'$ có đáy là tam giác vuông cân và các cạnh $AB=BC=2, AA' =2\\sqrt{2}$. Tính thể tích khối cầu ngoại tiếp tứ diện $AB'A'C$.",
#  'Cho hình chóp tứ giác đều \\(S.ABCD\\) có cạnh đáy bằng \\(3\\sqrt{2}a\\), cạnh bên bằng \\(5a\\). Tính bán kính \\(R\\) của mặt cầu ngoại tiếp hình chóp \\(S.ABCD\\).',
#  'Cho hình chóp $S.ABC$ có đáy $ABC$ là tam giác vuông tại $B$ với $AB=a,$ $BC=2a,$ $SA=2a$ và $SA$ vuông góc với mặt phẳng $(ABC).$ Tính thể tích $V$ của mặt cầu ngoại tiếp hình chóp $S.ABC.$',
#  'Cho hình chóp $S.ABCD$ có đáy $ABCD$ là hình thoi cạnh $a$, góc $\\widehat{BAD} = 60^{\\circ}$. Hình chiếu vuông góc của $S$ trên mặt phẳng $(ABCD)$ là trung điểm $M$ của cạnh $AB$. Biết $SD = a\\sqrt{3}$, tính thể tích $V$ của khối cầu ngoại tiếp hình chóp $S.ABCD$.',
#  'Cho hình chóp $S. ABCD$ có đáy là hình thang vuông tại $A$ và $B$, $SA$ vuông góc với đáy. Biết $SA=a \\sqrt 2$, $AD=2AB=2BC=2a$. Tính bán kính mặt cầu ngoại tiếp hình chóp $S. BCD$.',
#  'Hình chóp $S.ABCD$ có đáy $ABCD$ là hình thoi cạnh bằng 1, $\\widehat{ABC}=60^\\circ$. Hai mặt phẳng $(SAD)$ và $(SAB)$ cùng vuông góc với mặt phẳng $(ABCD)$. Cạnh $SB$ tạo với mặt phẳng $(ABCD)$ góc $60^\\circ$. Tính diện tích mặt cầu ngoại tiếp tứ diện $S.ABD$.',
#  'Cho hình chóp $S.ABC$, có đáy $ABC$ là tam giác vuông tại $A$, $SA\\perp (ABC)$ và $AB=2$, $AC=4$, $SA=\\sqrt{5}$. Mặt cầu đi qua các đỉnh của hình chóp $S.ABC$ có bán kính bằng bao nhiêu?',
#  'Cho hình chóp $S.ABCD$ có đáy là hình chữ nhật với $AD=a\\sqrt{2}$, $AB=a$, góc giữa hai mặt phẳng $(SBD)$ và $(ABCD)$ bằng $60^\\circ$. Gọi $H$ là trung điểm của $BC$. Biết mặt bên $SBC$ là tam giác cân tại đỉnh $S$ và thuộc mặt phẳng vuông góc với mặt phẳng đáy. Bán kính mặt cầu ngoại tiếp hình chóp $S.BHD$ là',
#  'Cho hình chóp $S.ABCD$ có đáy $ABCD$ là hình vuông cạnh bằng 1. Mặt bên $SAB$ là tam giác đều và nằm trong mặt phẳng vuông góc với mặt phẳng đáy. Hỏi bán kính $R$ của mặt cầu ngoại tiếp hình chóp $S.ABCD$ bằng bao nhiêu?',
#  'Cho hình chóp  $S.ABCD$  có đáy  $ABCD$  là hình vuông cạnh  $2\\sqrt{2},$  cạnh bên  $SA$  vuông góc với mặt phẳng đáy. \nMặt phẳng  $(\\alpha)$  qua  $A$  và vuông góc với  $SC$  cắt các cạnh  $SB$,  $SC$,  $SD$ lần lượt tại các điểm  $M$,  $N$,  $P$. \nTính thể tích  $V$  của khối cầu ngoại tiếp tứ diện $CMNP$.',
#  'Diện tích $S$ của mặt cầu có bán kính $R$ là',
#  'Một thùng đựng nước hình trụ có chiều cao $6\\textrm{\\,m}$ và bán kính $2\\textrm{\\,m}$. Đổ vào thùng một lượng nước nhất định, khi đặt thùng nằm ngang thì mực nước là $3\\textrm{\\,m}$ (như hình vẽ). Tính chiều cao mực nước khi đặt thùng đứng lên (quy tròn thành hàng phần nghìn).',
#  '  Tìm $a$ để diện tích hình phẳng được giới hạn bởi đường cong $y = \\dfrac{2}{x}$, $Ox$, $x = 1$, $x = a$ $(a>1)$ bằng 2.',
#  'Diện tích hình phẳng giới hạn bởi các đường $y=\\dfrac{x}{\\sqrt{1+x^2}}$, trục hoành và đường thẳng $x=1$ là $S=\\sqrt{a}-b$. Khi đó, $a+b$ bằng',
#  'Cho $y=f(x)$ là hàm số liên tục trên đoạn $[a;b]$. Hình phẳng giới hạn bởi các đường $f=(x)$, $y=0$, $x=a$ và $x=b$ quay quanh trục $Ox$ tạo thành một khối tròn xoay có thể tích $V$. Khẳng định nào sau đây là $\\textbf{đúng}$?',
#  'Cho hàm số $y=f(x)$ có đồ thị như hình vẽ. Diện tích hình phẳng phần tô đậm trong hình vẽ là',
#  'Gọi $S$ là diện tích hình phẳng giới hạn bởi các đường $y=(1-x)\\mathrm{e}^{2x}$, trục hoành và $x=2$. Biết $S=\\dfrac{\\mathrm{e}^2\\bigl(\\mathrm{e}^2+a\\bigr)}{b},\\ (a,b\\in \\mathbb{N})$. Tính tổng $a+b$.',
#  'Một mặt cầu $(S)$ có  độ dài  bán kính bằng  $2a$. Tính diện tích $S_{mc}$ của  mặt cầu $(S)$.',
#  'Cho tứ diện đều $ABCD$ có độ dài cạnh là $a\\sqrt{2}$. Bán kính $R$ của mặt cầu ngoại tiếp tứ diện đó bằng bao nhiêu?',
#  "Cho hình lăng trụ tam giác đều $ABCA'B'C'$ có độ dài cạnh đáy bằng $a$ và chiều cao bằng $2a$. Tính diện tích $S$ của mặt cầu ngoại tiếp lăng trụ đã cho.",
#  'Bán kính mặt cầu ngoại tiếp khối lập phương cạnh $2a$ có độ dài bằng',
#  "Cho hình lăng trụ tam giác đều $ABC.A'B'C'$ có độ dài cạnh đáy bằng $a$ và chiều cao bằng $h.$ Tính thể tích của khối cầu ngoại tiếp lăng trụ đã cho.",
#  'Trong các hình chóp sau đây, hình chóp nào có mặt cầu ngoại tiếp?',
#  'Mỗi quả bóng bàn được đựng trong một hộp hình trụ sao cho quả bóng tiếp xúc với mặt xung quanh và hai mặt đáy của hộp. Tính tỉ số thể tích giữa quả bóng và hộp chứa.',
#  'Cho hình thang cong $(H)$ giới hạn bởi các đường $y=e^x,y=0,x=0$ và $x=\\ln 4$. Đường thẳng $x=k, (0<k<\\ln 4)$ chia $(H)$ thành hai phần có diện tích là $S_1, S_2$ và như hình vẽ bên. Tìm $k$ để $S_1=2S_2$.',
#  'Cho $(H)$ là miền hình phẳng giới hạn bởi các đường $x = a,\\,x = b$ (với $a<b$) và đồ thị của hai hàm số $y = f (x),\\, y = g(x)$. Gọi $V$ là thể tích của vật thể tròn xoay khi quay $(H)$ quanh $Ox$. Mệnh đề nào dưới đây là $\\textbf{đúng}$?',
#  'Cho hình chóp $S.ABC$ có đáy là tam giác $ABC$ vuông cân tại $B$, $SA$ vuông góc mp$(ABC)$. Biết $AB=a, SA=2a$. Tính diện tích mặt cầu ngoại tiếp hình chóp $S.ABC$.',
#  'Tính bán kính $R$ của mặt cầu ngoại tiếp bát diện đều cạnh $2a$.',
#  'Cho hình chóp $S.ABCD$ có đáy $ABCD$ là hình thang cân với đáy lớn $AD=2a, AB=BC=a$. Cạnh bên $SA=2a$ và vuông góc với mặt phẳng $(ABCD)$. Tính thể tích $V$ của khối cầu ngoại tiếp hình chóp $S.ABCD$.',
#  'Cho hình chóp $S.ABC$, có đáy $ABC$ là tam giác vuông tại $B$, cạnh bên $SA$ vuông góc với mặt đáy, $AB = a$, $BC = a\\sqrt{3}$, $SA = 2a$. Tính diện tích mặt cầu ngoại tiếp hình chóp $S.ABC$.',
#  'Cho hình hộp chữ nhật có ba kích thước lần lượt là $a$, $b$, $c$. Tính bán kính $R$ của mặt cầu ngoại tiếp hình hộp đó.',
#  'Mặt cầu thứ nhất có bán kính $R_1,$  diện tích  $S_1$.   Mặt cầu thứ hai có bán kính $R_2,$  diện tích  $S_2$.\nTìm tỉ số $\\dfrac{S_2}{S_1},$ biết $R_2=2R_1.$',
#  'Một cái phễu có dạng hình nón với chiều cao là $30\\ \\mathrm{cm}$. Người ta đổ một lượng nước vào phễu sao cho chiều cao của cột nước trong phễu bằng $15\\ \\mathrm{cm}$ (Hình 1). Nếu bịt kín miệng phễu rồi lật ngược phễu lên (Hình 2) thì chiều cao của cột nước trong phễu gần bằng với giá trị nào sau đây?',
#  ' $\\\\$Bình có một tấm bìa hình tròn như hình vẽ. Bạn ấy muốn biến hình tròn đó thành một hình cái phễu \nhình nón. Khi đó Bình phải cắt bỏ hình quạt tròn $AOB$ rồi dán hai bán kính $OA$ và $OB$ lại với \nnhau. Gọi $x$ là góc ở tâm hình quạt tròn dùng làm phễu. Tìm $x$ để thể tích phễu lớn nhất.',
#  'Căn biệt thự của ông $A$ có mười cây cột nhà hình trụ tròn, tất cả đều có chiều cao bằng $4,2 \\, \\mathrm{m}$. Trong đó, bốn cây cột trước đại sảnh có đường kính bằng $40 \\, \\mathrm{cm}$ và sáu cây cột còn lại bên hiên nhà có đường kính bằng $26 \\, \\mathrm{cm}$. Ông $A$ dự định dùng loại sơn giả đá để sơn tất cả mười cây cột đó. Biết rằng mỗi mét vuông, ông $A$ phải tốn $380\\, 000$ đồng, bao gồm tiền vật liệu và tiền công. Hỏi để sơn cả mười cây cột thì ông $A$ phải tốn bao nhiêu tiền?',
#  'Diện tích hình phẳng giới hạn bởi đồ thị các hàm số $y=x^{2}-2x$ và $y=x$ bằng',
#  'Tính diện tích hình phẳng được giới hạn bởi các đường $y=x^2-4x+6$ và $y=-x^2-2x+6.$',
#  'Cho hàm số $y=f(x)$ liên tục trên đoạn $[a;b]$ và $f(x)<0,\\forall x\\in[a;b]$. Ký hiệu $S$ là diện tích hình phẳng giới hạn bởi đồ thị hàm số $y=f(x)$, trục hoành và hai đường thẳng $x=a,x=b$. Khẳng định nào dưới đây $\\textbf{sai}$?',
#  'Cho hình chóp $S.ABCD,$ đáy là tứ giác $ABCD$ có $AB=2a,$ $BC=AC= a\\sqrt{2},$ $AD=a,$ $BD= a\\sqrt{3},$\ntam giác $SAB$ đều và nằm trong mặt phẳng vuông góc với đáy. Tính thể tích khối cầu ngoại tiếp hình chóp trên.',
#  'Mệnh đề nào sau đây đúng?',
#  'Cho hình chóp $S.ABCD$ có đáy $ABCD$ là hình vuông cạnh $2a$. Mặt bên $SAB$ là tam giác vuông cân tại $S$ và nằm trong mặt phẳng vuông góc với đáy. Tính bán kính $r$ của mặt cầu ngoại tiếp hình chóp $S.ABCD$.',
#  'Một mặt cầu bán kính $R$ đi qua tám đỉnh của hình lập phương thì cạnh của hình lập phương bằng',
#  'Hình chóp $S.ABC$ có đáy $ABC$ là tam giác vuông tại $A$, $SA$ vuông góc với $(ABC)$, $SA=a$, $AB=b$, $AC=c$. Tính bán kính $R$ của mặt cầu đi qua các điểm $A$, $B$, $C$ và $S$.',
#  'Cho hình chóp $ S.ABCD $ có $ SA \\perp (ABCD) $, đáy $ ABCD $ là hình chữ nhật, $ AB=a, AD=2a $, góc giữa đường thẳng $ SC $ và đáy bằng $ 45^\\circ $. Tính theo $a$ thể tích $ V $ của khối cầu ngoại tiếp hình chóp $ S.ABCD $.',
#  'Cho hình chóp $S.ABC$ có đáy $ABC$ là tam giác vuông cân tại $B$, $AB=BC=a\\sqrt{3}$, $\\widehat{SAB}=\\widehat{SCB}=90^\\circ$ và khoảng cách từ $A$ đến mặt phẳng $\\left(SBC\\right)$ bằng $a\\sqrt{2}$. Tính thể tích $V$ của mặt cầu ngoại tiếp hình chóp $S.ABC$.',
#  'Cho hình chóp $S.ABC$ có $3$ cạnh $SA,SB,SC$ đôi một vuông góc và tương ứng có độ dài bằng $a,2a,3a$. Tính thể tích $V$ của khối cầu ngoại tiếp hình chóp $S.ABC$.',
#  'Tính thể tích $V$ của khối cầu nội tiếp một hình lập phương có cạnh bằng $4$.',
#  'Một khối cầu có bán kính $6$ dm người ta cắt bỏ hai phần bằng hai mặt phẳng $(P)$, $(Q)$ (tâm khối cầu nằm giữa hai mặt phẳng $(P)$, $(Q)$) vuông góc cùng $1$ bán kính và mặt phẳng $(P)$ cách tâm $3$ dm và mặt phẳng $(Q)$ cách tâm $4$ dm để làm một chiếc lu đựng. Tính thể tích của chiếc lu.',
#  'Từ khúc gỗ hình trụ có đường kính $30 \\textrm{ cm},$ chiều cao $20 \\textrm{ cm},$ người ta cắt khúc gỗ thành hai phần bởi mặt phẳng đi qua đường kính đáy và nghiêng với đáy một góc $45^\\circ.$ Tính tỉ số thể tích giữa phần nhỏ và phần lớn.',
#  'Khi dựng nhà bằng gỗ, người ta thường kê dưới chân mỗi một cột một viên đá để không bị nhanh hỏng chân cột theo thời gian (gọi là đá tảng). $\\\\$\nCàng về sau càng có nhiều nghệ nhân làm đá một cách tinh xảo và đẹp mắt. Xét viên đá tảng được chia làm ba phân (như hình bên). Phần dưới cùng là khối chóp cụt lục giác đều có cạnh đáy nhỏ bằng $180$ mm, cạnh đáy lớn là $200$ mm. Phần ở giữa là một phần của khối cầu có tâm trùng với tâm đáy nhỏ của khối chóp cụt và bán kình $R=50\\sqrt{97}$ mm, khối cầu này cắt đáy lớn của khối chóp cụt theo giao diện là một hình tròn nội tiếp lục giác đều. Phần trên cùng là khối trụ có chiều cao $12$ mm. Chiều cao của viên đá là $482$ mm. Tính thể tích của viên (khối) đá tảng đó (lấy kết quả gần đúng đến mm$^3$).{0.6cm',
#  'Phần không gian bên trong chai nước ngọt có hình dạng như hình vẽ. Biết bán kính đáy $R=5$ cm, bán kính cổ chai $r=2$ cm, $AB=3$ cm, $BC=6$ cm, $CD=16$ cm. Tính thể tích $V$ phần không gian bên trong của chai nước ngọt đó.',
#  'Cho một tấm bìa hình tròn như hình vẽ. Ta cắt bỏ hình quạt $AOB$ (phần gạch chéo) rồi dán hai bán kính $OA$ và $OB$ lại với nhau để biến hình tròn đó thành một cái phễu hình nón. Gọi $x$ là số đo góc ở tâm hình quạt tròn dùng làm phễu. Tìm $x$ để thể tích của phễu đạt giá trị lớn nhất.',
# ...
#  'Lưu lượng xe ô tô vào đường hầm được cho bởi công thức\n$$f(v)=\\dfrac{290,4v}{0,36v^2+13,2v+264}\\text{ (xe/giây)}.$$\nTrong đó, $v$ (km/h) là vận tốc trung bình của các xe khi vào đường hầm. Tìm vận tốc trung bình của các xe khi vào đường hầm sao cho lưu lượng xe lớn nhất (kêt quả làm tròn đến hàng phần trăm).',
#  'Sau khi phát hiện một bệnh dịch, các chuyên gia Y tế ước tính số người nhiễm bệnh kể từ ngày phát hiện bệnh nhân đầu tiên đến ngày thứ $t$ là $f(t)=45t^2-t^3$. Hỏi số người nhiễm bệnh lớn nhất vào ngày thứ bao nhiêu?',
#  'Một nhà máy sản xuất cần thiết kế một thùng sơn dạng hình trụ có nắp đậy với dung tích $1000\\mathrm{\\, cm}^3$. Tính bán kính của nắp đậy sao cho nhà sản xuất tiết kiệm được nguyên liệu nhất.',
#  'Xác định số phức liên hợp của số phức $z$ biết $\\dfrac{\\big(i - 1\\big)z + 2}{1 - 2i} = 2 + 3i$.',
#  'Cho số phức $z\\ne 0$ sao cho $z$ không phải là số thực và $\\omega=\\dfrac z{1+z^2}$ là số thực. Tính $\\dfrac{|z|}{1+|z|^2}.$',
#  'Tìm số phức liên hợp của số phức $z=(1-i)^2(2-3i)$.',
#  'Cho số phức $z=2+3i$. Tìm mô-đun của số phức $w=1+2\\bar{z}+z$.',
#  'Số phức $z$ thỏa $2z-3i\\bar{z}+6+i=0$ có phần ảo là',
#  'Cho số phức $z=1+3i$. Tính mô-đun của số phức $w=z^2-i\\bar{z}$.',
#  'Cho số phức $z$ thỏa mãn $\\left|z\\right|=1$ và $w=\\dfrac{z^2-1}{z}$. Khẳng định nào dưới đây là $\\textbf{đúng}$?',
#  'Tính mô-đun của số phức $z$ thỏa mãn $(2-i)z-2=2+3i.$',
#  'Tính mô-đun của số phức $z=\\dfrac{(2+i)(2+4i)}{1-i} -(3+i)^2$.',
#  'Tìm số phức nghịch đảo của số phức $z=1+3i$.',
#  'Tìm mô-đun của số phức $z=(2-i)(1+2i)^2.$',
#  'Cho số phức $z=2-3i.$ Tìm tọa độ điểm $M$ biểu diễn của số phức $w=2z-i\\overline{z}.$',
#  'Cho số phức $z$ thỏa mãn $\\dfrac{5\\left(\\overline{z}+i\\right)}{z+1}=2-i.$ Tìm mô-đun của số phức $w=1+z+2\\overline{z}^2.$',
#  'Cho hai số phức $z_1=2-3i, z_2=1+2i$. Tính mô đun của số phức $z=(z_1+2)z_2$.',
#  'Cho số phức $z$ thỏa mãn $\\bar{z}=\\dfrac{1+3i}{1-i}$. Tính mô đun của số phức $w=\\bar{z}+iz$.',
#  'Cho hai số phức $z_1=3-2i,$ $z_2=-2+5i$. Tìm phần ảo của số phức $z=z_1+z_2.$',
#  'Tìm số phức liên hợp của số phức $(1-i)(3+2i).$',
#  "Cho hai số phức $z=a+2i \\,\\, (a \\in \\mathbb{R})$ và $z'=5-i$. Tìm điều kiện của $a$ để $z.z'$ là một số thực.",
#  'Một vật chuyển động theo quy luật $h=18t^{2}-\\dfrac{3}{2}t^{3}$, với $t$ là khoảng thời gian tính từ lúc vật bắt đầu chuyển động (tính bằng giây) và $h$ là quãng đường vật đi được (tính bằng mét) trong khoảng thời gian đó. Hỏi trong khoảng thời gian 6 giây, kể từ lúc vật bắt đầu chuyển động, vận tốc lớn nhất của vật đạt được bằng bao nhiêu?',
#  'Cho số phức $z=a+bi (a, b \\in \\mathbb R)$ thỏa mãn $(1+i)(2z-1)+(\\overline z + 1)(1-i)=2-2i$. Tính $P=a+b$.',
#  'Giá trị của biểu thức $\\left|4+3i\\right|+3\\left|3-4i\\right|-i^2$ bằng',
#  'Cho hai số phức $z_1=-3+2i, z_2=7-3i$. Tính $z_1-z_2$.',
#  'Cho số phức $z$ thỏa mãn $\\left(2-3i\\right)z+\\left(4+i\\right)\\overline{z}=-\\left(1+3i\\right)^2$. Xác định phần thực và phần ảo của số phức $z$.',
#  'Cho số phức $z=a+bi \\ (a,\\,b\\in\\mathbb{R})$ thoả mãn $z=\\dfrac{{(1+3i)}^2+3+4i}{1+2i}$. Khẳng định nào sau đây là khẳng định $\\textbf{đúng}$?',
#  'Tìm tọa độ điểm biểu diễn của số phức $z=(3-2i)-(-4+i)$ trong mặt phẳng phức.',
#  'Số nào trong các số sau là số thuần ảo?',
#  'Tìm tất cả các giá trị thực của tham số $m$ để số phức $(m+i)^2$ có phần thực bằng $3$.',
#  'Cho hai số phức $z_1 =2-3i, z_2 =1+4i.$  Tính mô-đun của số phức $w =z_1 +2\\overline{z_2}.$',
#  'Tính mô-đun của số phức $ z=(1-2i)\\left[2+i+i(3-2i)\\right].$',
#  'Tính tổng $S$ của phần thực và phần ảo của số phức $z=\\dfrac{(-1-i)\\left[(2-i)-(3-2i)\\right]}{1-i}$.',
#  'Cho số phức $z=a+bi$ $(a,b\\in \\mathbb R;\\, i^2=-1)$. Số phức $z^2$ có phần ảo là',
#  'Số phức liên hợp của số phức $z=(2+i)(-1+i)(2i+1)^2$ là',
#  'Mô-đun của số phức $z=5+2i-\\left(1+i\\right)^3$ là',
#  'Biết $\\dfrac{1}{3+4i}=a+bi,$ với $a,b\\in\\mathbb{R}.$ Tính $ab.$',
#  'Một vật chuyển động theo quy luật $s(t) = 6t^2 - 2t^3,$ với $t$ (giây) là khoảng thời gian tính từ lúc vật bắt đầu chuyển động và $s\\unit{(m)}$ là quãng đường vật đi được trong thời gian đó. Hỏi trong khoảng 6 giây kể từ lúc vật bắt đầu chuyển động, vận tốc lớn nhất của vật là bao nhiêu?',
#  'Một chất điểm chuyển động theo quy luật $s(t)=3t^2-t^3,$ trong đó $t$ là khoảng thời gian tính bằng giây, tính từ lúc chất điểm bắt đầu chuyển động, $s$ là quảng đường chất điểm đi được tính bằng mét. Tính thời điểm $t$ (giây) mà tại đó vận tốc của chất điểm đạt giá trị lớn nhất.',
#  'Khi nuôi cá thí nghiệm trong hồ, một nhà sinh vật học thấy rằng: Nếu trên mỗi đơn vị diện tích của mặt hồ có $n$ con cá thì trung bình mỗi con cá sau một vụ cân nặng $P(n)=480-20n\\,(\\mathrm{gam}).$ Tìm số con cá phải thả trên mỗi đơn vị diện tích của mặt hồ để sau một vụ thu hoạch được nhiều $\\mathrm{gam}$ cá nhất.',
#  'Công ty $X$ muốn thiết kế các hộp chứa sản phẩm dạng hình trụ có nắp với dung tích bằng $100\\textrm{ cm}^3$, bán kính đáy $x\\textrm{ cm}$, chiều cao $h\\textrm{ cm}$ (xem hình bên). Khi thiết kế, công ty $X$ luôn đặt mục tiêu sao cho vật liệu làm vỏ hộp là ít nhất, nghĩa là diện tích toàn phần hình trụ là nhỏ nhất. Khi đó, kích thước của $x$ và $h$ gần bằng số nào nhất trong các số dưới đây để công ty $X$ tiết kiệm được vật liệu nhất?',
#  'Số phức$z$ thỏa mãn $z - (2 + 3i)\\overline{z} = 1 - 9i$ là',
#  'Tính mô-đun của số phức $z=\\left(1+i \\right)^3$.',
#  'Cho các  số  phức  $z_1 =2-3i, z_2=1+4i$. Tìm số  phức  liên hợp của số phức  $z_1z_2$.',
#  'Tìm tất cả các căn bậc hai của số phức $-25$.',
#  'Cho số phức $z=i(2-3i)$ có phần thực là $a$ và phần ảo là $b$. Tìm $a$ và $b$.',
#  'Cho số phức $z=2+5i$. Tìm số phức $w=iz+\\overline{z}$.',
#  'Cho số phức $z=(3-2i)(2+i)-7$. Tìm số phức liên hợp của số phức $w=1+z+z^2$.',
#  'Tìm phần thực và phần ảo của số phức $z=(1+3i)-(2+i)$.',
#  'Cho số phức $z$ thỏa mãn điều kiện $2z+\\overline z = 3+i$. Tính $A= |iz+2i+1|$.',
#  'Trong mặt phẳng phức cho tam giác $ABC$ vuông tại $C$. Biết rằng $A$, $B$ lần lượt là điểm biểu diễn các số phức $z_{1}=-2-4i$, $z_{2}=2-2i$. Khi đó điểm $C$ biểu diễn số phức',
#  'Số phức $z=a+bi$ $\\left(a,b\\in\\mathbb{R}\\right)$ thỏa mãn $2z+\\overline{z}-5+i=0$. Tính $P=6a+4b$.',
#  'Cho số phức $z=\\dfrac{1-i}{1+i}$. Tìm phần thực và phần ảo của số phức $z^{2017}$.',
#  'Trong mặt phẳng phức, tìm tọa độ điểm $M$ là điểm biểu diễn số phức $z$ biết $z$ thỏa mãn phương trình $(1+i)\\overline{z}=3-5i$.',
#  'Tổng phần thực và phần ảo của số phức $z=\\left(1+2i\\right)\\left(3-i\\right)$ là',
#  'Cho hai số phức $z_1=3-2i$ và $z_2=1+i$. Tính mô-đun của số phức $w=z_1+\\overline{z_2}$.',
#  'Số phức $z=a+bi\\, (a,b\\in \\mathbb{R})$ thoả mãn điều kiện $z+\\dfrac{\\overline{z}\\left(6-2i\\right)}{(1+3i)(1+i)} +4i=0$. Tính tích $P=a.b$.',
#  'Giá trị của biểu thức $z={\\left(1+i\\sqrt{7-4\\sqrt{3}}\\right)}^{24}$ bằng',
#  'Tính tổng phần thực và phần ảo của số phức $z=2+2i-(3-i)(1+3i).$',
#  'Cho số phức $z=2-5i$. Tìm phần thực của số phức $z^{-1}$.',
#  'Tìm số phức liên hợp của số phức $z=2i(5-i)$.',
#  'Tìm số phức $z$ biết $\\bar{z}=(3-i)(2+3i)$.',
#  'Một gia đình xây cái bể hình trụ có thể tích $100$ m$^3$. Đáy bể làm bằng bê tông có giá $100.000$ đồng/m$^2$. Phần thân làm bằng tôn có giá $90.000$ đồng/m$^2$. Phần nắp làm bằng nhôm giá $120.000$ đồng/m$^2$. Để chi phí xây dựng bể đạt chi phí thấp nhất thì tỉ số giữa chiều cao $h$ và bán kính $R$ của bể là bao nhiêu?',
#  'Tìm số phức liên hợp của số phức $z$ biết $z=i.z+2$.',
#  'Cho các số phức $z_1$, $z_2$ thỏa mãn $|z_1+z_2|=3$, $|z_1|=1$, $|z_2|=2$. Tính $z_1 \\overline{z_2} + \\overline{z_1} z_2$.',
#  'Gọi $M$ là điểm biểu diễn của số phức $z=\\left(2-i\\right)2i$ trong mặt phẳng toạ độ. Tọa độ của điểm $M$ là',
#  'Số phức $(2-i)(1+2i)^2$ có mô-đun bằng',
#  'Cho số phức $z=a+bi$ ($a, b$ là các số thực khác $0$) thỏa mãn $\\left(i\\overline{z}\\right)\\left(z+3-i\\right)=0$. Tính tích $ab$.',
#  'Trên mặt phẳng tọa độ, điểm $P$ là điểm biểu diễn số phức $z$ như hình vẽ. Điểm nào trong hình vẽ là điểm biểu diễn số phức $w=z-1-2i$. ',
#  'Cho số phức $z=2-3i-(1+i).$ Gọi $M$ là điểm biểu diễn của số phức $z$ trên mặt phẳng tọa độ. Tìm tọa độ điểm $M$.',
#  'Cho số phức $z=(1+4i)i$. Tính mô-đun của số phức $\\overline{z}$.',
#  'Cho số phức $z$ thỏa mãn $\\left(1+i\\right)z+\\left(3-i\\right)\\overline{z}=2-6i$. Tính mô-đun của $z$.',
#  'Cho hai số phức $z_1=4-2i;z_2=-2+i$. Tính môđun của số phức $z_1+z_2$.',
#  'Với  $z_1,z_2$ là  hai số  phức  bất kỳ, giá trị của  biểu thức  $a=\\dfrac{|z_1|^2+|z_2|^2}{|z_1+z_2|^2+|z_1-z_2|^2}$ bằng',
#  'Trong các mệnh đề sau, hãy xác định mệnh đề đúng?',
#  'Tìm phần thực của số phức $z=(2-3i)(1-2i).$',
#  'Tìm số phức liên hợp của số phức $z=3-2i$.',
#  'Giá trị nhỏ nhất của hàm số $y=\\dfrac{1-x}{2x-3}$ trên đoạn $[0; 1]$ là',
#  'Cho $x, y$ là các số thực dương thỏa mãn điều kiện $x^4 + y^4 + \\dfrac{2}{xy}=3xy+3$. Khi đó giá trị lớn nhất của biểu thức $P=x^2 y^2 + \\dfrac{16}{x^2 + y^2 + 2}$ là',
#  'Hàm số $y=\\dfrac{{x}^2-3x}{x+1}$ có giá trị lớn nhất trên đoạn $[0;3]$ là',
#  'Tìm giá trị lớn nhất và giá trị nhỏ nhất của hàm số $y=x^3+3x^2-9x+1$ trên đoạn $[0;3]$.',
#  'Tìm giá trị lớn nhất và giá trị nhỏ nhất của hàm số $y=\\sqrt{4-x^2}$ trên đoạn $\\left[\\sqrt{3};2\\right]$.',
#  'Cho $x,y\\ge 0$ và $x+y=4$. Tìm giá trị lớn nhất của biểu thức $S=\\left(x^3-1\\right)\\left(y^3-1\\right)$.',
#  'Biết giá trị lớn nhất của hàm số $y=-x^2+4x-m$ trên đoạn $[-1;3]$ là 10. Khi đó, giá trị $m$ là bao nhiêu?',
#  'Giá trị lớn nhất của hàm số $y=\\dfrac{x^2+3}{x-1}$ trên đoạn $[2; 4]$ là',
#  'Giá trị nhỏ nhất của hàm số $y=-x^3+6x^2+2$ trên đoạn $\\left[1;6\\right]$ là',
#  'Tìm tất cả các giá trị thực $x$, $y$ sao cho $x^2-1+yi=-1+2i$.',
#  'Tìm số phức $z$ biết $\\dfrac{1}{\\overline{z}}=\\dfrac{1}{1-2i}-\\dfrac{1}{(1+2i)^{2}}$.',
#  'Số căn bậc hai của số phức $z=4i$ là',
#  'Cho hai số phức $z_1, z_2$ thỏa $|z_1|=1, |z_2|=1, |z_1+z_2|=\\sqrt{3}$. Khi đó, $|z_1-z_2|$ bằng',
#  'Cho $z_1$, $z_2$, $z_3$ là các số phức thỏa mãn $z_1+z_2+z_3=0$ và $\\left|z_1\\right|=\\left|z_2\\right|=\\left|z_3\\right|=1$. Gọi $A$, $B$, $C$ là ba điểm biểu diễn lần lượt cho ba số phức $z_1$, $z_2$, $z_3$. Tính diện tích $S$ của tam giác $ABC$.',
#  'Cho các số thực $a, b$ và số phức $w$, biết $w-2$ và $3i+2w$ là các nghiệm của phương trình\n$z^2 + az +b = 0$. Khi đó, mô-đun của $w$ bằng',
#  'Cho số phức $z=a+bi$, $a\\ne 0$ thỏa mãn $z$ không là số thực và $\\dfrac{z^2+z+1}{z^2-z+1}$ là số thực. Tính $M=\\dfrac{1-a^4-b^4}{1-a^6-b^6}$.',
#  'Cho số phức $z$ là nghiệm của phương trình $z^2-2z+2=0$. Tính giá trị của biểu thức  $P=z^{2012}+\\dfrac{1}{z^{2012}}$.',
#  'Tập nghiệm của phương trình $z^4-2z^2-8=0$ là',
#  'Gọi $z_1$ là nghiệm phức có phần ảo âm của phương trình $z^2+2z+2=0$. Tìm số phức liên hợp của số phức $w=(1+2i)z_1$.',
#  'Phương trình: $8z^2-4z+1=0$ có nghiệm là',
#  'Cho số phức $z=a+bi, \\mbox{ trong đó }a,b\\in \\mathbb{R}$ thoả mãn $3z-2\\overline{z}-6+10i=0.$ Tính $a-b.$',
#  'Trong $\\mathbb{C}$, tìm tập hợp nghiệm của phương trình $z^4  - 2z^2  - 8 = 0$.',
#  'Tính mô đun của số phức $z$ biết $(1+2i)z^2=3+4i.$',
#  'Kí hiệu $z_1, z_2$ là hai nghiệm phức của phương trình $z^2+z+1=0$. Tính giá trị của  $P=z_1^2+z_2^2+z_1z_2$.',
#  'Cho $m=2^x,\\space n=3^x$. Biểu diễn $6^x$ theo $m,n$',
#  'Cho $m=2^x,\\space n=2^{2x}$, biểu diễn $2^{3x}$ theo $m,n$',
#  'Cho $m=12^x,\\space n=6^x$. Biểu diễn $2^x$ theo $m,\\space n$',
#  'Cho $a=2^{3x},\\space b=2^{7x}$, biểu diễn $2^{4x}$ theo $a,\\space b$',
#  '',
#  'Trong không gian, cho hình chữ nhật $ABCD$ có $AB=1$ và $AD=2$. Gọi $M$, $N$ lần lượt là trung điểm của $AD$ và $BC$. Quay hình chữ nhật đó xung quanh trục $MN$, ta được một khối trụ. Tính diện tích toàn phần của hình trụ.',
#  "Cho hình trụ có bán kính đường tròn đáy bằng $R,$ chiều cao bằng $R\\sqrt{3}.$ Gọi $O,$ $O'$ là tâm của hai đường tròn đáy. Lấy các điểm $A,$ $B$ lần lượt thuộc đường tròn $(O),$ $(O')$ sao cho $AB=R\\sqrt{6}.$ Tính thể tích $V$ của khối tứ diện $OAO'B$ theo $R.$",
#  'Một chi tiết máy bằng đồng được tạo ra bằng cách cho hình vẽ sau (tất  cả các góc của hai đường thẳng cắt nhau đều bằng $90^\\circ$) với các kích thước $DI = 6$ cm, $GH = 1$ cm, $DE = FG = 2$ cm xoay quanh trục $d$. Khi bỏ chi tiết này vào một hộp nước hình trụ có bán kính đáy là $4$ cm, chiều cao $12$ cm đang chứa một lượng nước bằng nửa thể tích hộp thì mực nước dâng thêm là (Biết chi tiết chìm hoàn toàn trong nước)',
#  'Bánh của một chiếc xe lu có dạng hình trụ với đường kính đáy bằng $1,\\!2$ m, bề ngang bằng $2,\\!1$ m. Hỏi khi xe di chuyển thẳng, bánh xe quay được $12$ vòng, thì diện tích mặt đường được lu là bao nhiêu? (Kết quả làm tròn đến hàng đơn vị.)',
#  'Phần ảo của số phức $z=\\dfrac{5}{3}i$ là',
#  'Phần thực và phần ảo của số phức $z=\\sqrt{2}-\\sqrt{3}i$ lần lượt là',
#  'Tìm phần thực và phần ảo của số phức $z = 1 - 3i$.',
#  'Trong các khẳng định dưới đây, khẳng định nào $\\textbf{sai}$?',
#  'Tìm giá trị nhỏ nhất $m$ của hàm số $y=x^3-7x^2+11x-2$ trên đoạn $[0; 2]$.',
#  'Cho hàm số $f(x)=\\dfrac{9x+m^2}{x-1}$ (với $m$ là tham số thực). Tìm giá trị lớn nhất của hàm số trên đoạn $\\left[2;4\\right].$',
#  'Cho $x, y$ là những số thực thoả mãn $x^2+2xy+3y^2=1$. Giá trị  lớn nhất $M$ và nhỏ nhất $m$ của biểu thức $P=2(x^2+6xy)$ tương ứng là:',
#  'Giá trị lớn nhất của hàm số $y=\\sqrt{2x-x^2}$ trên đoạn $\\left[0;\\dfrac{3}{2}\\right]$ là',
#  'Đặt $M$ là giá trị lớn nhất, $m$ là giá trị nhỏ nhất của hàm số $f(x)=|x^3+3x^2-72x+90|$ trên đoạn $[-5;5].$ Khi đó tổng $M+m$ có giá trị là một số thuộc khoảng nào dưới đây?',
#  'Cho các số thực  $x, y$  thỏa mãn $x^2+2xy+3y^2=4.$  Tìm giá trị lớn nhất của biểu thức $P=\\left(x-y\\right)^2.$',
#  'Tổng giá trị lớn nhất và giá trị nhỏ nhất của hàm số $y=2x^3-3x^2-12x+10$ trên đoạn $[-3;3]$ là',
#  'Cho phương trình $\\sqrt{x-1}+4m\\sqrt[4]{x^2-3x+2}+(m+3)\\sqrt{x-2}=0$. Tìm $m$ để phương trình có nghiệm thực.',
#  'Cho số phức $z_1 = 1 + 2i$ và $z_2 = 1 - 2i$. Hỏi $z_1$, $z_2$ là nghiệm của phương trình phức nào sau đây?',
#  'Trong  tập phức,  phương trình ${(z+1)}^2 +{(z+2)}^2 +{(z+3)}^2=0$  có  bao nhiêu nghiệm?',
#  'Các nghiệm phức của phương trình $z^2+\\left(1+i\\right)z+5i=0$ là',
#  'Cho $z$ là số phức có phần thực là số nguyên và $|z|-2\\overline{z}=-7+3i+z$. Tính môđun của số phức $w=1-z+z^{2}$.',
#  'Trên đoạn $[-5; 5]$ có bao nhiêu số nguyên $x$ thỏa mãn $\\left|1+4i-2^{-x}\\right|\\le 5$?',
#  'Biết phương trình $z^2+az+b=0$ có một nghiệm phức là $z_0=1+2i$ với $a,b \\in \\mathbb{R}$. Tìm $a, b$.',
#  'Cho số phức $z$ có phần ảo âm, và thỏa mãn $z^2-z+1=0.$ Tìm môđun của số phức $\\omega=2z+3.$',
#  'Cho số phức $z$ thỏa mãn $\\left|z\\right|\\leq 1$. Đặt $A=\\dfrac{2z-i}{2+iz}$. Mệnh đề nào dưới đây đúng?',
#  'Tìm phần ảo của số phức $z$ thỏa mãn $z+2\\overline z=\\left(2-i\\right)^3\\left(1-i\\right)$.',
#  'Gọi $z_1$ và $z_2$ là hai nghiệm phức của phương trình $z^2-2z+10=0$. Giá trị biểu thức $A=|z_1|+|z_2|$ là',
#  'Biết rằng phương trình $z^2+bz+c=0 (b, c\\in \\mathbb{R})$ có một nghiệm phức là $z_1=1+2i$. Khẳng định nào sau đây là đúng?',
#  'Cho số phức $z$ thỏa mãn hệ thức $z+4i=\\vert z\\vert+2\\vert z\\vert i-1.$ Tính $T=4\\vert z\\vert^2-18\\vert z\\vert.$',
#  'Cho số phức $z=a+bi$ ($a,b\\in \\mathbb{R}$) thỏa mãn $6(2+i)z-18\\overline{z}=-1+19i$. Tính tổng $S=3a+2b$.',
#  'Có bao nhiêu số phức thỏa mãn phương trình $z^2=\\left|z\\right|^2+\\overline z$ ?',
#  'Cho số phức $z$ có môđun bằng $\\dfrac{1}{2}$ và số phức $w$ thỏa mãn: $\\dfrac{1}{z}+\\dfrac{1}{w}=\\dfrac{1}{z+w}$. Môđun của số phức $w$ bằng bao nhiêu?',
#  'Trong $\\mathbb{C}$, tìm nghiệm của phương trình $\\big(2 + 3i\\big)z = z - 1$.',
#  'Cho số phức $z$ là nghiệm phức của phương trình $x^2+x+1=0.$ Tính $P=z^4+2z^3-z.$',
#  'Cho số phức $z$ thỏa mãn $\\big(1 + i\\big)^2\\big(2 - i\\big)z = 8 + i + \\big(1 + 2i\\big)z$. Tìm phần thực của số phức $z$.',
#  'Trong tập hợp số phức $\\mathbb{C}$, có bao nhiêu số phức $z$ thỏa mãn điều kiện $z^2 + 3\\bar{z} - 2z\\cdot\\bar{z} = 0$.',
#  'Cho các số thực $a$, $b$, $c$ sao cho phương trình $z^3 + az^2 + bz + c = 0$ nhận $z = 1 + i$ và $z = 2$ là nghiệm của phương trình. Tính tổng $S = a + b + c$.',
#  ...]

# %%
tfidf = TfidfVectorizer()

# %%
# %%time

X = tfidf.fit_transform(corpus)
X
# Out:
# Wall time: 717 ms
# <34799x4517 sparse matrix of type '<class 'numpy.float64'>'
# 	with 683668 stored elements in Compressed Sparse Row format>

# %%
vocabulary = tfidf.vocabulary_
idf = tfidf.idf_

# %%
np.savez_compressed('tfidf/idf', idf=idf)
pickle.dump(vocabulary, open('tfidf/vocab.pkl', 'wb'))

# %%
idf
# Out:
# array([ 7.06292351, 10.76422549, 10.76422549, ..., 10.76422549,
#        10.76422549,  6.6370911 ])

# %%
new_tfidf = TfidfVectorizer()
new_tfidf.vocabulary_ = vocabulary
new_tfidf.idf_ = idf

# %%
new_tfidf
# Out:
# TfidfVectorizer()

# %%
mini_corpus = [corpus[f], corpus[s], corpus[234], corpus[981]]
mini_X = new_tfidf.transform(mini_corpus)

# %%
mini_X[0]
# Out:
# <1x4517 sparse matrix of type '<class 'numpy.float64'>'
# 	with 16 stored elements in Compressed Sparse Row format>

# %%
cosine_similarity(mini_X, X[0])
# Out:
# array([[0.35468638],
#        [0.02123111],
#        [0.00660203],
#        [0.02442019]])

# %%
new_X = new_tfidf.transform(corpus)

# %%
f = 9542
s = 34000
origin = cosine_similarity(X[f], X[s]).ravel()[0]
truncated = cosine_similarity(mini_X[0], mini_X[1]).ravel()[0]

print("Origin: %f" % origin)
print("Trunacted: %f" % truncated)
# Out:
# Origin: 0.019722
# Trunacted: 0.019722

# %%
f = 9542
s = 34028
origin = cosine_similarity(new_X[f], new_X[s]).ravel()[0]
truncated = cosine_similarity(X[f], X[s]).ravel()[0]

print("No-Train: %f" % origin)
print("Trained: %f" % truncated)
# Out:
# No-Train: 0.025679
# Trained: 0.025679
